# %% [markdown]
# ## Prep python

# %%
import os
import subprocess
import pandas as pd
import shutil
from shutil import copy
import time
from collections import defaultdict
from Bio import SeqIO
import glob

os.chdir("/master/nplatt/pathogen_probes/")


def wait_on_running_jobs():
   
    num_jobs = 1
    
    while num_jobs > 0:
        num_jobs = len(subprocess.check_output('qstat', shell=True).split("\n")) - 2
        time.sleep(60)
        print(".")

# %% [markdown]
# # Chlamydia

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'chlamydia'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Chlamydia_abortus_GCF_002895085",
               "Chlamydia_avium_GCF_000583875",
               "Chlamydia_buteonis_GCF_900634605",
               "Chlamydia_caviae_GCF_000007605",
               "Chlamydia_felis_GCF_000009945",
               "Chlamydia_gallinacea_GCF_000471025",
               "Chlamydia_ibidis_GCF_000454725",
               "Chlamydia_muridarum_GCF_000006685",
               "Chlamydia_pecorum_GCF_000204135",
               "Chlamydia_pneumoniae_GCF_000008745",
               "Chlamydia_psittaci_GCF_000204255",
               "Chlamydia_sp_GCF_900239945",
               "Chlamydia_suis_GCF_900169085" ]

reference_taxon = "Chlamydia_trachomatis_GCF_000008725"


all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002895085.1_ASM289508v1_genomic.fna.gz
#
# sent 42 bytes  received 341785 bytes  227884.67 bytes/sec
# total size is 341591  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000583875.1_ASM58387v1_genomic.fna.gz
#
# sent 42 bytes  received 311132 bytes  622348.00 bytes/sec
# total size is 310947  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900634605.1_RSHA_genomic.fna.gz
#
# sent 42 bytes  received 341793 bytes  227890.00 bytes/sec
# total size is 341606  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000007605.1_ASM760v1_genomic.fna.gz
#
# sent 42 bytes  received 351700 bytes  234494.67 bytes/sec
# total size is 351509  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000009945.1_ASM994v1_genomic.fna.gz
#
# sent 42 bytes  received 349893 bytes  233290.00 bytes/sec
# total size is 349702  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000471025.2_ASM47102v2_genomic.fna.gz
#
# sent 42 bytes  received 316978 bytes  211346.67 bytes/sec
# total size is 316793  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000454725.1_ibidis.assembly_genomic.fna.gz
#
# sent 42 bytes  received 342508 bytes  228366.67 bytes/sec
# total size is 342310  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000006685.1_ASM668v1_genomic.fna.gz
#
# sent 42 bytes  received 320871 bytes  213942.00 bytes/sec
# total size is 320688  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000204135.1_ASM20413v1_genomic.fna.gz
#
# sent 42 bytes  received 328845 bytes  219258.00 bytes/sec
# total size is 328652  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000008745.1_ASM874v1_genomic.fna.gz
#
# sent 42 bytes  received 366606 bytes  244432.00 bytes/sec
# total size is 366407  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_000204255.1_ASM20425v1_genomic.fna.gz
#
# sent 42 bytes  received 351224 bytes  234177.33 bytes/sec
# total size is 351031  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900239945.1_Chlamydia_sp._nov._H15-1957-10C_genomic.fna.gz
#
# sent 42 bytes  received 357880 bytes  238614.67 bytes/sec
# total size is 357666  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900169085.1_SWA-2_genomic.fna.gz
#
# sent 42 bytes  received 322351 bytes  644786.00 bytes/sec
# total size is 322171  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000008725.1_ASM872v1_genomic.fna.gz
#
# sent 42 bytes  received 310297 bytes  206892.67 bytes/sec
# total size is 310114  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482630 ("sim_Chlamydia_abortus_GCF_002895085") has been submitted
# Your job 5482631 ("sim_Chlamydia_avium_GCF_000583875") has been submitted
# Your job 5482632 ("sim_Chlamydia_buteonis_GCF_900634605") has been submitted
# Your job 5482633 ("sim_Chlamydia_caviae_GCF_000007605") has been submitted
# Your job 5482634 ("sim_Chlamydia_felis_GCF_000009945") has been submitted
# Your job 5482635 ("sim_Chlamydia_gallinacea_GCF_000471025") has been submitted
# Your job 5482636 ("sim_Chlamydia_ibidis_GCF_000454725") has been submitted
# Your job 5482637 ("sim_Chlamydia_muridarum_GCF_000006685") has been submitted
# Your job 5482638 ("sim_Chlamydia_pecorum_GCF_000204135") has been submitted
# Your job 5482639 ("sim_Chlamydia_pneumoniae_GCF_000008745") has been submitted
# Your job 5482640 ("sim_Chlamydia_psittaci_GCF_000204255") has been submitted
# Your job 5482641 ("sim_Chlamydia_sp_GCF_900239945") has been submitted
# Your job 5482642 ("sim_Chlamydia_suis_GCF_900169085") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/chlamydia/cleaned_genomes/Chlamydia_trachomatis_GCF_000008725_formatted.fas path=results/phyluce/chlamydia/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482643 ("map_Chlamydia_abortus_GCF_002895085") has been submitted
# Your job 5482644 ("map_Chlamydia_avium_GCF_000583875") has been submitted
# Your job 5482645 ("map_Chlamydia_buteonis_GCF_900634605") has been submitted
# Your job 5482646 ("map_Chlamydia_caviae_GCF_000007605") has been submitted
# Your job 5482647 ("map_Chlamydia_felis_GCF_000009945") has been submitted
# Your job 5482648 ("map_Chlamydia_gallinacea_GCF_000471025") has been submitted
# Your job 5482649 ("map_Chlamydia_ibidis_GCF_000454725") has been submitted
# Your job 5482650 ("map_Chlamydia_muridarum_GCF_000006685") has been submitted
# Your job 5482651 ("map_Chlamydia_pecorum_GCF_000204135") has been submitted
# Your job 5482652 ("map_Chlamydia_pneumoniae_GCF_000008745") has been submitted
# Your job 5482653 ("map_Chlamydia_psittaci_GCF_000204255") has been submitted
# Your job 5482654 ("map_Chlamydia_sp_GCF_900239945") has been submitted
# Your job 5482655 ("map_Chlamydia_suis_GCF_900169085") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482656 ("merge_Chlamydia_abortus_GCF_002895085") has been submitted
# Your job 5482657 ("merge_Chlamydia_avium_GCF_000583875") has been submitted
# Your job 5482658 ("merge_Chlamydia_buteonis_GCF_900634605") has been submitted
# Your job 5482659 ("merge_Chlamydia_caviae_GCF_000007605") has been submitted
# Your job 5482660 ("merge_Chlamydia_felis_GCF_000009945") has been submitted
# Your job 5482661 ("merge_Chlamydia_gallinacea_GCF_000471025") has been submitted
# Your job 5482662 ("merge_Chlamydia_ibidis_GCF_000454725") has been submitted
# Your job 5482663 ("merge_Chlamydia_muridarum_GCF_000006685") has been submitted
# Your job 5482664 ("merge_Chlamydia_pecorum_GCF_000204135") has been submitted
# Your job 5482665 ("merge_Chlamydia_pneumoniae_GCF_000008745") has been submitted
# Your job 5482666 ("merge_Chlamydia_psittaci_GCF_000204255") has been submitted
# Your job 5482667 ("merge_Chlamydia_sp_GCF_900239945") has been submitted
# Your job 5482668 ("merge_Chlamydia_suis_GCF_900169085") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 49 sequences from Chlamydia_abortus_GCF_002895085_merged.bed.  Filtered 39 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 10.
# Screened 33 sequences from Chlamydia_avium_GCF_000583875_merged.bed.  Filtered 21 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 12.
# Screened 47 sequences from Chlamydia_buteonis_GCF_900634605_merged.bed.  Filtered 37 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 10.
# Screened 45 sequences from Chlamydia_caviae_GCF_000007605_merged.bed.  Filtered 34 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 11.
# Screened 40 sequences from Chlamydia_felis_GCF_000009945_merged.bed.  Filtered 27 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 13.
# Screened 36 sequences from Chlamydia_gallinacea_GCF_000471025_merged.bed.  Filtered 24 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 12.
# Screened 40 sequences from Chlamydia_ibidis_GCF_000454725_merged.bed.  Filtered 30 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 10.
# Screened 802 sequences from Chlamydia_muridarum_GCF_000006685_merged.bed.  Filtered 458 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 344.
# Screened 24 sequences from Chlamydia_pecorum_GCF_000204135_merged.bed.  Filtered 14 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 10.
# Screened 35 sequences from Chlamydia_pneumoniae_GCF_000008745_merged.bed.  Filtered 29 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 42 sequences from Chlamydia_psittaci_GCF_000204255_merged.bed.  Filtered 29 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 13.
# Screened 33 sequences from Chlamydia_sp_GCF_900239945_merged.bed.  Filtered 22 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 11.
# Screened 653 sequences from Chlamydia_suis_GCF_900169085_merged.bed.  Filtered 375 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 278.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/chlamydia/initial_intervals/Chlamydia_suis_GCF_900169085_merged.bed --twobit results/phyluce/chlamydia/cleaned_genomes/Chlamydia_trachomatis_GCF_000008725_formatted.2bit --output results/phyluce/chlamydia/initial_intervals/Chlamydia_suis_GCF_900169085_stripped.bed;
# chlamydia_abortus_gcf_002895085.
# chlamydia_avium_gcf_000583875.
# chlamydia_buteonis_gcf_900634605.
# chlamydia_caviae_gcf_000007605.
# chlamydia_felis_gcf_000009945.
# chlamydia_gallinacea_gcf_000471025.
# chlamydia_ibidis_gcf_000454725.
# chlamydia_muridarum_gcf_000006685.
# chlamydia_pecorum_gcf_000204135.
# chlamydia_pneumoniae_gcf_000008745.
# chlamydia_psittaci_gcf_000204255.
# chlamydia_sp_gcf_900239945.
# chlamydia_suis_gcf_900169085.
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/chlamydia/initial_intervals/Chlamydia_suis_GCF_900169085_merged.bed --twobit results/phyluce/chlamydia/cleaned_genomes/Chlamydia_trachomatis_GCF_000008725_formatted.2bit --output results/phyluce/chlamydia/initial_intervals/Chlamydia_suis_GCF_900169085_stripped.bed;
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 0 taxa:	405.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 1 taxa:	405.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 2 taxa:	231.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 3 taxa:	14.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 4 taxa:	13.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 5 taxa:	12.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 6 taxa:	12.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 7 taxa:	10.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 8 taxa:	10.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 9 taxa:	9.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 10 taxa:	8.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 11 taxa:	7.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 12 taxa:	6.0
# Loci shared by Chlamydia_trachomatis_GCF_000008725 + 13 taxa:	6.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 2
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/chlamydia/initial_intervals/chlamydia-to-Chlamydia_trachomatis_GCF_000008725.sqlite --base-taxon Chlamydia_trachomatis_GCF_000008725 --output results/phyluce/chlamydia/initial_intervals/Chlamydia_trachomatis_GCF_000008725_+2.bed --specific-counts 2;
# Counter({'chlamydia_muridarum_gcf_000006685': 230, 'chlamydia_suis_gcf_900169085': 229, 'chlamydia_felis_gcf_000009945': 12, 'chlamydia_psittaci_gcf_000204255': 12, 'chlamydia_avium_gcf_000583875': 11, 'chlamydia_gallinacea_gcf_000471025': 10, 'chlamydia_caviae_gcf_000007605': 10, 'chlamydia_sp_gcf_900239945': 10, 'chlamydia_abortus_gcf_002895085': 10, 'chlamydia_pecorum_gcf_000204135': 10, 'chlamydia_ibidis_gcf_000454725': 10, 'chlamydia_buteonis_gcf_900634605': 9, 'chlamydia_pneumoniae_gcf_000008745': 6})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/chlamydia/initial_intervals/Chlamydia_trachomatis_GCF_000008725_+2.bed --twobit results/phyluce/chlamydia/cleaned_genomes/Chlamydia_trachomatis_GCF_000008725_formatted.2bit --buffer-to 160 --output results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2.fasta;
# Screened 231 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 231.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2.fasta --probe-prefix uce_chlamydia_ --design chlamydia_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 227
# Probe Count = 446

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas --query results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  09:29:01
# Ended:  Fri Feb 07, 2020  09:29:01
# Time for execution:  0.00403754711151 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas                        --lastz results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes_vself.lastz                       --probe-prefix=uce_chlamydia_;
# Parsing lastz file...
# Screening results...
# Screened 445 fasta sequences.  Filtered 4 duplicates. Kept 438.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/chlamydia/validate_intervals/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas --scaffoldlist Chlamydia_abortus_GCF_002895085 Chlamydia_avium_GCF_000583875 Chlamydia_buteonis_GCF_900634605 Chlamydia_caviae_GCF_000007605 Chlamydia_felis_GCF_000009945 Chlamydia_gallinacea_GCF_000471025 Chlamydia_ibidis_GCF_000454725 Chlamydia_muridarum_GCF_000006685 Chlamydia_pecorum_GCF_000204135 Chlamydia_pneumoniae_GCF_000008745 Chlamydia_psittaci_GCF_000204255 Chlamydia_sp_GCF_900239945 Chlamydia_suis_GCF_900169085 Chlamydia_trachomatis_GCF_000008725 --genome-base-path results/phyluce/chlamydia/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/chlamydia/validate_intervals/chlamydia-to-Chlamydia_trachomatis_GCF_000008725.sqlite --output results/phyluce/chlamydia/validate_intervals/lastz/;
#
# Running against Chlamydia_abortus_GCF_002895085.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmXuH4u.fasta
#
# Writing the results file...
# 	/tmp/tmpSxcq73.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_abortus_GCF_002895085.lastz
# Creating Chlamydia_abortus_GCF_002895085 table
# Inserting data to Chlamydia_abortus_GCF_002895085 table
#
# Running against Chlamydia_avium_GCF_000583875.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxX2hRE.fasta
#
# Writing the results file...
# 	/tmp/tmpXGCPjK.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_avium_GCF_000583875.lastz
# Creating Chlamydia_avium_GCF_000583875 table
# Inserting data to Chlamydia_avium_GCF_000583875 table
#
# Running against Chlamydia_buteonis_GCF_900634605.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpTUETwi.fasta
#
# Writing the results file...
# 	/tmp/tmpqmjk4j.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_buteonis_GCF_900634605.lastz
# Creating Chlamydia_buteonis_GCF_900634605 table
# Inserting data to Chlamydia_buteonis_GCF_900634605 table
#
# Running against Chlamydia_caviae_GCF_000007605.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpRDZO4k.fasta
#
# Writing the results file...
# 	/tmp/tmpwOBOhE.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_caviae_GCF_000007605.lastz
# Creating Chlamydia_caviae_GCF_000007605 table
# Inserting data to Chlamydia_caviae_GCF_000007605 table
#
# Running against Chlamydia_felis_GCF_000009945.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp5nXkFY.fasta
#
# Writing the results file...
# 	/tmp/tmp1oWtNh.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_felis_GCF_000009945.lastz
# Creating Chlamydia_felis_GCF_000009945 table
# Inserting data to Chlamydia_felis_GCF_000009945 table
#
# Running against Chlamydia_gallinacea_GCF_000471025.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpzgt5ix.fasta
#
# Writing the results file...
# 	/tmp/tmp3liO5A.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_gallinacea_GCF_000471025.lastz
# Creating Chlamydia_gallinacea_GCF_000471025 table
# Inserting data to Chlamydia_gallinacea_GCF_000471025 table
#
# Running against Chlamydia_ibidis_GCF_000454725.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp0v3oVM.fasta
#
# Writing the results file...
# 	/tmp/tmpzK_40a.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_ibidis_GCF_000454725.lastz
# Creating Chlamydia_ibidis_GCF_000454725 table
# Inserting data to Chlamydia_ibidis_GCF_000454725 table
#
# Running against Chlamydia_muridarum_GCF_000006685.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpKQXVlK.fasta
#
# Writing the results file...
# 	/tmp/tmpR_29EQ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_muridarum_GCF_000006685.lastz
# Creating Chlamydia_muridarum_GCF_000006685 table
# Inserting data to Chlamydia_muridarum_GCF_000006685 table
#
# Running against Chlamydia_pecorum_GCF_000204135.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpY9Lqov.fasta
#
# Writing the results file...
# 	/tmp/tmpXbAoCZ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_pecorum_GCF_000204135.lastz
# Creating Chlamydia_pecorum_GCF_000204135 table
# Inserting data to Chlamydia_pecorum_GCF_000204135 table
#
# Running against Chlamydia_pneumoniae_GCF_000008745.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmphpnvPF.fasta
#
# Writing the results file...
# 	/tmp/tmpflsnEE.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_pneumoniae_GCF_000008745.lastz
# Creating Chlamydia_pneumoniae_GCF_000008745 table
# Inserting data to Chlamydia_pneumoniae_GCF_000008745 table
#
# Running against Chlamydia_psittaci_GCF_000204255.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpehayqs.fasta
#
# Writing the results file...
# 	/tmp/tmp5kY3cs.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_psittaci_GCF_000204255.lastz
# Creating Chlamydia_psittaci_GCF_000204255 table
# Inserting data to Chlamydia_psittaci_GCF_000204255 table
#
# Running against Chlamydia_sp_GCF_900239945.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmppGgv6g.fasta
#
# Writing the results file...
# 	/tmp/tmplcJpAg.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_sp_GCF_900239945.lastz
# Creating Chlamydia_sp_GCF_900239945 table
# Inserting data to Chlamydia_sp_GCF_900239945 table
#
# Running against Chlamydia_suis_GCF_900169085.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpak0ct5.fasta
#
# Writing the results file...
# 	/tmp/tmp5g4J2k.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_suis_GCF_900169085.lastz
# Creating Chlamydia_suis_GCF_900169085 table
# Inserting data to Chlamydia_suis_GCF_900169085 table
#
# Running against Chlamydia_trachomatis_GCF_000008725.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpBJesKG.fasta
#
# Writing the results file...
# 	/tmp/tmpfT00xj.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/chlamydia/validate_intervals/lastz/Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_Chlamydia_trachomatis_GCF_000008725.lastz
# Creating Chlamydia_trachomatis_GCF_000008725 table
# Inserting data to Chlamydia_trachomatis_GCF_000008725 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/chlamydia/extract_probes_from_group/chlamydia_genome.conf --lastz results/phyluce/chlamydia/validate_intervals/lastz --probes 120 --probe-prefix uce_chlamydia_ --name-pattern "Chlamydia_trachomatis_GCF_000008725_+2_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/chlamydia/extract_probes_from_group/probe_fasta;
# 2020-02-07 09:29:20,337 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 09:29:20,339 - Phyluce - INFO - ------- Working on Chlamydia_abortus_GCF_002895085 genome -------
# 2020-02-07 09:29:20,340 - Phyluce - INFO - Reading Chlamydia_abortus_GCF_002895085 genome
# 2020-02-07 09:29:21,004 - Phyluce - INFO - Chlamydia_abortus_GCF_002895085: 208 uces, 0 dupes, 208 non-dupes, 2 orient drop, 0 length drop, 206 written
# 2020-02-07 09:29:21,004 - Phyluce - INFO - -------- Working on Chlamydia_avium_GCF_000583875 genome --------
# 2020-02-07 09:29:21,005 - Phyluce - INFO - Reading Chlamydia_avium_GCF_000583875 genome
# 2020-02-07 09:29:21,589 - Phyluce - INFO - Chlamydia_avium_GCF_000583875: 200 uces, 0 dupes, 200 non-dupes, 1 orient drop, 0 length drop, 199 written
# 2020-02-07 09:29:21,589 - Phyluce - INFO - ------- Working on Chlamydia_buteonis_GCF_900634605 genome ------
# 2020-02-07 09:29:21,590 - Phyluce - INFO - Reading Chlamydia_buteonis_GCF_900634605 genome
# 2020-02-07 09:29:22,209 - Phyluce - INFO - Chlamydia_buteonis_GCF_900634605: 210 uces, 1 dupes, 209 non-dupes, 2 orient drop, 0 length drop, 207 written
# 2020-02-07 09:29:22,209 - Phyluce - INFO - -------- Working on Chlamydia_caviae_GCF_000007605 genome -------
# 2020-02-07 09:29:22,209 - Phyluce - INFO - Reading Chlamydia_caviae_GCF_000007605 genome
# 2020-02-07 09:29:22,826 - Phyluce - INFO - Chlamydia_caviae_GCF_000007605: 206 uces, 0 dupes, 206 non-dupes, 2 orient drop, 0 length drop, 204 written
# 2020-02-07 09:29:22,827 - Phyluce - INFO - -------- Working on Chlamydia_felis_GCF_000009945 genome --------
# 2020-02-07 09:29:22,827 - Phyluce - INFO - Reading Chlamydia_felis_GCF_000009945 genome
# 2020-02-07 09:29:23,433 - Phyluce - INFO - Chlamydia_felis_GCF_000009945: 208 uces, 0 dupes, 208 non-dupes, 1 orient drop, 0 length drop, 207 written
# 2020-02-07 09:29:23,433 - Phyluce - INFO - ------ Working on Chlamydia_gallinacea_GCF_000471025 genome -----
# 2020-02-07 09:29:23,434 - Phyluce - INFO - Reading Chlamydia_gallinacea_GCF_000471025 genome
# 2020-02-07 09:29:24,023 - Phyluce - INFO - Chlamydia_gallinacea_GCF_000471025: 200 uces, 0 dupes, 200 non-dupes, 1 orient drop, 0 length drop, 199 written
# 2020-02-07 09:29:24,023 - Phyluce - INFO - -------- Working on Chlamydia_ibidis_GCF_000454725 genome -------
# 2020-02-07 09:29:24,024 - Phyluce - INFO - Reading Chlamydia_ibidis_GCF_000454725 genome
# 2020-02-07 09:29:24,613 - Phyluce - INFO - Chlamydia_ibidis_GCF_000454725: 197 uces, 1 dupes, 196 non-dupes, 2 orient drop, 0 length drop, 194 written
# 2020-02-07 09:29:24,613 - Phyluce - INFO - ------ Working on Chlamydia_muridarum_GCF_000006685 genome ------
# 2020-02-07 09:29:24,614 - Phyluce - INFO - Reading Chlamydia_muridarum_GCF_000006685 genome
# 2020-02-07 09:29:25,382 - Phyluce - INFO - Chlamydia_muridarum_GCF_000006685: 227 uces, 0 dupes, 227 non-dupes, 0 orient drop, 11 length drop, 216 written
# 2020-02-07 09:29:25,382 - Phyluce - INFO - ------- Working on Chlamydia_pecorum_GCF_000204135 genome -------
# 2020-02-07 09:29:25,383 - Phyluce - INFO - Reading Chlamydia_pecorum_GCF_000204135 genome
# 2020-02-07 09:29:25,940 - Phyluce - INFO - Chlamydia_pecorum_GCF_000204135: 195 uces, 0 dupes, 195 non-dupes, 2 orient drop, 0 length drop, 193 written
# 2020-02-07 09:29:25,940 - Phyluce - INFO - ------ Working on Chlamydia_pneumoniae_GCF_000008745 genome -----
# 2020-02-07 09:29:25,957 - Phyluce - INFO - Reading Chlamydia_pneumoniae_GCF_000008745 genome
# 2020-02-07 09:29:26,549 - Phyluce - INFO - Chlamydia_pneumoniae_GCF_000008745: 195 uces, 0 dupes, 195 non-dupes, 3 orient drop, 0 length drop, 192 written
# 2020-02-07 09:29:26,550 - Phyluce - INFO - ------- Working on Chlamydia_psittaci_GCF_000204255 genome ------
# 2020-02-07 09:29:26,550 - Phyluce - INFO - Reading Chlamydia_psittaci_GCF_000204255 genome
# 2020-02-07 09:29:27,161 - Phyluce - INFO - Chlamydia_psittaci_GCF_000204255: 208 uces, 0 dupes, 208 non-dupes, 3 orient drop, 0 length drop, 205 written
# 2020-02-07 09:29:27,161 - Phyluce - INFO - ---------- Working on Chlamydia_sp_GCF_900239945 genome ---------
# 2020-02-07 09:29:27,162 - Phyluce - INFO - Reading Chlamydia_sp_GCF_900239945 genome
# 2020-02-07 09:29:27,736 - Phyluce - INFO - Chlamydia_sp_GCF_900239945: 195 uces, 0 dupes, 195 non-dupes, 3 orient drop, 0 length drop, 192 written
# 2020-02-07 09:29:27,737 - Phyluce - INFO - --------- Working on Chlamydia_suis_GCF_900169085 genome --------
# 2020-02-07 09:29:27,737 - Phyluce - INFO - Reading Chlamydia_suis_GCF_900169085 genome
# 2020-02-07 09:29:28,507 - Phyluce - INFO - Chlamydia_suis_GCF_900169085: 227 uces, 0 dupes, 227 non-dupes, 0 orient drop, 12 length drop, 215 written
# 2020-02-07 09:29:28,507 - Phyluce - INFO - ----- Working on Chlamydia_trachomatis_GCF_000008725 genome -----
# 2020-02-07 09:29:28,508 - Phyluce - INFO - Reading Chlamydia_trachomatis_GCF_000008725 genome
# 2020-02-07 09:29:29,270 - Phyluce - INFO - Chlamydia_trachomatis_GCF_000008725: 227 uces, 0 dupes, 227 non-dupes, 1 orient drop, 11 length drop, 215 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/chlamydia/extract_probes_from_group/probe_fasta --output results/phyluce/chlamydia/extract_probes_from_group/multifastas.sqlite --base-taxon Chlamydia_trachomatis_GCF_000008725;
# chlamydia_abortus_gcf_002895085.
# chlamydia_avium_gcf_000583875.
# chlamydia_buteonis_gcf_900634605.
# chlamydia_caviae_gcf_000007605.
# chlamydia_felis_gcf_000009945.
# chlamydia_gallinacea_gcf_000471025.
# chlamydia_ibidis_gcf_000454725.
# chlamydia_muridarum_gcf_000006685.
# chlamydia_pecorum_gcf_000204135.
# chlamydia_pneumoniae_gcf_000008745.
# chlamydia_psittaci_gcf_000204255.
# chlamydia_sp_gcf_900239945.
# chlamydia_suis_gcf_900169085.
# chlamydia_trachomatis_gcf_000008725.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/chlamydia/extract_probes_from_group/multifastas.sqlite --base-taxon Chlamydia_trachomatis_GCF_000008725;
# Loci shared by 0 taxa:	226.0
# Loci shared by 1 taxa:	226.0
# Loci shared by 2 taxa:	226.0
# Loci shared by 3 taxa:	226.0
# Loci shared by 4 taxa:	215.0
# Loci shared by 5 taxa:	211.0
# Loci shared by 6 taxa:	210.0
# Loci shared by 7 taxa:	208.0
# Loci shared by 8 taxa:	207.0
# Loci shared by 9 taxa:	204.0
# Loci shared by 10 taxa:	200.0
# Loci shared by 11 taxa:	196.0
# Loci shared by 12 taxa:	183.0
# Loci shared by 13 taxa:	176.0
# Loci shared by 14 taxa:	156.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(14)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/chlamydia/extract_probes_from_group/multifastas.sqlite  --base-taxon Chlamydia_trachomatis_GCF_000008725 --output results/phyluce/chlamydia/extract_probes_from_group/Chlamydia_trachomatis_GCF_000008725+2-back-to-14.conf --specific-counts 14;
# Counter({'chlamydia_buteonis_gcf_900634605': 156, 'chlamydia_avium_gcf_000583875': 156, 'chlamydia_gallinacea_gcf_000471025': 156, 'chlamydia_felis_gcf_000009945': 156, 'chlamydia_caviae_gcf_000007605': 156, 'chlamydia_sp_gcf_900239945': 156, 'chlamydia_pneumoniae_gcf_000008745': 156, 'chlamydia_trachomatis_gcf_000008725': 156, 'chlamydia_psittaci_gcf_000204255': 156, 'chlamydia_suis_gcf_900169085': 156, 'chlamydia_abortus_gcf_002895085': 156, 'chlamydia_pecorum_gcf_000204135': 156, 'chlamydia_ibidis_gcf_000454725': 156, 'chlamydia_muridarum_gcf_000006685': 156})
# Total loci = 156

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/chlamydia/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/chlamydia/extract_probes_from_group/Chlamydia_trachomatis_GCF_000008725+2-back-to-14.conf --probe-prefix uce_chlamydia_ --designer rnplattii --design chlamydia_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.fasta;
# GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 156
# Probe Count = 4238

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.fasta --query results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  09:29:43
# Ended:  Fri Feb 07, 2020  09:29:49
# Time for execution:  0.0977126995722 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.fasta --lastz results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_chlamydia_;
# Parsing lastz file...
# Screening results...
# Screened 4237 fasta sequences.  Filtered 2 duplicates. Kept 4182.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.fasta
#          -o
#          results/phyluce/chlamydia/final_probe_design/chlamydia_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 09:31:56 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 4238
# longest and shortest : 80 and 80
# Total letters: 339040
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 16M = 33M
# Miscellaneous   : 4M
# Total           : 87M
#
# Table limit with the given memory limit:
# Max number of representatives: 3957771
# Max number of word counting entries: 89089442
#
# # comparing sequences from          0  to        706
# ---------- new table with      575 representatives
# # comparing sequences from        706  to       1294
# ----------    129 remaining sequences to the next cycle
# ---------- new table with      380 representatives
# # comparing sequences from       1165  to       1677
# ----------    221 remaining sequences to the next cycle
# ---------- new table with      253 representatives
# # comparing sequences from       1456  to       1919
# ----------    173 remaining sequences to the next cycle
# ---------- new table with      243 representatives
# # comparing sequences from       1746  to       2161
# ----------     47 remaining sequences to the next cycle
# ---------- new table with      299 representatives
# # comparing sequences from       2114  to       2468
# ----------    146 remaining sequences to the next cycle
# ---------- new table with      164 representatives
# # comparing sequences from       2322  to       2641
# ----------     96 remaining sequences to the next cycle
# ---------- new table with      188 representatives
# # comparing sequences from       2545  to       2827
# ----------     37 remaining sequences to the next cycle
# ---------- new table with      201 representatives
# # comparing sequences from       2790  to       3031
# ----------     49 remaining sequences to the next cycle
# ---------- new table with      150 representatives
# # comparing sequences from       2982  to       3191
# 99.9%---------- new table with      163 representatives
# # comparing sequences from       3191  to       3365
# 100.0%---------- new table with      120 representatives
# # comparing sequences from       3365  to       4238
# .....................---------- new table with      680 representatives
#
#      4238  finished       3416  clusters
#
# Approximated maximum memory consumption: 87M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 0.96

# %% [markdown]
# # Coxiella burnetti

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'coxiella'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Coxiella_burnetii_GCF_000017105",
               "Coxiella_burnetii_GCF_001572745",
               "Coxiella_burnetii_GCF_004006195",
               "Coxiella_burnetii_GCF_000019885",
               "Coxiella_burnetii_GCF_000168875",
               "Coxiella_burnetii_GCF_000018745",
               "Coxiella_burnetii_GCF_000019865",
               "Coxiella_burnetii_GCF_000367725",
               "Coxiella_burnetii_GCF_004087735",
               "Coxiella_burnetii_GCF_002109345",
               "Coxiella_burnetii_GCF_002094935",
               "Coxiella_burnetii_GCF_005280755",
               "Coxiella_burnetii_GCF_002634005",
               "Coxiella_burnetii_GCF_002633985",
               "Coxiella_burnetii_GCF_002633965",
               "Coxiella_burnetii_GCF_002633945",
               "Coxiella_burnetii_GCF_002633885",
               "Coxiella_burnetii_GCF_002634025",
               "Coxiella_burnetii_GCF_002634045",
               "Coxiella_burnetii_GCF_000767035",
               "Coxiella_burnetii_GCF_002634065",
               "Coxiella_burnetii_GCF_002633925",
               "Coxiella_burnetii_GCF_002633905",
               "Coxiella_burnetii_GCF_001572765",
               "Coxiella_burnetii_GCF_002634085",
               "Coxiella_burnetii_GCF_000612785",
               "Coxiella_burnetii_GCF_000826165",
               "Coxiella_burnetii_GCF_000820465",
               "Coxiella_burnetii_GCF_000967075",
               "Coxiella_burnetii_GCF_000470495",
               "Coxiella_burnetii_GCF_002247545",
               "Coxiella_burnetii_GCF_002247155",
               "Coxiella_burnetii_GCF_002896835",
               "Coxiella_burnetii_GCF_000613025",
               "Coxiella_burnetii_GCF_000723305",
               "Coxiella_burnetii_GCF_002924395",
               "Coxiella_burnetii_GCF_002247185",
               "Coxiella_burnetii_GCF_002896735",
               "Coxiella_burnetii_GCF_002896755",
               "Coxiella_burnetii_GCF_002896775",
               "Coxiella_burnetii_GCF_002247265",
               "Coxiella_burnetii_GCF_002247205",
               "Coxiella_burnetii_GCF_002924305",
               "Coxiella_burnetii_GCF_002924345",
               "Coxiella_burnetii_GCF_002924425",
               "Coxiella_burnetii_GCF_000723245",
               "Coxiella_burnetii_GCF_002247285",
               "Coxiella_burnetii_GCF_002247305",
               "Coxiella_burnetii_GCF_002247335",
               "Coxiella_burnetii_GCF_002249845",
               "Coxiella_burnetii_GCF_002924325",
               "Coxiella_burnetii_GCF_003849965",
               "Coxiella_burnetii_GCF_002247225",
               "Coxiella_burnetii_GCF_002896795",
               "Coxiella_burnetii_GCF_002924385",
               "Coxiella_burnetii_GCF_000751935",
               "Coxiella_burnetii_GCF_000820825",
               "Coxiella_burnetii_GCF_000756325",
               "Coxiella_burnetii_GCF_002591355",
               "Coxiella_burnetii_GCF_000169495",
               "Coxiella_burnetii_GCF_000723285",
               "Coxiella_burnetii_GCF_002896815",
               "Coxiella_burnetii_GCF_003849885",
               "Coxiella_burnetii_GCF_003849875",
               "Coxiella_burnetii_GCF_003849785",
               "Coxiella_burnetii_GCF_000723265",
               "Coxiella_burnetii_GCF_000300315",
               "Coxiella_burnetii_GCA_000359545" ]
                    
reference_taxon = "Coxiella_burnetii_GCF_000007765"


all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000007765.2_ASM776v2_genomic.fna.gz
#
# sent 42 bytes  received 605169 bytes  242084.40 bytes/sec
# total size is 604914  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000017105.1_ASM1710v1_genomic.fna.gz
#
# sent 42 bytes  received 659451 bytes  439662.00 bytes/sec
# total size is 659179  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001572745.1_ASM157274v1_genomic.fna.gz
#
# sent 42 bytes  received 619874 bytes  413277.33 bytes/sec
# total size is 619616  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004006195.1_ASM400619v1_genomic.fna.gz
#
# sent 42 bytes  received 608351 bytes  243357.20 bytes/sec
# total size is 608093  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000019885.1_ASM1988v1_genomic.fna.gz
#
# sent 42 bytes  received 623461 bytes  415668.67 bytes/sec
# total size is 623197  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000168875.3_ASM16887v3_genomic.fna.gz
#
# sent 42 bytes  received 623524 bytes  249426.40 bytes/sec
# total size is 623259  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000018745.1_ASM1874v1_genomic.fna.gz
#
# sent 42 bytes  received 609250 bytes  406194.67 bytes/sec
# total size is 608994  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000019865.1_ASM1986v1_genomic.fna.gz
#
# sent 42 bytes  received 597049 bytes  398060.67 bytes/sec
# total size is 596793  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000367725.3_Z3055_genomic.fna.gz
#
# sent 42 bytes  received 594265 bytes  237722.80 bytes/sec
# total size is 594013  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004087735.1_ASM408773v1_genomic.fna.gz
#
# sent 42 bytes  received 599598 bytes  399760.00 bytes/sec
# total size is 599340  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002109345.1_ASM210934v1_genomic.fna.gz
#
# sent 42 bytes  received 597412 bytes  238981.60 bytes/sec
# total size is 597154  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002094935.1_ASM209493v1_genomic.fna.gz
#
# sent 42 bytes  received 597419 bytes  398307.33 bytes/sec
# total size is 597161  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_005280755.1_ASM528075v1_genomic.fna.gz
#
# sent 42 bytes  received 597371 bytes  238965.20 bytes/sec
# total size is 597113  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002634005.1_ASM263400v1_genomic.fna.gz
#
# sent 42 bytes  received 597633 bytes  398450.00 bytes/sec
# total size is 597375  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633985.1_ASM263398v1_genomic.fna.gz
#
# sent 42 bytes  received 598140 bytes  398788.00 bytes/sec
# total size is 597882  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633965.1_ASM263396v1_genomic.fna.gz
#
# sent 42 bytes  received 598067 bytes  239243.60 bytes/sec
# total size is 597809  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633945.1_ASM263394v1_genomic.fna.gz
#
# sent 42 bytes  received 597452 bytes  398329.33 bytes/sec
# total size is 597194  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633885.1_ASM263388v1_genomic.fna.gz
#
# sent 42 bytes  received 587882 bytes  391949.33 bytes/sec
# total size is 587632  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002634025.1_ASM263402v1_genomic.fna.gz
#
# sent 42 bytes  received 595903 bytes  397296.67 bytes/sec
# total size is 595645  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002634045.1_ASM263404v1_genomic.fna.gz
#
# sent 42 bytes  received 595629 bytes  397114.00 bytes/sec
# total size is 595371  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000767035.1_ASM76703v1_genomic.fna.gz
#
# sent 42 bytes  received 610232 bytes  406849.33 bytes/sec
# total size is 609975  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002634065.1_ASM263406v1_genomic.fna.gz
#
# sent 42 bytes  received 608536 bytes  1217156.00 bytes/sec
# total size is 608278  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633925.1_ASM263392v1_genomic.fna.gz
#
# sent 42 bytes  received 601647 bytes  1203378.00 bytes/sec
# total size is 601389  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002633905.1_ASM263390v1_genomic.fna.gz
#
# sent 42 bytes  received 602387 bytes  401619.33 bytes/sec
# total size is 602129  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001572765.1_ASM157276v1_genomic.fna.gz
#
# sent 42 bytes  received 595298 bytes  396893.33 bytes/sec
# total size is 595040  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002634085.1_ASM263408v1_genomic.fna.gz
#
# sent 42 bytes  received 591967 bytes  394672.67 bytes/sec
# total size is 591709  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000612785.1_Cb-C2_genomic.fna.gz
#
# sent 42 bytes  received 604561 bytes  93015.85 bytes/sec
# total size is 604309  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000826165.2_Coxiella_burnetii_Cb171_QLYMPHOMA_genomic.fna.gz
#
# sent 42 bytes  received 620084 bytes  413417.33 bytes/sec
# total size is 619804  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000820465.1_Coxiella_burnetii_genomic.fna.gz
#
# sent 42 bytes  received 596982 bytes  398016.00 bytes/sec
# total size is 596718  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000967075.1_ASM96707v1_genomic.fna.gz
#
# sent 42 bytes  received 636538 bytes  424386.67 bytes/sec
# total size is 636273  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000470495.1_Cb185_genomic.fna.gz
#
# sent 42 bytes  received 593546 bytes  395725.33 bytes/sec
# total size is 593294  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247545.1_ASM224754v1_genomic.fna.gz
#
# sent 42 bytes  received 656777 bytes  437879.33 bytes/sec
# total size is 656503  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002247155.1_ASM224715v1_genomic.fna.gz
#
# sent 42 bytes  received 657149 bytes  438127.33 bytes/sec
# total size is 656875  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002896835.1_ASM289683v1_genomic.fna.gz
#
# sent 42 bytes  received 602458 bytes  401666.67 bytes/sec
# total size is 602200  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000613025.1_Cb-B1_genomic.fna.gz
#
# sent 42 bytes  received 602783 bytes  401883.33 bytes/sec
# total size is 602531  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000723305.1_Cb-B18_genomic.fna.gz
#
# sent 42 bytes  received 603153 bytes  402130.00 bytes/sec
# total size is 602900  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002924395.1_ASM292439v1_genomic.fna.gz
#
# sent 42 bytes  received 591704 bytes  394497.33 bytes/sec
# total size is 591446  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247185.1_ASM224718v1_genomic.fna.gz
#
# sent 42 bytes  received 601877 bytes  401279.33 bytes/sec
# total size is 601619  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002896735.1_ASM289673v1_genomic.fna.gz
#
# sent 42 bytes  received 601963 bytes  401336.67 bytes/sec
# total size is 601705  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002896755.1_ASM289675v1_genomic.fna.gz
#
# sent 42 bytes  received 602191 bytes  401488.67 bytes/sec
# total size is 601933  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002896775.1_ASM289677v1_genomic.fna.gz
#
# sent 42 bytes  received 602724 bytes  401844.00 bytes/sec
# total size is 602466  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247265.1_ASM224726v1_genomic.fna.gz
#
# sent 42 bytes  received 601637 bytes  401119.33 bytes/sec
# total size is 601379  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247205.1_ASM224720v1_genomic.fna.gz
#
# sent 42 bytes  received 601515 bytes  401038.00 bytes/sec
# total size is 601257  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002924305.1_ASM292430v1_genomic.fna.gz
#
# sent 42 bytes  received 601463 bytes  401003.33 bytes/sec
# total size is 601205  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002924345.1_ASM292434v1_genomic.fna.gz
#
# sent 42 bytes  received 601623 bytes  401110.00 bytes/sec
# total size is 601365  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002924425.1_ASM292442v1_genomic.fna.gz
#
# sent 42 bytes  received 601459 bytes  401000.67 bytes/sec
# total size is 601201  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000723245.1_EV-Cb-BK10_genomic.fna.gz
#
# sent 42 bytes  received 600571 bytes  400408.67 bytes/sec
# total size is 600314  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247285.1_ASM224728v1_genomic.fna.gz
#
# sent 42 bytes  received 601652 bytes  70787.53 bytes/sec
# total size is 601394  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247305.1_ASM224730v1_genomic.fna.gz
#
# sent 42 bytes  received 601807 bytes  401232.67 bytes/sec
# total size is 601549  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247335.1_ASM224733v1_genomic.fna.gz
#
# sent 42 bytes  received 601782 bytes  401216.00 bytes/sec
# total size is 601524  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002249845.1_ASM224984v1_genomic.fna.gz
#
# sent 42 bytes  received 601724 bytes  401177.33 bytes/sec
# total size is 601466  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002924325.1_ASM292432v1_genomic.fna.gz
#
# sent 42 bytes  received 602079 bytes  133804.67 bytes/sec
# total size is 601821  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003849965.1_ASM384996v1_genomic.fna.gz
#
# sent 42 bytes  received 602548 bytes  401726.67 bytes/sec
# total size is 602290  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002247225.1_ASM224722v1_genomic.fna.gz
#
# sent 42 bytes  received 592110 bytes  394768.00 bytes/sec
# total size is 591852  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002896795.1_ASM289679v1_genomic.fna.gz
#
# sent 42 bytes  received 597094 bytes  398090.67 bytes/sec
# total size is 596836  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002924385.1_ASM292438v1_genomic.fna.gz
#
# sent 42 bytes  received 601801 bytes  401228.67 bytes/sec
# total size is 601543  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000751935.2_Coxiella_burnetii_genomic.fna.gz
#
# sent 42 bytes  received 586693 bytes  391156.67 bytes/sec
# total size is 586437  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000820825.1_Coxiella_burnetii_Dog_Utad_genomic.fna.gz
#
# sent 42 bytes  received 588901 bytes  1177886.00 bytes/sec
# total size is 588636  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000756325.1_CoxAra_genomic.fna.gz
#
# sent 42 bytes  received 620655 bytes  413798.00 bytes/sec
# total size is 620402  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002591355.1_ASM259135v1_genomic.fna.gz
#
# sent 42 bytes  received 627194 bytes  418157.33 bytes/sec
# total size is 626928  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000169495.2_ASM16949v2_genomic.fna.gz
#
# sent 42 bytes  received 598301 bytes  398895.33 bytes/sec
# total size is 598044  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000723285.1_EV-Cb-C13_genomic.fna.gz
#
# sent 42 bytes  received 604197 bytes  402826.00 bytes/sec
# total size is 603941  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002896815.1_ASM289681v1_genomic.fna.gz
#
# sent 42 bytes  received 603699 bytes  402494.00 bytes/sec
# total size is 603441  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003849885.1_ASM384988v1_genomic.fna.gz
#
# sent 42 bytes  received 600558 bytes  400400.00 bytes/sec
# total size is 600300  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003849875.1_ASM384987v1_genomic.fna.gz
#
# sent 42 bytes  received 600910 bytes  400634.67 bytes/sec
# total size is 600652  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_003849785.1_ASM384978v1_genomic.fna.gz
#
# sent 42 bytes  received 599846 bytes  399925.33 bytes/sec
# total size is 599588  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000723265.1_Cb-O184_genomic.fna.gz
#
# sent 42 bytes  received 645790 bytes  430554.67 bytes/sec
# total size is 645528  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000300315.1_ASM30031v1_genomic.fna.gz
#
# sent 42 bytes  received 588648 bytes  392460.00 bytes/sec
# total size is 588399  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000359545.5_G255_GS_genomic.fna.gz
#
# sent 42 bytes  received 603448 bytes  402326.67 bytes/sec
# total size is 603194  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482669 ("sim_Coxiella_burnetii_GCF_000017105") has been submitted
# Your job 5482670 ("sim_Coxiella_burnetii_GCF_001572745") has been submitted
# Your job 5482671 ("sim_Coxiella_burnetii_GCF_004006195") has been submitted
# Your job 5482672 ("sim_Coxiella_burnetii_GCF_000019885") has been submitted
# Your job 5482673 ("sim_Coxiella_burnetii_GCF_000168875") has been submitted
# Your job 5482674 ("sim_Coxiella_burnetii_GCF_000018745") has been submitted
# Your job 5482675 ("sim_Coxiella_burnetii_GCF_000019865") has been submitted
# Your job 5482676 ("sim_Coxiella_burnetii_GCF_000367725") has been submitted
# Your job 5482677 ("sim_Coxiella_burnetii_GCF_004087735") has been submitted
# Your job 5482678 ("sim_Coxiella_burnetii_GCF_002109345") has been submitted
# Your job 5482679 ("sim_Coxiella_burnetii_GCF_002094935") has been submitted
# Your job 5482680 ("sim_Coxiella_burnetii_GCF_005280755") has been submitted
# Your job 5482681 ("sim_Coxiella_burnetii_GCF_002634005") has been submitted
# Your job 5482682 ("sim_Coxiella_burnetii_GCF_002633985") has been submitted
# Your job 5482683 ("sim_Coxiella_burnetii_GCF_002633965") has been submitted
# Your job 5482684 ("sim_Coxiella_burnetii_GCF_002633945") has been submitted
# Your job 5482685 ("sim_Coxiella_burnetii_GCF_002633885") has been submitted
# Your job 5482686 ("sim_Coxiella_burnetii_GCF_002634025") has been submitted
# Your job 5482687 ("sim_Coxiella_burnetii_GCF_002634045") has been submitted
# Your job 5482688 ("sim_Coxiella_burnetii_GCF_000767035") has been submitted
# Your job 5482689 ("sim_Coxiella_burnetii_GCF_002634065") has been submitted
# Your job 5482690 ("sim_Coxiella_burnetii_GCF_002633925") has been submitted
# Your job 5482691 ("sim_Coxiella_burnetii_GCF_002633905") has been submitted
# Your job 5482692 ("sim_Coxiella_burnetii_GCF_001572765") has been submitted
# Your job 5482693 ("sim_Coxiella_burnetii_GCF_002634085") has been submitted
# Your job 5482694 ("sim_Coxiella_burnetii_GCF_000612785") has been submitted
# Your job 5482695 ("sim_Coxiella_burnetii_GCF_000826165") has been submitted
# Your job 5482696 ("sim_Coxiella_burnetii_GCF_000820465") has been submitted
# Your job 5482697 ("sim_Coxiella_burnetii_GCF_000967075") has been submitted
# Your job 5482698 ("sim_Coxiella_burnetii_GCF_000470495") has been submitted
# Your job 5482699 ("sim_Coxiella_burnetii_GCF_002247545") has been submitted
# Your job 5482700 ("sim_Coxiella_burnetii_GCF_002247155") has been submitted
# Your job 5482701 ("sim_Coxiella_burnetii_GCF_002896835") has been submitted
# Your job 5482702 ("sim_Coxiella_burnetii_GCF_000613025") has been submitted
# Your job 5482703 ("sim_Coxiella_burnetii_GCF_000723305") has been submitted
# Your job 5482704 ("sim_Coxiella_burnetii_GCF_002924395") has been submitted
# Your job 5482705 ("sim_Coxiella_burnetii_GCF_002247185") has been submitted
# Your job 5482706 ("sim_Coxiella_burnetii_GCF_002896735") has been submitted
# Your job 5482707 ("sim_Coxiella_burnetii_GCF_002896755") has been submitted
# Your job 5482708 ("sim_Coxiella_burnetii_GCF_002896775") has been submitted
# Your job 5482709 ("sim_Coxiella_burnetii_GCF_002247265") has been submitted
# Your job 5482710 ("sim_Coxiella_burnetii_GCF_002247205") has been submitted
# Your job 5482711 ("sim_Coxiella_burnetii_GCF_002924305") has been submitted
# Your job 5482712 ("sim_Coxiella_burnetii_GCF_002924345") has been submitted
# Your job 5482713 ("sim_Coxiella_burnetii_GCF_002924425") has been submitted
# Your job 5482714 ("sim_Coxiella_burnetii_GCF_000723245") has been submitted
# Your job 5482715 ("sim_Coxiella_burnetii_GCF_002247285") has been submitted
# Your job 5482716 ("sim_Coxiella_burnetii_GCF_002247305") has been submitted
# Your job 5482717 ("sim_Coxiella_burnetii_GCF_002247335") has been submitted
# Your job 5482718 ("sim_Coxiella_burnetii_GCF_002249845") has been submitted
# Your job 5482719 ("sim_Coxiella_burnetii_GCF_002924325") has been submitted
# Your job 5482720 ("sim_Coxiella_burnetii_GCF_003849965") has been submitted
# Your job 5482721 ("sim_Coxiella_burnetii_GCF_002247225") has been submitted
# Your job 5482722 ("sim_Coxiella_burnetii_GCF_002896795") has been submitted
# Your job 5482723 ("sim_Coxiella_burnetii_GCF_002924385") has been submitted
# Your job 5482724 ("sim_Coxiella_burnetii_GCF_000751935") has been submitted
# Your job 5482725 ("sim_Coxiella_burnetii_GCF_000820825") has been submitted
# Your job 5482726 ("sim_Coxiella_burnetii_GCF_000756325") has been submitted
# Your job 5482727 ("sim_Coxiella_burnetii_GCF_002591355") has been submitted
# Your job 5482728 ("sim_Coxiella_burnetii_GCF_000169495") has been submitted
# Your job 5482729 ("sim_Coxiella_burnetii_GCF_000723285") has been submitted
# Your job 5482730 ("sim_Coxiella_burnetii_GCF_002896815") has been submitted
# Your job 5482731 ("sim_Coxiella_burnetii_GCF_003849885") has been submitted
# Your job 5482732 ("sim_Coxiella_burnetii_GCF_003849875") has been submitted
# Your job 5482733 ("sim_Coxiella_burnetii_GCF_003849785") has been submitted
# Your job 5482734 ("sim_Coxiella_burnetii_GCF_000723265") has been submitted
# Your job 5482735 ("sim_Coxiella_burnetii_GCF_000300315") has been submitted
# Your job 5482736 ("sim_Coxiella_burnetii_GCA_000359545") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/coxiella/cleaned_genomes/Coxiella_burnetii_GCF_000007765_formatted.fas path=results/phyluce/coxiella/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482737 ("map_Coxiella_burnetii_GCF_000017105") has been submitted
# Your job 5482738 ("map_Coxiella_burnetii_GCF_001572745") has been submitted
# Your job 5482739 ("map_Coxiella_burnetii_GCF_004006195") has been submitted
# Your job 5482740 ("map_Coxiella_burnetii_GCF_000019885") has been submitted
# Your job 5482741 ("map_Coxiella_burnetii_GCF_000168875") has been submitted
# Your job 5482742 ("map_Coxiella_burnetii_GCF_000018745") has been submitted
# Your job 5482743 ("map_Coxiella_burnetii_GCF_000019865") has been submitted
# Your job 5482744 ("map_Coxiella_burnetii_GCF_000367725") has been submitted
# Your job 5482745 ("map_Coxiella_burnetii_GCF_004087735") has been submitted
# Your job 5482746 ("map_Coxiella_burnetii_GCF_002109345") has been submitted
# Your job 5482747 ("map_Coxiella_burnetii_GCF_002094935") has been submitted
# Your job 5482748 ("map_Coxiella_burnetii_GCF_005280755") has been submitted
# Your job 5482749 ("map_Coxiella_burnetii_GCF_002634005") has been submitted
# Your job 5482750 ("map_Coxiella_burnetii_GCF_002633985") has been submitted
# Your job 5482751 ("map_Coxiella_burnetii_GCF_002633965") has been submitted
# Your job 5482752 ("map_Coxiella_burnetii_GCF_002633945") has been submitted
# Your job 5482753 ("map_Coxiella_burnetii_GCF_002633885") has been submitted
# Your job 5482754 ("map_Coxiella_burnetii_GCF_002634025") has been submitted
# Your job 5482755 ("map_Coxiella_burnetii_GCF_002634045") has been submitted
# Your job 5482756 ("map_Coxiella_burnetii_GCF_000767035") has been submitted
# Your job 5482757 ("map_Coxiella_burnetii_GCF_002634065") has been submitted
# Your job 5482758 ("map_Coxiella_burnetii_GCF_002633925") has been submitted
# Your job 5482759 ("map_Coxiella_burnetii_GCF_002633905") has been submitted
# Your job 5482760 ("map_Coxiella_burnetii_GCF_001572765") has been submitted
# Your job 5482761 ("map_Coxiella_burnetii_GCF_002634085") has been submitted
# Your job 5482762 ("map_Coxiella_burnetii_GCF_000612785") has been submitted
# Your job 5482763 ("map_Coxiella_burnetii_GCF_000826165") has been submitted
# Your job 5482764 ("map_Coxiella_burnetii_GCF_000820465") has been submitted
# Your job 5482765 ("map_Coxiella_burnetii_GCF_000967075") has been submitted
# Your job 5482766 ("map_Coxiella_burnetii_GCF_000470495") has been submitted
# Your job 5482767 ("map_Coxiella_burnetii_GCF_002247545") has been submitted
# Your job 5482768 ("map_Coxiella_burnetii_GCF_002247155") has been submitted
# Your job 5482769 ("map_Coxiella_burnetii_GCF_002896835") has been submitted
# Your job 5482770 ("map_Coxiella_burnetii_GCF_000613025") has been submitted
# Your job 5482771 ("map_Coxiella_burnetii_GCF_000723305") has been submitted
# Your job 5482772 ("map_Coxiella_burnetii_GCF_002924395") has been submitted
# Your job 5482773 ("map_Coxiella_burnetii_GCF_002247185") has been submitted
# Your job 5482774 ("map_Coxiella_burnetii_GCF_002896735") has been submitted
# Your job 5482775 ("map_Coxiella_burnetii_GCF_002896755") has been submitted
# Your job 5482776 ("map_Coxiella_burnetii_GCF_002896775") has been submitted
# Your job 5482777 ("map_Coxiella_burnetii_GCF_002247265") has been submitted
# Your job 5482778 ("map_Coxiella_burnetii_GCF_002247205") has been submitted
# Your job 5482779 ("map_Coxiella_burnetii_GCF_002924305") has been submitted
# Your job 5482780 ("map_Coxiella_burnetii_GCF_002924345") has been submitted
# Your job 5482781 ("map_Coxiella_burnetii_GCF_002924425") has been submitted
# Your job 5482782 ("map_Coxiella_burnetii_GCF_000723245") has been submitted
# Your job 5482783 ("map_Coxiella_burnetii_GCF_002247285") has been submitted
# Your job 5482784 ("map_Coxiella_burnetii_GCF_002247305") has been submitted
# Your job 5482785 ("map_Coxiella_burnetii_GCF_002247335") has been submitted
# Your job 5482786 ("map_Coxiella_burnetii_GCF_002249845") has been submitted
# Your job 5482787 ("map_Coxiella_burnetii_GCF_002924325") has been submitted
# Your job 5482788 ("map_Coxiella_burnetii_GCF_003849965") has been submitted
# Your job 5482789 ("map_Coxiella_burnetii_GCF_002247225") has been submitted
# Your job 5482790 ("map_Coxiella_burnetii_GCF_002896795") has been submitted
# Your job 5482791 ("map_Coxiella_burnetii_GCF_002924385") has been submitted
# Your job 5482792 ("map_Coxiella_burnetii_GCF_000751935") has been submitted
# Your job 5482793 ("map_Coxiella_burnetii_GCF_000820825") has been submitted
# Your job 5482794 ("map_Coxiella_burnetii_GCF_000756325") has been submitted
# Your job 5482795 ("map_Coxiella_burnetii_GCF_002591355") has been submitted
# Your job 5482796 ("map_Coxiella_burnetii_GCF_000169495") has been submitted
# Your job 5482797 ("map_Coxiella_burnetii_GCF_000723285") has been submitted
# Your job 5482798 ("map_Coxiella_burnetii_GCF_002896815") has been submitted
# Your job 5482799 ("map_Coxiella_burnetii_GCF_003849885") has been submitted
# Your job 5482800 ("map_Coxiella_burnetii_GCF_003849875") has been submitted
# Your job 5482801 ("map_Coxiella_burnetii_GCF_003849785") has been submitted
# Your job 5482802 ("map_Coxiella_burnetii_GCF_000723265") has been submitted
# Your job 5482803 ("map_Coxiella_burnetii_GCF_000300315") has been submitted
# Your job 5482804 ("map_Coxiella_burnetii_GCA_000359545") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482805 ("merge_Coxiella_burnetii_GCF_000017105") has been submitted
# Your job 5482806 ("merge_Coxiella_burnetii_GCF_001572745") has been submitted
# Your job 5482807 ("merge_Coxiella_burnetii_GCF_004006195") has been submitted
# Your job 5482808 ("merge_Coxiella_burnetii_GCF_000019885") has been submitted
# Your job 5482809 ("merge_Coxiella_burnetii_GCF_000168875") has been submitted
# Your job 5482810 ("merge_Coxiella_burnetii_GCF_000018745") has been submitted
# Your job 5482811 ("merge_Coxiella_burnetii_GCF_000019865") has been submitted
# Your job 5482812 ("merge_Coxiella_burnetii_GCF_000367725") has been submitted
# Your job 5482813 ("merge_Coxiella_burnetii_GCF_004087735") has been submitted
# Your job 5482814 ("merge_Coxiella_burnetii_GCF_002109345") has been submitted
# Your job 5482815 ("merge_Coxiella_burnetii_GCF_002094935") has been submitted
# Your job 5482816 ("merge_Coxiella_burnetii_GCF_005280755") has been submitted
# Your job 5482817 ("merge_Coxiella_burnetii_GCF_002634005") has been submitted
# Your job 5482818 ("merge_Coxiella_burnetii_GCF_002633985") has been submitted
# Your job 5482819 ("merge_Coxiella_burnetii_GCF_002633965") has been submitted
# Your job 5482820 ("merge_Coxiella_burnetii_GCF_002633945") has been submitted
# Your job 5482821 ("merge_Coxiella_burnetii_GCF_002633885") has been submitted
# Your job 5482822 ("merge_Coxiella_burnetii_GCF_002634025") has been submitted
# Your job 5482823 ("merge_Coxiella_burnetii_GCF_002634045") has been submitted
# Your job 5482824 ("merge_Coxiella_burnetii_GCF_000767035") has been submitted
# Your job 5482825 ("merge_Coxiella_burnetii_GCF_002634065") has been submitted
# Your job 5482826 ("merge_Coxiella_burnetii_GCF_002633925") has been submitted
# Your job 5482827 ("merge_Coxiella_burnetii_GCF_002633905") has been submitted
# Your job 5482828 ("merge_Coxiella_burnetii_GCF_001572765") has been submitted
# Your job 5482829 ("merge_Coxiella_burnetii_GCF_002634085") has been submitted
# Your job 5482830 ("merge_Coxiella_burnetii_GCF_000612785") has been submitted
# Your job 5482831 ("merge_Coxiella_burnetii_GCF_000826165") has been submitted
# Your job 5482832 ("merge_Coxiella_burnetii_GCF_000820465") has been submitted
# Your job 5482833 ("merge_Coxiella_burnetii_GCF_000967075") has been submitted
# Your job 5482834 ("merge_Coxiella_burnetii_GCF_000470495") has been submitted
# Your job 5482835 ("merge_Coxiella_burnetii_GCF_002247545") has been submitted
# Your job 5482836 ("merge_Coxiella_burnetii_GCF_002247155") has been submitted
# Your job 5482837 ("merge_Coxiella_burnetii_GCF_002896835") has been submitted
# Your job 5482838 ("merge_Coxiella_burnetii_GCF_000613025") has been submitted
# Your job 5482839 ("merge_Coxiella_burnetii_GCF_000723305") has been submitted
# Your job 5482840 ("merge_Coxiella_burnetii_GCF_002924395") has been submitted
# Your job 5482841 ("merge_Coxiella_burnetii_GCF_002247185") has been submitted
# Your job 5482842 ("merge_Coxiella_burnetii_GCF_002896735") has been submitted
# Your job 5482843 ("merge_Coxiella_burnetii_GCF_002896755") has been submitted
# Your job 5482844 ("merge_Coxiella_burnetii_GCF_002896775") has been submitted
# Your job 5482845 ("merge_Coxiella_burnetii_GCF_002247265") has been submitted
# Your job 5482846 ("merge_Coxiella_burnetii_GCF_002247205") has been submitted
# Your job 5482847 ("merge_Coxiella_burnetii_GCF_002924305") has been submitted
# Your job 5482848 ("merge_Coxiella_burnetii_GCF_002924345") has been submitted
# Your job 5482849 ("merge_Coxiella_burnetii_GCF_002924425") has been submitted
# Your job 5482850 ("merge_Coxiella_burnetii_GCF_000723245") has been submitted
# Your job 5482851 ("merge_Coxiella_burnetii_GCF_002247285") has been submitted
# Your job 5482852 ("merge_Coxiella_burnetii_GCF_002247305") has been submitted
# Your job 5482853 ("merge_Coxiella_burnetii_GCF_002247335") has been submitted
# Your job 5482854 ("merge_Coxiella_burnetii_GCF_002249845") has been submitted
# Your job 5482855 ("merge_Coxiella_burnetii_GCF_002924325") has been submitted
# Your job 5482856 ("merge_Coxiella_burnetii_GCF_003849965") has been submitted
# Your job 5482857 ("merge_Coxiella_burnetii_GCF_002247225") has been submitted
# Your job 5482858 ("merge_Coxiella_burnetii_GCF_002896795") has been submitted
# Your job 5482859 ("merge_Coxiella_burnetii_GCF_002924385") has been submitted
# Your job 5482860 ("merge_Coxiella_burnetii_GCF_000751935") has been submitted
# Your job 5482861 ("merge_Coxiella_burnetii_GCF_000820825") has been submitted
# Your job 5482862 ("merge_Coxiella_burnetii_GCF_000756325") has been submitted
# Your job 5482863 ("merge_Coxiella_burnetii_GCF_002591355") has been submitted
# Your job 5482864 ("merge_Coxiella_burnetii_GCF_000169495") has been submitted
# Your job 5482865 ("merge_Coxiella_burnetii_GCF_000723285") has been submitted
# Your job 5482866 ("merge_Coxiella_burnetii_GCF_002896815") has been submitted
# Your job 5482867 ("merge_Coxiella_burnetii_GCF_003849885") has been submitted
# Your job 5482868 ("merge_Coxiella_burnetii_GCF_003849875") has been submitted
# Your job 5482869 ("merge_Coxiella_burnetii_GCF_003849785") has been submitted
# Your job 5482870 ("merge_Coxiella_burnetii_GCF_000723265") has been submitted
# Your job 5482871 ("merge_Coxiella_burnetii_GCF_000300315") has been submitted
# Your job 5482872 ("merge_Coxiella_burnetii_GCA_000359545") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 109 sequences from Coxiella_burnetii_GCF_000017105_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 107.
# Screened 130 sequences from Coxiella_burnetii_GCF_001572745_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 126.
# Screened 140 sequences from Coxiella_burnetii_GCF_004006195_merged.bed.  Filtered 5 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 135.
# Screened 142 sequences from Coxiella_burnetii_GCF_000019885_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 134.
# Screened 130 sequences from Coxiella_burnetii_GCF_000168875_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 122.
# Screened 102 sequences from Coxiella_burnetii_GCF_000018745_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 96.
# Screened 122 sequences from Coxiella_burnetii_GCF_000019865_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 118.
# Screened 124 sequences from Coxiella_burnetii_GCF_000367725_merged.bed.  Filtered 13 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 111.
# Screened 50 sequences from Coxiella_burnetii_GCF_004087735_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 49.
# Screened 52 sequences from Coxiella_burnetii_GCF_002109345_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 52.
# Screened 48 sequences from Coxiella_burnetii_GCF_002094935_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 48.
# Screened 57 sequences from Coxiella_burnetii_GCF_005280755_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 56.
# Screened 84 sequences from Coxiella_burnetii_GCF_002634005_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 82.
# Screened 80 sequences from Coxiella_burnetii_GCF_002633985_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 79.
# Screened 85 sequences from Coxiella_burnetii_GCF_002633965_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 84.
# Screened 88 sequences from Coxiella_burnetii_GCF_002633945_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 87.
# Screened 126 sequences from Coxiella_burnetii_GCF_002633885_merged.bed.  Filtered 5 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 121.
# Screened 232 sequences from Coxiella_burnetii_GCF_002634025_merged.bed.  Filtered 10 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 222.
# Screened 214 sequences from Coxiella_burnetii_GCF_002634045_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 208.
# Screened 158 sequences from Coxiella_burnetii_GCF_000767035_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 150.
# Screened 145 sequences from Coxiella_burnetii_GCF_002634065_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 139.
# Screened 248 sequences from Coxiella_burnetii_GCF_002633925_merged.bed.  Filtered 5 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 243.
# Screened 135 sequences from Coxiella_burnetii_GCF_002633905_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 131.
# Screened 271 sequences from Coxiella_burnetii_GCF_001572765_merged.bed.  Filtered 10 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 261.
# Screened 201 sequences from Coxiella_burnetii_GCF_002634085_merged.bed.  Filtered 17 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 184.
# Screened 102 sequences from Coxiella_burnetii_GCF_000612785_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 100.
# Screened 147 sequences from Coxiella_burnetii_GCF_000826165_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 135.
# Screened 122 sequences from Coxiella_burnetii_GCF_000820465_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 114.
# Screened 135 sequences from Coxiella_burnetii_GCF_000967075_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 129.
# Screened 89 sequences from Coxiella_burnetii_GCF_000470495_merged.bed.  Filtered 3 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 86.
# Screened 110 sequences from Coxiella_burnetii_GCF_002247545_merged.bed.  Filtered 10 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 100.
# Screened 117 sequences from Coxiella_burnetii_GCF_002247155_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 113.
# Screened 84 sequences from Coxiella_burnetii_GCF_002896835_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 80.
# Screened 89 sequences from Coxiella_burnetii_GCF_000613025_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 87.
# Screened 95 sequences from Coxiella_burnetii_GCF_000723305_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 89.
# Screened 54 sequences from Coxiella_burnetii_GCF_002924395_merged.bed.  Filtered 3 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 51.
# Screened 79 sequences from Coxiella_burnetii_GCF_002247185_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 77.
# Screened 84 sequences from Coxiella_burnetii_GCF_002896735_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 80.
# Screened 87 sequences from Coxiella_burnetii_GCF_002896755_merged.bed.  Filtered 3 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 84.
# Screened 87 sequences from Coxiella_burnetii_GCF_002896775_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 86.
# Screened 50 sequences from Coxiella_burnetii_GCF_002247265_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 49.
# Screened 46 sequences from Coxiella_burnetii_GCF_002247205_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 46.
# Screened 41 sequences from Coxiella_burnetii_GCF_002924305_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 41.
# Screened 39 sequences from Coxiella_burnetii_GCF_002924345_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 39.
# Screened 44 sequences from Coxiella_burnetii_GCF_002924425_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 43.
# Screened 88 sequences from Coxiella_burnetii_GCF_000723245_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 87.
# Screened 47 sequences from Coxiella_burnetii_GCF_002247285_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 47.
# Screened 46 sequences from Coxiella_burnetii_GCF_002247305_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 45.
# Screened 49 sequences from Coxiella_burnetii_GCF_002247335_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 49.
# Screened 47 sequences from Coxiella_burnetii_GCF_002249845_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 47.
# Screened 47 sequences from Coxiella_burnetii_GCF_002924325_merged.bed.  Filtered 0 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 47.
# Screened 91 sequences from Coxiella_burnetii_GCF_003849965_merged.bed.  Filtered 2 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 89.
# Screened 125 sequences from Coxiella_burnetii_GCF_002247225_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 119.
# Screened 112 sequences from Coxiella_burnetii_GCF_002896795_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 108.
# Screened 98 sequences from Coxiella_burnetii_GCF_002924385_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 94.
# Screened 153 sequences from Coxiella_burnetii_GCF_000751935_merged.bed.  Filtered 5 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 148.
# Screened 152 sequences from Coxiella_burnetii_GCF_000820825_merged.bed.  Filtered 5 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 147.
# Screened 140 sequences from Coxiella_burnetii_GCF_000756325_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 132.
# Screened 137 sequences from Coxiella_burnetii_GCF_002591355_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 133.
# Screened 214 sequences from Coxiella_burnetii_GCF_000169495_merged.bed.  Filtered 16 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 198.
# Screened 130 sequences from Coxiella_burnetii_GCF_000723285_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 124.
# Screened 131 sequences from Coxiella_burnetii_GCF_002896815_merged.bed.  Filtered 3 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 128.
# Screened 150 sequences from Coxiella_burnetii_GCF_003849885_merged.bed.  Filtered 7 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 143.
# Screened 155 sequences from Coxiella_burnetii_GCF_003849875_merged.bed.  Filtered 6 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 149.
# Screened 154 sequences from Coxiella_burnetii_GCF_003849785_merged.bed.  Filtered 4 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 150.
# Screened 159 sequences from Coxiella_burnetii_GCF_000723265_merged.bed.  Filtered 8 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 151.
# Screened 311 sequences from Coxiella_burnetii_GCF_000300315_merged.bed.  Filtered 11 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 300.
# Screened 65 sequences from Coxiella_burnetii_GCA_000359545_merged.bed.  Filtered 1 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 64.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCA_000359545_merged.bed --twobit results/phyluce/coxiella/cleaned_genomes/Coxiella_burnetii_GCF_000007765_formatted.2bit --output results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCA_000359545_stripped.bed;
# coxiella_burnetii_gcf_000017105.
# coxiella_burnetii_gcf_001572745.
# coxiella_burnetii_gcf_004006195.
# coxiella_burnetii_gcf_000019885.
# coxiella_burnetii_gcf_000168875.
# coxiella_burnetii_gcf_000018745.
# coxiella_burnetii_gcf_000019865.
# coxiella_burnetii_gcf_000367725.
# coxiella_burnetii_gcf_004087735.
# coxiella_burnetii_gcf_002109345.
# coxiella_burnetii_gcf_002094935.
# coxiella_burnetii_gcf_005280755.
# coxiella_burnetii_gcf_002634005.
# coxiella_burnetii_gcf_002633985.
# coxiella_burnetii_gcf_002633965.
# coxiella_burnetii_gcf_002633945.
# coxiella_burnetii_gcf_002633885.
# coxiella_burnetii_gcf_002634025.
# coxiella_burnetii_gcf_002634045.
# coxiella_burnetii_gcf_000767035.
# coxiella_burnetii_gcf_002634065.
# coxiella_burnetii_gcf_002633925.
# coxiella_burnetii_gcf_002633905.
# coxiella_burnetii_gcf_001572765.
# coxiella_burnetii_gcf_002634085.
# coxiella_burnetii_gcf_000612785.
# coxiella_burnetii_gcf_000826165.
# coxiella_burnetii_gcf_000820465.
# coxiella_burnetii_gcf_000967075.
# coxiella_burnetii_gcf_000470495.
# coxiella_burnetii_gcf_002247545.
# coxiella_burnetii_gcf_002247155.
# coxiella_burnetii_gcf_002896835.
# coxiella_burnetii_gcf_000613025.
# coxiella_burnetii_gcf_000723305.
# coxiella_burnetii_gcf_002924395.
# coxiella_burnetii_gcf_002247185.
# coxiella_burnetii_gcf_002896735.
# coxiella_burnetii_gcf_002896755.
# coxiella_burnetii_gcf_002896775.
# coxiella_burnetii_gcf_002247265.
# coxiella_burnetii_gcf_002247205.
# coxiella_burnetii_gcf_002924305.
# coxiella_burnetii_gcf_002924345.
# coxiella_burnetii_gcf_002924425.
# coxiella_burnetii_gcf_000723245.
# coxiella_burnetii_gcf_002247285.
# coxiella_burnetii_gcf_002247305.
# coxiella_burnetii_gcf_002247335.
# coxiella_burnetii_gcf_002249845.
# coxiella_burnetii_gcf_002924325.
# coxiella_burnetii_gcf_003849965.
# coxiella_burnetii_gcf_002247225.
# coxiella_burnetii_gcf_002896795.
# coxiella_burnetii_gcf_002924385.
# coxiella_burnetii_gcf_000751935.
# coxiella_burnetii_gcf_000820825.
# coxiella_burnetii_gcf_000756325.
# coxiella_burnetii_gcf_002591355.
# coxiella_burnetii_gcf_000169495.
# coxiella_burnetii_gcf_000723285.
# coxiella_burnetii_gcf_002896815.
# coxiella_burnetii_gcf_003849885.
# coxiella_burnetii_gcf_003849875.
# coxiella_burnetii_gcf_003849785.
# coxiella_burnetii_gcf_000723265.
# coxiella_burnetii_gcf_000300315.
# coxiella_burnetii_gca_000359545.
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCA_000359545_merged.bed --twobit results/phyluce/coxiella/cleaned_genomes/Coxiella_burnetii_GCF_000007765_formatted.2bit --output results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCA_000359545_stripped.bed;
# Loci shared by Coxiella_burnetii_GCF_000007765 + 0 taxa:	114.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 1 taxa:	114.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 2 taxa:	113.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 3 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 4 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 5 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 6 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 7 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 8 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 9 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 10 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 11 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 12 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 13 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 14 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 15 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 16 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 17 taxa:	111.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 18 taxa:	110.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 19 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 20 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 21 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 22 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 23 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 24 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 25 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 26 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 27 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 28 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 29 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 30 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 31 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 32 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 33 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 34 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 35 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 36 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 37 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 38 taxa:	109.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 39 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 40 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 41 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 42 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 43 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 44 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 45 taxa:	108.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 46 taxa:	107.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 47 taxa:	107.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 48 taxa:	107.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 49 taxa:	107.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 50 taxa:	107.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 51 taxa:	106.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 52 taxa:	104.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 53 taxa:	104.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 54 taxa:	104.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 55 taxa:	104.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 56 taxa:	103.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 57 taxa:	103.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 58 taxa:	99.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 59 taxa:	99.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 60 taxa:	99.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 61 taxa:	98.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 62 taxa:	98.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 63 taxa:	96.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 64 taxa:	95.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 65 taxa:	94.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 66 taxa:	94.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 67 taxa:	91.0
# Loci shared by Coxiella_burnetii_GCF_000007765 + 68 taxa:	91.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 68
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/coxiella/initial_intervals/coxiella-to-Coxiella_burnetii_GCF_000007765.sqlite --base-taxon Coxiella_burnetii_GCF_000007765 --output results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCF_000007765_+68.bed --specific-counts 68;
# Counter({'coxiella_burnetii_gcf_005280755': 91, 'coxiella_burnetii_gcf_000169495': 91, 'coxiella_burnetii_gcf_001572765': 91, 'coxiella_burnetii_gcf_002094935': 91, 'coxiella_burnetii_gcf_003849885': 91, 'coxiella_burnetii_gcf_000470495': 91, 'coxiella_burnetii_gcf_002247185': 91, 'coxiella_burnetii_gcf_002924395': 91, 'coxiella_burnetii_gcf_004087735': 91, 'coxiella_burnetii_gcf_002247155': 91, 'coxiella_burnetii_gcf_000723265': 91, 'coxiella_burnetii_gcf_001572745': 91, 'coxiella_burnetii_gcf_002247285': 91, 'coxiella_burnetii_gcf_002924385': 91, 'coxiella_burnetii_gcf_000300315': 91, 'coxiella_burnetii_gcf_002633925': 91, 'coxiella_burnetii_gcf_000767035': 91, 'coxiella_burnetii_gcf_002896835': 91, 'coxiella_burnetii_gca_000359545': 91, 'coxiella_burnetii_gcf_000756325': 91, 'coxiella_burnetii_gcf_002634085': 91, 'coxiella_burnetii_gcf_000019865': 91, 'coxiella_burnetii_gcf_002249845': 91, 'coxiella_burnetii_gcf_002247205': 91, 'coxiella_burnetii_gcf_002633885': 91, 'coxiella_burnetii_gcf_002247265': 91, 'coxiella_burnetii_gcf_002896775': 91, 'coxiella_burnetii_gcf_000168875': 91, 'coxiella_burnetii_gcf_002247225': 91, 'coxiella_burnetii_gcf_002247305': 91, 'coxiella_burnetii_gcf_002634045': 91, 'coxiella_burnetii_gcf_000613025': 91, 'coxiella_burnetii_gcf_002896755': 91, 'coxiella_burnetii_gcf_000826165': 91, 'coxiella_burnetii_gcf_000723305': 91, 'coxiella_burnetii_gcf_000751935': 91, 'coxiella_burnetii_gcf_002634065': 91, 'coxiella_burnetii_gcf_000967075': 91, 'coxiella_burnetii_gcf_002633945': 91, 'coxiella_burnetii_gcf_002896735': 91, 'coxiella_burnetii_gcf_003849875': 91, 'coxiella_burnetii_gcf_004006195': 91, 'coxiella_burnetii_gcf_002924425': 91, 'coxiella_burnetii_gcf_000018745': 91, 'coxiella_burnetii_gcf_002633985': 91, 'coxiella_burnetii_gcf_002896815': 91, 'coxiella_burnetii_gcf_002634025': 91, 'coxiella_burnetii_gcf_002247545': 91, 'coxiella_burnetii_gcf_002896795': 91, 'coxiella_burnetii_gcf_000019885': 91, 'coxiella_burnetii_gcf_000820465': 91, 'coxiella_burnetii_gcf_002109345': 91, 'coxiella_burnetii_gcf_003849965': 91, 'coxiella_burnetii_gcf_000723285': 91, 'coxiella_burnetii_gcf_002924325': 91, 'coxiella_burnetii_gcf_002633905': 91, 'coxiella_burnetii_gcf_002924305': 91, 'coxiella_burnetii_gcf_000723245': 91, 'coxiella_burnetii_gcf_002633965': 91, 'coxiella_burnetii_gcf_002924345': 91, 'coxiella_burnetii_gcf_002247335': 91, 'coxiella_burnetii_gcf_002634005': 91, 'coxiella_burnetii_gcf_000612785': 91, 'coxiella_burnetii_gcf_000367725': 91, 'coxiella_burnetii_gcf_002591355': 91, 'coxiella_burnetii_gcf_000820825': 91, 'coxiella_burnetii_gcf_000017105': 91, 'coxiella_burnetii_gcf_003849785': 91})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/coxiella/initial_intervals/Coxiella_burnetii_GCF_000007765_+68.bed --twobit results/phyluce/coxiella/cleaned_genomes/Coxiella_burnetii_GCF_000007765_formatted.2bit --buffer-to 160 --output results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68.fasta;
# Screened 91 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 91.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68.fasta --probe-prefix uce_coxiella_ --design coxiella_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGGGGG
#
#
# Conserved locus count = 89
# Probe Count = 175

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas --query results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  09:44:05
# Ended:  Fri Feb 07, 2020  09:44:06
# Time for execution:  0.0123950004578 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas                        --lastz results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes_vself.lastz                       --probe-prefix=uce_coxiella_;
# Parsing lastz file...
# Screening results...
# Screened 174 fasta sequences.  Filtered 0 duplicates. Kept 175.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/coxiella/validate_intervals/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas --scaffoldlist Coxiella_burnetii_GCF_000017105 Coxiella_burnetii_GCF_001572745 Coxiella_burnetii_GCF_004006195 Coxiella_burnetii_GCF_000019885 Coxiella_burnetii_GCF_000168875 Coxiella_burnetii_GCF_000018745 Coxiella_burnetii_GCF_000019865 Coxiella_burnetii_GCF_000367725 Coxiella_burnetii_GCF_004087735 Coxiella_burnetii_GCF_002109345 Coxiella_burnetii_GCF_002094935 Coxiella_burnetii_GCF_005280755 Coxiella_burnetii_GCF_002634005 Coxiella_burnetii_GCF_002633985 Coxiella_burnetii_GCF_002633965 Coxiella_burnetii_GCF_002633945 Coxiella_burnetii_GCF_002633885 Coxiella_burnetii_GCF_002634025 Coxiella_burnetii_GCF_002634045 Coxiella_burnetii_GCF_000767035 Coxiella_burnetii_GCF_002634065 Coxiella_burnetii_GCF_002633925 Coxiella_burnetii_GCF_002633905 Coxiella_burnetii_GCF_001572765 Coxiella_burnetii_GCF_002634085 Coxiella_burnetii_GCF_000612785 Coxiella_burnetii_GCF_000826165 Coxiella_burnetii_GCF_000820465 Coxiella_burnetii_GCF_000967075 Coxiella_burnetii_GCF_000470495 Coxiella_burnetii_GCF_002247545 Coxiella_burnetii_GCF_002247155 Coxiella_burnetii_GCF_002896835 Coxiella_burnetii_GCF_000613025 Coxiella_burnetii_GCF_000723305 Coxiella_burnetii_GCF_002924395 Coxiella_burnetii_GCF_002247185 Coxiella_burnetii_GCF_002896735 Coxiella_burnetii_GCF_002896755 Coxiella_burnetii_GCF_002896775 Coxiella_burnetii_GCF_002247265 Coxiella_burnetii_GCF_002247205 Coxiella_burnetii_GCF_002924305 Coxiella_burnetii_GCF_002924345 Coxiella_burnetii_GCF_002924425 Coxiella_burnetii_GCF_000723245 Coxiella_burnetii_GCF_002247285 Coxiella_burnetii_GCF_002247305 Coxiella_burnetii_GCF_002247335 Coxiella_burnetii_GCF_002249845 Coxiella_burnetii_GCF_002924325 Coxiella_burnetii_GCF_003849965 Coxiella_burnetii_GCF_002247225 Coxiella_burnetii_GCF_002896795 Coxiella_burnetii_GCF_002924385 Coxiella_burnetii_GCF_000751935 Coxiella_burnetii_GCF_000820825 Coxiella_burnetii_GCF_000756325 Coxiella_burnetii_GCF_002591355 Coxiella_burnetii_GCF_000169495 Coxiella_burnetii_GCF_000723285 Coxiella_burnetii_GCF_002896815 Coxiella_burnetii_GCF_003849885 Coxiella_burnetii_GCF_003849875 Coxiella_burnetii_GCF_003849785 Coxiella_burnetii_GCF_000723265 Coxiella_burnetii_GCF_000300315 Coxiella_burnetii_GCA_000359545 Coxiella_burnetii_GCF_000007765 --genome-base-path results/phyluce/coxiella/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/coxiella/validate_intervals/coxiella-to-Coxiella_burnetii_GCF_000007765.sqlite --output results/phyluce/coxiella/validate_intervals/lastz/;
#
# Running against Coxiella_burnetii_GCF_000017105.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmO18Oj.fasta
#
# Writing the results file...
# 	/tmp/tmp2jTAou.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000017105.lastz
# Creating Coxiella_burnetii_GCF_000017105 table
# Inserting data to Coxiella_burnetii_GCF_000017105 table
#
# Running against Coxiella_burnetii_GCF_001572745.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpCjo6yS.fasta
#
# Writing the results file...
# 	/tmp/tmp9nubon.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_001572745.lastz
# Creating Coxiella_burnetii_GCF_001572745 table
# Inserting data to Coxiella_burnetii_GCF_001572745 table
#
# Running against Coxiella_burnetii_GCF_004006195.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpUfsLAn.fasta
#
# Writing the results file...
# 	/tmp/tmpRDCyPD.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_004006195.lastz
# Creating Coxiella_burnetii_GCF_004006195 table
# Inserting data to Coxiella_burnetii_GCF_004006195 table
#
# Running against Coxiella_burnetii_GCF_000019885.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpvUgpBa.fasta
#
# Writing the results file...
# 	/tmp/tmpbKNrfc.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000019885.lastz
# Creating Coxiella_burnetii_GCF_000019885 table
# Inserting data to Coxiella_burnetii_GCF_000019885 table
#
# Running against Coxiella_burnetii_GCF_000168875.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxJQVJS.fasta
#
# Writing the results file...
# 	/tmp/tmpSxoj1m.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000168875.lastz
# Creating Coxiella_burnetii_GCF_000168875 table
# Inserting data to Coxiella_burnetii_GCF_000168875 table
#
# Running against Coxiella_burnetii_GCF_000018745.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpfx_Jfu.fasta
#
# Writing the results file...
# 	/tmp/tmp_qWmRn.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000018745.lastz
# Creating Coxiella_burnetii_GCF_000018745 table
# Inserting data to Coxiella_burnetii_GCF_000018745 table
#
# Running against Coxiella_burnetii_GCF_000019865.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmprwpJFv.fasta
#
# Writing the results file...
# 	/tmp/tmpBylozP.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000019865.lastz
# Creating Coxiella_burnetii_GCF_000019865 table
# Inserting data to Coxiella_burnetii_GCF_000019865 table
#
# Running against Coxiella_burnetii_GCF_000367725.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpiNAVRP.fasta
#
# Writing the results file...
# 	/tmp/tmpRNu3sY.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000367725.lastz
# Creating Coxiella_burnetii_GCF_000367725 table
# Inserting data to Coxiella_burnetii_GCF_000367725 table
#
# Running against Coxiella_burnetii_GCF_004087735.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpGSV2ay.fasta
#
# Writing the results file...
# 	/tmp/tmpAVCRT8.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_004087735.lastz
# Creating Coxiella_burnetii_GCF_004087735 table
# Inserting data to Coxiella_burnetii_GCF_004087735 table
#
# Running against Coxiella_burnetii_GCF_002109345.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpBhpASv.fasta
#
# Writing the results file...
# 	/tmp/tmpSAj8W9.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002109345.lastz
# Creating Coxiella_burnetii_GCF_002109345 table
# Inserting data to Coxiella_burnetii_GCF_002109345 table
#
# Running against Coxiella_burnetii_GCF_002094935.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpvgAQid.fasta
#
# Writing the results file...
# 	/tmp/tmpgUZm07.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002094935.lastz
# Creating Coxiella_burnetii_GCF_002094935 table
# Inserting data to Coxiella_burnetii_GCF_002094935 table
#
# Running against Coxiella_burnetii_GCF_005280755.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpvHw9bH.fasta
#
# Writing the results file...
# 	/tmp/tmpuqRDF4.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_005280755.lastz
# Creating Coxiella_burnetii_GCF_005280755 table
# Inserting data to Coxiella_burnetii_GCF_005280755 table
#
# Running against Coxiella_burnetii_GCF_002634005.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpW4HNUJ.fasta
#
# Writing the results file...
# 	/tmp/tmpTJmPOf.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002634005.lastz
# Creating Coxiella_burnetii_GCF_002634005 table
# Inserting data to Coxiella_burnetii_GCF_002634005 table
#
# Running against Coxiella_burnetii_GCF_002633985.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpTq4yWJ.fasta
#
# Writing the results file...
# 	/tmp/tmpxH9a3o.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633985.lastz
# Creating Coxiella_burnetii_GCF_002633985 table
# Inserting data to Coxiella_burnetii_GCF_002633985 table
#
# Running against Coxiella_burnetii_GCF_002633965.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpQum2NT.fasta
#
# Writing the results file...
# 	/tmp/tmpuTM_6X.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633965.lastz
# Creating Coxiella_burnetii_GCF_002633965 table
# Inserting data to Coxiella_burnetii_GCF_002633965 table
#
# Running against Coxiella_burnetii_GCF_002633945.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmptXAqi_.fasta
#
# Writing the results file...
# 	/tmp/tmpGuqYFT.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633945.lastz
# Creating Coxiella_burnetii_GCF_002633945 table
# Inserting data to Coxiella_burnetii_GCF_002633945 table
#
# Running against Coxiella_burnetii_GCF_002633885.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpHNW693.fasta
#
# Writing the results file...
# 	/tmp/tmpBLgA6m.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633885.lastz
# Creating Coxiella_burnetii_GCF_002633885 table
# Inserting data to Coxiella_burnetii_GCF_002633885 table
#
# Running against Coxiella_burnetii_GCF_002634025.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpbFX_6p.fasta
#
# Writing the results file...
# 	/tmp/tmpRKL8d8.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002634025.lastz
# Creating Coxiella_burnetii_GCF_002634025 table
# Inserting data to Coxiella_burnetii_GCF_002634025 table
#
# Running against Coxiella_burnetii_GCF_002634045.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpnym7da.fasta
#
# Writing the results file...
# 	/tmp/tmpJ0Y26U.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002634045.lastz
# Creating Coxiella_burnetii_GCF_002634045 table
# Inserting data to Coxiella_burnetii_GCF_002634045 table
#
# Running against Coxiella_burnetii_GCF_000767035.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp0_lVSM.fasta
#
# Writing the results file...
# 	/tmp/tmpwSt7gI.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000767035.lastz
# Creating Coxiella_burnetii_GCF_000767035 table
# Inserting data to Coxiella_burnetii_GCF_000767035 table
#
# Running against Coxiella_burnetii_GCF_002634065.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpZPbeyH.fasta
#
# Writing the results file...
# 	/tmp/tmpoDkxCG.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002634065.lastz
# Creating Coxiella_burnetii_GCF_002634065 table
# Inserting data to Coxiella_burnetii_GCF_002634065 table
#
# Running against Coxiella_burnetii_GCF_002633925.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpGshZTQ.fasta
#
# Writing the results file...
# 	/tmp/tmph8MJ_p.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633925.lastz
# Creating Coxiella_burnetii_GCF_002633925 table
# Inserting data to Coxiella_burnetii_GCF_002633925 table
#
# Running against Coxiella_burnetii_GCF_002633905.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpRS3vvT.fasta
#
# Writing the results file...
# 	/tmp/tmpXqIuhf.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002633905.lastz
# Creating Coxiella_burnetii_GCF_002633905 table
# Inserting data to Coxiella_burnetii_GCF_002633905 table
#
# Running against Coxiella_burnetii_GCF_001572765.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpCIU3CJ.fasta
#
# Writing the results file...
# 	/tmp/tmpwTf4wt.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_001572765.lastz
# Creating Coxiella_burnetii_GCF_001572765 table
# Inserting data to Coxiella_burnetii_GCF_001572765 table
#
# Running against Coxiella_burnetii_GCF_002634085.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpMDFeE7.fasta
#
# Writing the results file...
# 	/tmp/tmph8YB1M.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002634085.lastz
# Creating Coxiella_burnetii_GCF_002634085 table
# Inserting data to Coxiella_burnetii_GCF_002634085 table
#
# Running against Coxiella_burnetii_GCF_000612785.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpWAaJv6.fasta
#
# Writing the results file...
# 	/tmp/tmpCTHE6q.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000612785.lastz
# Creating Coxiella_burnetii_GCF_000612785 table
# Inserting data to Coxiella_burnetii_GCF_000612785 table
#
# Running against Coxiella_burnetii_GCF_000826165.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpQE1G5J.fasta
#
# Writing the results file...
# 	/tmp/tmp8kxSfw.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000826165.lastz
# Creating Coxiella_burnetii_GCF_000826165 table
# Inserting data to Coxiella_burnetii_GCF_000826165 table
#
# Running against Coxiella_burnetii_GCF_000820465.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp4kz1tP.fasta
#
# Writing the results file...
# 	/tmp/tmpQOGbXx.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000820465.lastz
# Creating Coxiella_burnetii_GCF_000820465 table
# Inserting data to Coxiella_burnetii_GCF_000820465 table
#
# Running against Coxiella_burnetii_GCF_000967075.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpaWBWng.fasta
#
# Writing the results file...
# 	/tmp/tmpWtcPGs.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000967075.lastz
# Creating Coxiella_burnetii_GCF_000967075 table
# Inserting data to Coxiella_burnetii_GCF_000967075 table
#
# Running against Coxiella_burnetii_GCF_000470495.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmplr8aQj.fasta
#
# Writing the results file...
# 	/tmp/tmpc036MK.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000470495.lastz
# Creating Coxiella_burnetii_GCF_000470495 table
# Inserting data to Coxiella_burnetii_GCF_000470495 table
#
# Running against Coxiella_burnetii_GCF_002247545.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpltchkR.fasta
#
# Writing the results file...
# 	/tmp/tmp6LZNSe.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247545.lastz
# Creating Coxiella_burnetii_GCF_002247545 table
# Inserting data to Coxiella_burnetii_GCF_002247545 table
#
# Running against Coxiella_burnetii_GCF_002247155.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpccnmu5.fasta
#
# Writing the results file...
# 	/tmp/tmpQc9MY4.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247155.lastz
# Creating Coxiella_burnetii_GCF_002247155 table
# Inserting data to Coxiella_burnetii_GCF_002247155 table
#
# Running against Coxiella_burnetii_GCF_002896835.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxUO8c1.fasta
#
# Writing the results file...
# 	/tmp/tmpDi0Cok.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896835.lastz
# Creating Coxiella_burnetii_GCF_002896835 table
# Inserting data to Coxiella_burnetii_GCF_002896835 table
#
# Running against Coxiella_burnetii_GCF_000613025.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpSYoEC4.fasta
#
# Writing the results file...
# 	/tmp/tmpHpxxKD.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000613025.lastz
# Creating Coxiella_burnetii_GCF_000613025 table
# Inserting data to Coxiella_burnetii_GCF_000613025 table
#
# Running against Coxiella_burnetii_GCF_000723305.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDfi_SE.fasta
#
# Writing the results file...
# 	/tmp/tmpRh_ql5.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000723305.lastz
# Creating Coxiella_burnetii_GCF_000723305 table
# Inserting data to Coxiella_burnetii_GCF_000723305 table
#
# Running against Coxiella_burnetii_GCF_002924395.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpzyia26.fasta
#
# Writing the results file...
# 	/tmp/tmpiGRkla.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924395.lastz
# Creating Coxiella_burnetii_GCF_002924395 table
# Inserting data to Coxiella_burnetii_GCF_002924395 table
#
# Running against Coxiella_burnetii_GCF_002247185.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJqnTH4.fasta
#
# Writing the results file...
# 	/tmp/tmphDFBYA.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247185.lastz
# Creating Coxiella_burnetii_GCF_002247185 table
# Inserting data to Coxiella_burnetii_GCF_002247185 table
#
# Running against Coxiella_burnetii_GCF_002896735.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpOBjjip.fasta
#
# Writing the results file...
# 	/tmp/tmpJJY3KQ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896735.lastz
# Creating Coxiella_burnetii_GCF_002896735 table
# Inserting data to Coxiella_burnetii_GCF_002896735 table
#
# Running against Coxiella_burnetii_GCF_002896755.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpnYh5zp.fasta
#
# Writing the results file...
# 	/tmp/tmp4sWruG.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896755.lastz
# Creating Coxiella_burnetii_GCF_002896755 table
# Inserting data to Coxiella_burnetii_GCF_002896755 table
#
# Running against Coxiella_burnetii_GCF_002896775.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpLaNFwU.fasta
#
# Writing the results file...
# 	/tmp/tmpllqcTA.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896775.lastz
# Creating Coxiella_burnetii_GCF_002896775 table
# Inserting data to Coxiella_burnetii_GCF_002896775 table
#
# Running against Coxiella_burnetii_GCF_002247265.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxk3WK5.fasta
#
# Writing the results file...
# 	/tmp/tmpOi0BgA.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247265.lastz
# Creating Coxiella_burnetii_GCF_002247265 table
# Inserting data to Coxiella_burnetii_GCF_002247265 table
#
# Running against Coxiella_burnetii_GCF_002247205.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpX_dLCw.fasta
#
# Writing the results file...
# 	/tmp/tmpPPXQEV.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247205.lastz
# Creating Coxiella_burnetii_GCF_002247205 table
# Inserting data to Coxiella_burnetii_GCF_002247205 table
#
# Running against Coxiella_burnetii_GCF_002924305.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJyPF_H.fasta
#
# Writing the results file...
# 	/tmp/tmpCJeEhf.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924305.lastz
# Creating Coxiella_burnetii_GCF_002924305 table
# Inserting data to Coxiella_burnetii_GCF_002924305 table
#
# Running against Coxiella_burnetii_GCF_002924345.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp9lzmt7.fasta
#
# Writing the results file...
# 	/tmp/tmpYcWTnB.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924345.lastz
# Creating Coxiella_burnetii_GCF_002924345 table
# Inserting data to Coxiella_burnetii_GCF_002924345 table
#
# Running against Coxiella_burnetii_GCF_002924425.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpsuI0UR.fasta
#
# Writing the results file...
# 	/tmp/tmp6gNC0W.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924425.lastz
# Creating Coxiella_burnetii_GCF_002924425 table
# Inserting data to Coxiella_burnetii_GCF_002924425 table
#
# Running against Coxiella_burnetii_GCF_000723245.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp22sL95.fasta
#
# Writing the results file...
# 	/tmp/tmpo6Px27.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000723245.lastz
# Creating Coxiella_burnetii_GCF_000723245 table
# Inserting data to Coxiella_burnetii_GCF_000723245 table
#
# Running against Coxiella_burnetii_GCF_002247285.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp0SdyAw.fasta
#
# Writing the results file...
# 	/tmp/tmprW3v03.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247285.lastz
# Creating Coxiella_burnetii_GCF_002247285 table
# Inserting data to Coxiella_burnetii_GCF_002247285 table
#
# Running against Coxiella_burnetii_GCF_002247305.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpdE2NXK.fasta
#
# Writing the results file...
# 	/tmp/tmpfLmY2K.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247305.lastz
# Creating Coxiella_burnetii_GCF_002247305 table
# Inserting data to Coxiella_burnetii_GCF_002247305 table
#
# Running against Coxiella_burnetii_GCF_002247335.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpTHZDxP.fasta
#
# Writing the results file...
# 	/tmp/tmp9RM1_1.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247335.lastz
# Creating Coxiella_burnetii_GCF_002247335 table
# Inserting data to Coxiella_burnetii_GCF_002247335 table
#
# Running against Coxiella_burnetii_GCF_002249845.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpY_TjCM.fasta
#
# Writing the results file...
# 	/tmp/tmpPxQmnN.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002249845.lastz
# Creating Coxiella_burnetii_GCF_002249845 table
# Inserting data to Coxiella_burnetii_GCF_002249845 table
#
# Running against Coxiella_burnetii_GCF_002924325.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmppL_lWe.fasta
#
# Writing the results file...
# 	/tmp/tmpEJsI0o.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924325.lastz
# Creating Coxiella_burnetii_GCF_002924325 table
# Inserting data to Coxiella_burnetii_GCF_002924325 table
#
# Running against Coxiella_burnetii_GCF_003849965.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmplIOhmW.fasta
#
# Writing the results file...
# 	/tmp/tmpo2J6K0.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_003849965.lastz
# Creating Coxiella_burnetii_GCF_003849965 table
# Inserting data to Coxiella_burnetii_GCF_003849965 table
#
# Running against Coxiella_burnetii_GCF_002247225.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp8c2Dk5.fasta
#
# Writing the results file...
# 	/tmp/tmpShjClA.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002247225.lastz
# Creating Coxiella_burnetii_GCF_002247225 table
# Inserting data to Coxiella_burnetii_GCF_002247225 table
#
# Running against Coxiella_burnetii_GCF_002896795.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp513KFW.fasta
#
# Writing the results file...
# 	/tmp/tmp221XZU.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896795.lastz
# Creating Coxiella_burnetii_GCF_002896795 table
# Inserting data to Coxiella_burnetii_GCF_002896795 table
#
# Running against Coxiella_burnetii_GCF_002924385.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpN01JEw.fasta
#
# Writing the results file...
# 	/tmp/tmp2DKW7o.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002924385.lastz
# Creating Coxiella_burnetii_GCF_002924385 table
# Inserting data to Coxiella_burnetii_GCF_002924385 table
#
# Running against Coxiella_burnetii_GCF_000751935.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpILbpUy.fasta
#
# Writing the results file...
# 	/tmp/tmpJhQNPv.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000751935.lastz
# Creating Coxiella_burnetii_GCF_000751935 table
# Inserting data to Coxiella_burnetii_GCF_000751935 table
#
# Running against Coxiella_burnetii_GCF_000820825.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpPlHg7d.fasta
#
# Writing the results file...
# 	/tmp/tmpbd_v7e.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000820825.lastz
# Creating Coxiella_burnetii_GCF_000820825 table
# Inserting data to Coxiella_burnetii_GCF_000820825 table
#
# Running against Coxiella_burnetii_GCF_000756325.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpuoFvU9.fasta
#
# Writing the results file...
# 	/tmp/tmpWWJ_YB.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000756325.lastz
# Creating Coxiella_burnetii_GCF_000756325 table
# Inserting data to Coxiella_burnetii_GCF_000756325 table
#
# Running against Coxiella_burnetii_GCF_002591355.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpX0wCfI.fasta
#
# Writing the results file...
# 	/tmp/tmp7iWgV0.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002591355.lastz
# Creating Coxiella_burnetii_GCF_002591355 table
# Inserting data to Coxiella_burnetii_GCF_002591355 table
#
# Running against Coxiella_burnetii_GCF_000169495.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp647QuI.fasta
#
# Writing the results file...
# 	/tmp/tmp_McHjM.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000169495.lastz
# Creating Coxiella_burnetii_GCF_000169495 table
# Inserting data to Coxiella_burnetii_GCF_000169495 table
#
# Running against Coxiella_burnetii_GCF_000723285.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpns8Jpg.fasta
#
# Writing the results file...
# 	/tmp/tmpMUoPBq.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000723285.lastz
# Creating Coxiella_burnetii_GCF_000723285 table
# Inserting data to Coxiella_burnetii_GCF_000723285 table
#
# Running against Coxiella_burnetii_GCF_002896815.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpwwjdUs.fasta
#
# Writing the results file...
# 	/tmp/tmp6txCav.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_002896815.lastz
# Creating Coxiella_burnetii_GCF_002896815 table
# Inserting data to Coxiella_burnetii_GCF_002896815 table
#
# Running against Coxiella_burnetii_GCF_003849885.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpClK3JU.fasta
#
# Writing the results file...
# 	/tmp/tmpBA5ZqI.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_003849885.lastz
# Creating Coxiella_burnetii_GCF_003849885 table
# Inserting data to Coxiella_burnetii_GCF_003849885 table
#
# Running against Coxiella_burnetii_GCF_003849875.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpapkTZC.fasta
#
# Writing the results file...
# 	/tmp/tmpEWfN8F.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_003849875.lastz
# Creating Coxiella_burnetii_GCF_003849875 table
# Inserting data to Coxiella_burnetii_GCF_003849875 table
#
# Running against Coxiella_burnetii_GCF_003849785.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpricF11.fasta
#
# Writing the results file...
# 	/tmp/tmp2vkK4o.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_003849785.lastz
# Creating Coxiella_burnetii_GCF_003849785 table
# Inserting data to Coxiella_burnetii_GCF_003849785 table
#
# Running against Coxiella_burnetii_GCF_000723265.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpCPj8S4.fasta
#
# Writing the results file...
# 	/tmp/tmpEJRn4Q.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000723265.lastz
# Creating Coxiella_burnetii_GCF_000723265 table
# Inserting data to Coxiella_burnetii_GCF_000723265 table
#
# Running against Coxiella_burnetii_GCF_000300315.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp7YczgE.fasta
#
# Writing the results file...
# 	/tmp/tmpvxrbWM.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000300315.lastz
# Creating Coxiella_burnetii_GCF_000300315 table
# Inserting data to Coxiella_burnetii_GCF_000300315 table
#
# Running against Coxiella_burnetii_GCA_000359545.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpeDZL0U.fasta
#
# Writing the results file...
# 	/tmp/tmptlwiJO.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCA_000359545.lastz
# Creating Coxiella_burnetii_GCA_000359545 table
# Inserting data to Coxiella_burnetii_GCA_000359545 table
#
# Running against Coxiella_burnetii_GCF_000007765.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJ4heKh.fasta
#
# Writing the results file...
# 	/tmp/tmp0vHTJt.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/coxiella/validate_intervals/lastz/Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_Coxiella_burnetii_GCF_000007765.lastz
# Creating Coxiella_burnetii_GCF_000007765 table
# Inserting data to Coxiella_burnetii_GCF_000007765 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/coxiella/extract_probes_from_group/coxiella_genome.conf --lastz results/phyluce/coxiella/validate_intervals/lastz --probes 120 --probe-prefix uce_coxiella_ --name-pattern "Coxiella_burnetii_GCF_000007765_+68_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/coxiella/extract_probes_from_group/probe_fasta;
# 2020-02-07 09:45:58,466 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 09:45:58,473 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000017105 genome -------
# 2020-02-07 09:45:58,474 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000017105 genome
# 2020-02-07 09:45:59,004 - Phyluce - INFO - Coxiella_burnetii_GCF_000017105: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:45:59,005 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_001572745 genome -------
# 2020-02-07 09:45:59,006 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_001572745 genome
# 2020-02-07 09:45:59,303 - Phyluce - INFO - Coxiella_burnetii_GCF_001572745: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:45:59,303 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_004006195 genome -------
# 2020-02-07 09:45:59,304 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_004006195 genome
# 2020-02-07 09:45:59,592 - Phyluce - INFO - Coxiella_burnetii_GCF_004006195: 87 uces, 0 dupes, 87 non-dupes, 1 orient drop, 1 length drop, 85 written
# 2020-02-07 09:45:59,592 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000019885 genome -------
# 2020-02-07 09:45:59,593 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000019885 genome
# 2020-02-07 09:45:59,933 - Phyluce - INFO - Coxiella_burnetii_GCF_000019885: 88 uces, 0 dupes, 88 non-dupes, 1 orient drop, 1 length drop, 86 written
# 2020-02-07 09:45:59,933 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000168875 genome -------
# 2020-02-07 09:45:59,934 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000168875 genome
# 2020-02-07 09:46:00,266 - Phyluce - INFO - Coxiella_burnetii_GCF_000168875: 88 uces, 0 dupes, 88 non-dupes, 1 orient drop, 1 length drop, 86 written
# 2020-02-07 09:46:00,266 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000018745 genome -------
# 2020-02-07 09:46:00,267 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000018745 genome
# 2020-02-07 09:46:00,593 - Phyluce - INFO - Coxiella_burnetii_GCF_000018745: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:00,594 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000019865 genome -------
# 2020-02-07 09:46:00,594 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000019865 genome
# 2020-02-07 09:46:00,927 - Phyluce - INFO - Coxiella_burnetii_GCF_000019865: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:00,927 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000367725 genome -------
# 2020-02-07 09:46:00,928 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000367725 genome
# 2020-02-07 09:46:01,268 - Phyluce - INFO - Coxiella_burnetii_GCF_000367725: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:01,269 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_004087735 genome -------
# 2020-02-07 09:46:01,269 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_004087735 genome
# 2020-02-07 09:46:01,617 - Phyluce - INFO - Coxiella_burnetii_GCF_004087735: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:01,617 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002109345 genome -------
# 2020-02-07 09:46:01,618 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002109345 genome
# 2020-02-07 09:46:01,960 - Phyluce - INFO - Coxiella_burnetii_GCF_002109345: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:01,960 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002094935 genome -------
# 2020-02-07 09:46:01,961 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002094935 genome
# 2020-02-07 09:46:02,306 - Phyluce - INFO - Coxiella_burnetii_GCF_002094935: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:02,306 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_005280755 genome -------
# 2020-02-07 09:46:02,307 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_005280755 genome
# 2020-02-07 09:46:02,650 - Phyluce - INFO - Coxiella_burnetii_GCF_005280755: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:02,650 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002634005 genome -------
# 2020-02-07 09:46:02,651 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002634005 genome
# 2020-02-07 09:46:02,992 - Phyluce - INFO - Coxiella_burnetii_GCF_002634005: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:02,992 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633985 genome -------
# 2020-02-07 09:46:02,996 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633985 genome
# 2020-02-07 09:46:03,395 - Phyluce - INFO - Coxiella_burnetii_GCF_002633985: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:03,396 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633965 genome -------
# 2020-02-07 09:46:03,396 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633965 genome
# 2020-02-07 09:46:03,758 - Phyluce - INFO - Coxiella_burnetii_GCF_002633965: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:03,759 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633945 genome -------
# 2020-02-07 09:46:03,759 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633945 genome
# 2020-02-07 09:46:04,100 - Phyluce - INFO - Coxiella_burnetii_GCF_002633945: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:04,100 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633885 genome -------
# 2020-02-07 09:46:04,101 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633885 genome
# 2020-02-07 09:46:04,442 - Phyluce - INFO - Coxiella_burnetii_GCF_002633885: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:04,442 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002634025 genome -------
# 2020-02-07 09:46:04,443 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002634025 genome
# 2020-02-07 09:46:04,755 - Phyluce - INFO - Coxiella_burnetii_GCF_002634025: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:04,756 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002634045 genome -------
# 2020-02-07 09:46:04,756 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002634045 genome
# 2020-02-07 09:46:05,068 - Phyluce - INFO - Coxiella_burnetii_GCF_002634045: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:05,068 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000767035 genome -------
# 2020-02-07 09:46:05,069 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000767035 genome
# 2020-02-07 09:46:05,392 - Phyluce - INFO - Coxiella_burnetii_GCF_000767035: 89 uces, 0 dupes, 89 non-dupes, 1 orient drop, 1 length drop, 87 written
# 2020-02-07 09:46:05,392 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002634065 genome -------
# 2020-02-07 09:46:05,393 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002634065 genome
# 2020-02-07 09:46:05,737 - Phyluce - INFO - Coxiella_burnetii_GCF_002634065: 88 uces, 0 dupes, 88 non-dupes, 1 orient drop, 1 length drop, 86 written
# 2020-02-07 09:46:05,737 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633925 genome -------
# 2020-02-07 09:46:05,743 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633925 genome
# 2020-02-07 09:46:06,054 - Phyluce - INFO - Coxiella_burnetii_GCF_002633925: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:06,054 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002633905 genome -------
# 2020-02-07 09:46:06,055 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002633905 genome
# 2020-02-07 09:46:06,363 - Phyluce - INFO - Coxiella_burnetii_GCF_002633905: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:06,363 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_001572765 genome -------
# 2020-02-07 09:46:06,364 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_001572765 genome
# 2020-02-07 09:46:06,664 - Phyluce - INFO - Coxiella_burnetii_GCF_001572765: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:06,664 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002634085 genome -------
# 2020-02-07 09:46:06,665 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002634085 genome
# 2020-02-07 09:46:06,962 - Phyluce - INFO - Coxiella_burnetii_GCF_002634085: 87 uces, 0 dupes, 87 non-dupes, 0 orient drop, 1 length drop, 86 written
# 2020-02-07 09:46:06,963 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000612785 genome -------
# 2020-02-07 09:46:06,963 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000612785 genome
# 2020-02-07 09:46:07,312 - Phyluce - INFO - Coxiella_burnetii_GCF_000612785: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:07,312 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000826165 genome -------
# 2020-02-07 09:46:07,313 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000826165 genome
# 2020-02-07 09:46:07,654 - Phyluce - INFO - Coxiella_burnetii_GCF_000826165: 89 uces, 0 dupes, 89 non-dupes, 1 orient drop, 1 length drop, 87 written
# 2020-02-07 09:46:07,654 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000820465 genome -------
# 2020-02-07 09:46:07,667 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000820465 genome
# 2020-02-07 09:46:08,019 - Phyluce - INFO - Coxiella_burnetii_GCF_000820465: 88 uces, 1 dupes, 87 non-dupes, 0 orient drop, 1 length drop, 86 written
# 2020-02-07 09:46:08,019 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000967075 genome -------
# 2020-02-07 09:46:08,020 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000967075 genome
# 2020-02-07 09:46:08,334 - Phyluce - INFO - Coxiella_burnetii_GCF_000967075: 87 uces, 4 dupes, 83 non-dupes, 1 orient drop, 3 length drop, 79 written
# 2020-02-07 09:46:08,334 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000470495 genome -------
# 2020-02-07 09:46:08,340 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000470495 genome
# 2020-02-07 09:46:08,685 - Phyluce - INFO - Coxiella_burnetii_GCF_000470495: 88 uces, 0 dupes, 88 non-dupes, 2 orient drop, 1 length drop, 85 written
# 2020-02-07 09:46:08,686 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247545 genome -------
# 2020-02-07 09:46:08,686 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247545 genome
# 2020-02-07 09:46:09,053 - Phyluce - INFO - Coxiella_burnetii_GCF_002247545: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:09,053 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247155 genome -------
# 2020-02-07 09:46:09,054 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247155 genome
# 2020-02-07 09:46:09,434 - Phyluce - INFO - Coxiella_burnetii_GCF_002247155: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:09,434 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896835 genome -------
# 2020-02-07 09:46:09,435 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896835 genome
# 2020-02-07 09:46:09,778 - Phyluce - INFO - Coxiella_burnetii_GCF_002896835: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:09,778 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000613025 genome -------
# 2020-02-07 09:46:09,779 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000613025 genome
# 2020-02-07 09:46:10,127 - Phyluce - INFO - Coxiella_burnetii_GCF_000613025: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:10,127 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000723305 genome -------
# 2020-02-07 09:46:10,128 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000723305 genome
# 2020-02-07 09:46:10,470 - Phyluce - INFO - Coxiella_burnetii_GCF_000723305: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:10,470 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924395 genome -------
# 2020-02-07 09:46:10,471 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924395 genome
# 2020-02-07 09:46:10,815 - Phyluce - INFO - Coxiella_burnetii_GCF_002924395: 88 uces, 2 dupes, 86 non-dupes, 0 orient drop, 0 length drop, 86 written
# 2020-02-07 09:46:10,815 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247185 genome -------
# 2020-02-07 09:46:10,816 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247185 genome
# 2020-02-07 09:46:11,158 - Phyluce - INFO - Coxiella_burnetii_GCF_002247185: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:11,158 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896735 genome -------
# 2020-02-07 09:46:11,158 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896735 genome
# 2020-02-07 09:46:11,502 - Phyluce - INFO - Coxiella_burnetii_GCF_002896735: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:11,502 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896755 genome -------
# 2020-02-07 09:46:11,503 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896755 genome
# 2020-02-07 09:46:11,846 - Phyluce - INFO - Coxiella_burnetii_GCF_002896755: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:11,846 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896775 genome -------
# 2020-02-07 09:46:11,847 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896775 genome
# 2020-02-07 09:46:12,206 - Phyluce - INFO - Coxiella_burnetii_GCF_002896775: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:12,206 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247265 genome -------
# 2020-02-07 09:46:12,213 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247265 genome
# 2020-02-07 09:46:12,567 - Phyluce - INFO - Coxiella_burnetii_GCF_002247265: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:12,567 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247205 genome -------
# 2020-02-07 09:46:12,568 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247205 genome
# 2020-02-07 09:46:12,927 - Phyluce - INFO - Coxiella_burnetii_GCF_002247205: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:12,928 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924305 genome -------
# 2020-02-07 09:46:12,928 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924305 genome
# 2020-02-07 09:46:13,274 - Phyluce - INFO - Coxiella_burnetii_GCF_002924305: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:13,274 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924345 genome -------
# 2020-02-07 09:46:13,275 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924345 genome
# 2020-02-07 09:46:13,621 - Phyluce - INFO - Coxiella_burnetii_GCF_002924345: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:13,621 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924425 genome -------
# 2020-02-07 09:46:13,627 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924425 genome
# 2020-02-07 09:46:13,980 - Phyluce - INFO - Coxiella_burnetii_GCF_002924425: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:13,980 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000723245 genome -------
# 2020-02-07 09:46:13,981 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000723245 genome
# 2020-02-07 09:46:14,327 - Phyluce - INFO - Coxiella_burnetii_GCF_000723245: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:14,327 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247285 genome -------
# 2020-02-07 09:46:14,328 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247285 genome
# 2020-02-07 09:46:14,683 - Phyluce - INFO - Coxiella_burnetii_GCF_002247285: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:14,683 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247305 genome -------
# 2020-02-07 09:46:14,684 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247305 genome
# 2020-02-07 09:46:15,032 - Phyluce - INFO - Coxiella_burnetii_GCF_002247305: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:15,032 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247335 genome -------
# 2020-02-07 09:46:15,033 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247335 genome
# 2020-02-07 09:46:15,378 - Phyluce - INFO - Coxiella_burnetii_GCF_002247335: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:15,378 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002249845 genome -------
# 2020-02-07 09:46:15,379 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002249845 genome
# 2020-02-07 09:46:15,725 - Phyluce - INFO - Coxiella_burnetii_GCF_002249845: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:15,726 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924325 genome -------
# 2020-02-07 09:46:15,726 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924325 genome
# 2020-02-07 09:46:16,074 - Phyluce - INFO - Coxiella_burnetii_GCF_002924325: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:16,074 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_003849965 genome -------
# 2020-02-07 09:46:16,075 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_003849965 genome
# 2020-02-07 09:46:16,426 - Phyluce - INFO - Coxiella_burnetii_GCF_003849965: 89 uces, 2 dupes, 87 non-dupes, 0 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:16,426 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002247225 genome -------
# 2020-02-07 09:46:16,426 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002247225 genome
# 2020-02-07 09:46:16,761 - Phyluce - INFO - Coxiella_burnetii_GCF_002247225: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:16,761 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896795 genome -------
# 2020-02-07 09:46:16,762 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896795 genome
# 2020-02-07 09:46:17,097 - Phyluce - INFO - Coxiella_burnetii_GCF_002896795: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:17,098 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002924385 genome -------
# 2020-02-07 09:46:17,098 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002924385 genome
# 2020-02-07 09:46:17,419 - Phyluce - INFO - Coxiella_burnetii_GCF_002924385: 88 uces, 2 dupes, 86 non-dupes, 0 orient drop, 0 length drop, 86 written
# 2020-02-07 09:46:17,420 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000751935 genome -------
# 2020-02-07 09:46:17,421 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000751935 genome
# 2020-02-07 09:46:17,761 - Phyluce - INFO - Coxiella_burnetii_GCF_000751935: 87 uces, 0 dupes, 87 non-dupes, 2 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:17,761 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000820825 genome -------
# 2020-02-07 09:46:17,766 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000820825 genome
# 2020-02-07 09:46:18,098 - Phyluce - INFO - Coxiella_burnetii_GCF_000820825: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:18,098 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000756325 genome -------
# 2020-02-07 09:46:18,099 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000756325 genome
# 2020-02-07 09:46:18,419 - Phyluce - INFO - Coxiella_burnetii_GCF_000756325: 88 uces, 2 dupes, 86 non-dupes, 0 orient drop, 0 length drop, 86 written
# 2020-02-07 09:46:18,419 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002591355 genome -------
# 2020-02-07 09:46:18,420 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002591355 genome
# 2020-02-07 09:46:18,750 - Phyluce - INFO - Coxiella_burnetii_GCF_002591355: 88 uces, 2 dupes, 86 non-dupes, 0 orient drop, 0 length drop, 86 written
# 2020-02-07 09:46:18,750 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000169495 genome -------
# 2020-02-07 09:46:18,756 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000169495 genome
# 2020-02-07 09:46:19,058 - Phyluce - INFO - Coxiella_burnetii_GCF_000169495: 84 uces, 3 dupes, 81 non-dupes, 0 orient drop, 0 length drop, 81 written
# 2020-02-07 09:46:19,058 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000723285 genome -------
# 2020-02-07 09:46:19,058 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000723285 genome
# 2020-02-07 09:46:19,347 - Phyluce - INFO - Coxiella_burnetii_GCF_000723285: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:19,347 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_002896815 genome -------
# 2020-02-07 09:46:19,348 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_002896815 genome
# 2020-02-07 09:46:19,638 - Phyluce - INFO - Coxiella_burnetii_GCF_002896815: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:19,638 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_003849885 genome -------
# 2020-02-07 09:46:19,646 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_003849885 genome
# 2020-02-07 09:46:19,945 - Phyluce - INFO - Coxiella_burnetii_GCF_003849885: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:19,945 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_003849875 genome -------
# 2020-02-07 09:46:19,951 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_003849875 genome
# 2020-02-07 09:46:20,264 - Phyluce - INFO - Coxiella_burnetii_GCF_003849875: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:20,264 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_003849785 genome -------
# 2020-02-07 09:46:20,269 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_003849785 genome
# 2020-02-07 09:46:20,563 - Phyluce - INFO - Coxiella_burnetii_GCF_003849785: 87 uces, 2 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:20,563 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000723265 genome -------
# 2020-02-07 09:46:20,564 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000723265 genome
# 2020-02-07 09:46:20,908 - Phyluce - INFO - Coxiella_burnetii_GCF_000723265: 89 uces, 4 dupes, 85 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:20,908 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000300315 genome -------
# 2020-02-07 09:46:20,909 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000300315 genome
# 2020-02-07 09:46:21,190 - Phyluce - INFO - Coxiella_burnetii_GCF_000300315: 87 uces, 1 dupes, 86 non-dupes, 0 orient drop, 0 length drop, 85 written
# 2020-02-07 09:46:21,190 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCA_000359545 genome -------
# 2020-02-07 09:46:21,199 - Phyluce - INFO - Reading Coxiella_burnetii_GCA_000359545 genome
# 2020-02-07 09:46:21,546 - Phyluce - INFO - Coxiella_burnetii_GCA_000359545: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written
# 2020-02-07 09:46:21,547 - Phyluce - INFO - ------- Working on Coxiella_burnetii_GCF_000007765 genome -------
# 2020-02-07 09:46:21,548 - Phyluce - INFO - Reading Coxiella_burnetii_GCF_000007765 genome
# 2020-02-07 09:46:21,890 - Phyluce - INFO - Coxiella_burnetii_GCF_000007765: 89 uces, 0 dupes, 89 non-dupes, 2 orient drop, 0 length drop, 87 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/coxiella/extract_probes_from_group/probe_fasta --output results/phyluce/coxiella/extract_probes_from_group/multifastas.sqlite --base-taxon Coxiella_burnetii_GCF_000007765;
# coxiella_burnetii_gcf_000017105.
# coxiella_burnetii_gcf_001572745.
# coxiella_burnetii_gcf_004006195.
# coxiella_burnetii_gcf_000019885.
# coxiella_burnetii_gcf_000168875.
# coxiella_burnetii_gcf_000018745.
# coxiella_burnetii_gcf_000019865.
# coxiella_burnetii_gcf_000367725.
# coxiella_burnetii_gcf_004087735.
# coxiella_burnetii_gcf_002109345.
# coxiella_burnetii_gcf_002094935.
# coxiella_burnetii_gcf_005280755.
# coxiella_burnetii_gcf_002634005.
# coxiella_burnetii_gcf_002633985.
# coxiella_burnetii_gcf_002633965.
# coxiella_burnetii_gcf_002633945.
# coxiella_burnetii_gcf_002633885.
# coxiella_burnetii_gcf_002634025.
# coxiella_burnetii_gcf_002634045.
# coxiella_burnetii_gcf_000767035.
# coxiella_burnetii_gcf_002634065.
# coxiella_burnetii_gcf_002633925.
# coxiella_burnetii_gcf_002633905.
# coxiella_burnetii_gcf_001572765.
# coxiella_burnetii_gcf_002634085.
# coxiella_burnetii_gcf_000612785.
# coxiella_burnetii_gcf_000826165.
# coxiella_burnetii_gcf_000820465.
# coxiella_burnetii_gcf_000967075.
# coxiella_burnetii_gcf_000470495.
# coxiella_burnetii_gcf_002247545.
# coxiella_burnetii_gcf_002247155.
# coxiella_burnetii_gcf_002896835.
# coxiella_burnetii_gcf_000613025.
# coxiella_burnetii_gcf_000723305.
# coxiella_burnetii_gcf_002924395.
# coxiella_burnetii_gcf_002247185.
# coxiella_burnetii_gcf_002896735.
# coxiella_burnetii_gcf_002896755.
# coxiella_burnetii_gcf_002896775.
# coxiella_burnetii_gcf_002247265.
# coxiella_burnetii_gcf_002247205.
# coxiella_burnetii_gcf_002924305.
# coxiella_burnetii_gcf_002924345.
# coxiella_burnetii_gcf_002924425.
# coxiella_burnetii_gcf_000723245.
# coxiella_burnetii_gcf_002247285.
# coxiella_burnetii_gcf_002247305.
# coxiella_burnetii_gcf_002247335.
# coxiella_burnetii_gcf_002249845.
# coxiella_burnetii_gcf_002924325.
# coxiella_burnetii_gcf_003849965.
# coxiella_burnetii_gcf_002247225.
# coxiella_burnetii_gcf_002896795.
# coxiella_burnetii_gcf_002924385.
# coxiella_burnetii_gcf_000751935.
# coxiella_burnetii_gcf_000820825.
# coxiella_burnetii_gcf_000756325.
# coxiella_burnetii_gcf_002591355.
# coxiella_burnetii_gcf_000169495.
# coxiella_burnetii_gcf_000723285.
# coxiella_burnetii_gcf_002896815.
# coxiella_burnetii_gcf_003849885.
# coxiella_burnetii_gcf_003849875.
# coxiella_burnetii_gcf_003849785.
# coxiella_burnetii_gcf_000723265.
# coxiella_burnetii_gcf_000300315.
# coxiella_burnetii_gca_000359545.
# coxiella_burnetii_gcf_000007765.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/coxiella/extract_probes_from_group/multifastas.sqlite --base-taxon Coxiella_burnetii_GCF_000007765;
# Loci shared by 0 taxa:	88.0
# Loci shared by 1 taxa:	88.0
# Loci shared by 2 taxa:	88.0
# Loci shared by 3 taxa:	88.0
# Loci shared by 4 taxa:	87.0
# Loci shared by 5 taxa:	87.0
# Loci shared by 6 taxa:	87.0
# Loci shared by 7 taxa:	87.0
# Loci shared by 8 taxa:	87.0
# Loci shared by 9 taxa:	87.0
# Loci shared by 10 taxa:	87.0
# Loci shared by 11 taxa:	87.0
# Loci shared by 12 taxa:	87.0
# Loci shared by 13 taxa:	87.0
# Loci shared by 14 taxa:	87.0
# Loci shared by 15 taxa:	87.0
# Loci shared by 16 taxa:	87.0
# Loci shared by 17 taxa:	87.0
# Loci shared by 18 taxa:	87.0
# Loci shared by 19 taxa:	87.0
# Loci shared by 20 taxa:	87.0
# Loci shared by 21 taxa:	87.0
# Loci shared by 22 taxa:	87.0
# Loci shared by 23 taxa:	87.0
# Loci shared by 24 taxa:	87.0
# Loci shared by 25 taxa:	87.0
# Loci shared by 26 taxa:	87.0
# Loci shared by 27 taxa:	87.0
# Loci shared by 28 taxa:	87.0
# Loci shared by 29 taxa:	87.0
# Loci shared by 30 taxa:	87.0
# Loci shared by 31 taxa:	87.0
# Loci shared by 32 taxa:	87.0
# Loci shared by 33 taxa:	87.0
# Loci shared by 34 taxa:	87.0
# Loci shared by 35 taxa:	87.0
# Loci shared by 36 taxa:	87.0
# Loci shared by 37 taxa:	87.0
# Loci shared by 38 taxa:	87.0
# Loci shared by 39 taxa:	87.0
# Loci shared by 40 taxa:	87.0
# Loci shared by 41 taxa:	87.0
# Loci shared by 42 taxa:	87.0
# Loci shared by 43 taxa:	87.0
# Loci shared by 44 taxa:	87.0
# Loci shared by 45 taxa:	87.0
# Loci shared by 46 taxa:	87.0
# Loci shared by 47 taxa:	87.0
# Loci shared by 48 taxa:	87.0
# Loci shared by 49 taxa:	86.0
# Loci shared by 50 taxa:	86.0
# Loci shared by 51 taxa:	86.0
# Loci shared by 52 taxa:	86.0
# Loci shared by 53 taxa:	86.0
# Loci shared by 54 taxa:	86.0
# Loci shared by 55 taxa:	86.0
# Loci shared by 56 taxa:	86.0
# Loci shared by 57 taxa:	85.0
# Loci shared by 58 taxa:	85.0
# Loci shared by 59 taxa:	85.0
# Loci shared by 60 taxa:	85.0
# Loci shared by 61 taxa:	85.0
# Loci shared by 62 taxa:	84.0
# Loci shared by 63 taxa:	84.0
# Loci shared by 64 taxa:	84.0
# Loci shared by 65 taxa:	82.0
# Loci shared by 66 taxa:	82.0
# Loci shared by 67 taxa:	82.0
# Loci shared by 68 taxa:	81.0
# Loci shared by 69 taxa:	65.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(68)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/coxiella/extract_probes_from_group/multifastas.sqlite  --base-taxon Coxiella_burnetii_GCF_000007765 --output results/phyluce/coxiella/extract_probes_from_group/Coxiella_burnetii_GCF_000007765+68-back-to-68.conf --specific-counts 68;
# Counter({'coxiella_burnetii_gcf_005280755': 81, 'coxiella_burnetii_gcf_001572765': 81, 'coxiella_burnetii_gcf_002094935': 81, 'coxiella_burnetii_gcf_003849885': 81, 'coxiella_burnetii_gcf_000470495': 81, 'coxiella_burnetii_gcf_002247185': 81, 'coxiella_burnetii_gcf_004087735': 81, 'coxiella_burnetii_gcf_000007765': 81, 'coxiella_burnetii_gcf_001572745': 81, 'coxiella_burnetii_gcf_002247285': 81, 'coxiella_burnetii_gcf_002924385': 81, 'coxiella_burnetii_gcf_002633925': 81, 'coxiella_burnetii_gcf_002634045': 81, 'coxiella_burnetii_gcf_002896835': 81, 'coxiella_burnetii_gca_000359545': 81, 'coxiella_burnetii_gcf_002634085': 81, 'coxiella_burnetii_gcf_000019865': 81, 'coxiella_burnetii_gcf_002249845': 81, 'coxiella_burnetii_gcf_002247205': 81, 'coxiella_burnetii_gcf_002633885': 81, 'coxiella_burnetii_gcf_002247265': 81, 'coxiella_burnetii_gcf_002634005': 81, 'coxiella_burnetii_gcf_000168875': 81, 'coxiella_burnetii_gcf_002247225': 81, 'coxiella_burnetii_gcf_002247305': 81, 'coxiella_burnetii_gcf_000767035': 81, 'coxiella_burnetii_gcf_000613025': 81, 'coxiella_burnetii_gcf_002896755': 81, 'coxiella_burnetii_gcf_000723305': 81, 'coxiella_burnetii_gcf_000751935': 81, 'coxiella_burnetii_gcf_002633945': 81, 'coxiella_burnetii_gcf_002634065': 81, 'coxiella_burnetii_gcf_002896775': 81, 'coxiella_burnetii_gcf_003849875': 81, 'coxiella_burnetii_gcf_004006195': 81, 'coxiella_burnetii_gcf_002924425': 81, 'coxiella_burnetii_gcf_000018745': 81, 'coxiella_burnetii_gcf_002633985': 81, 'coxiella_burnetii_gcf_002896815': 81, 'coxiella_burnetii_gcf_002634025': 81, 'coxiella_burnetii_gcf_002247545': 81, 'coxiella_burnetii_gcf_000019885': 81, 'coxiella_burnetii_gcf_000820465': 81, 'coxiella_burnetii_gcf_002109345': 81, 'coxiella_burnetii_gcf_003849965': 81, 'coxiella_burnetii_gcf_000723285': 81, 'coxiella_burnetii_gcf_002924325': 81, 'coxiella_burnetii_gcf_002896735': 81, 'coxiella_burnetii_gcf_002924305': 81, 'coxiella_burnetii_gcf_000723245': 81, 'coxiella_burnetii_gcf_002633965': 81, 'coxiella_burnetii_gcf_002924345': 81, 'coxiella_burnetii_gcf_002247335': 81, 'coxiella_burnetii_gcf_002247155': 81, 'coxiella_burnetii_gcf_002633905': 81, 'coxiella_burnetii_gcf_000612785': 81, 'coxiella_burnetii_gcf_000367725': 81, 'coxiella_burnetii_gcf_002591355': 81, 'coxiella_burnetii_gcf_000820825': 81, 'coxiella_burnetii_gcf_000017105': 81, 'coxiella_burnetii_gcf_003849785': 81, 'coxiella_burnetii_gcf_002924395': 80, 'coxiella_burnetii_gcf_000723265': 80, 'coxiella_burnetii_gcf_000300315': 80, 'coxiella_burnetii_gcf_000756325': 80, 'coxiella_burnetii_gcf_000826165': 80, 'coxiella_burnetii_gcf_002896795': 80, 'coxiella_burnetii_gcf_000169495': 76, 'coxiella_burnetii_gcf_000967075': 76})
# Total loci = 81

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/coxiella/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/coxiella/extract_probes_from_group/Coxiella_burnetii_GCF_000007765+68-back-to-68.conf --probe-prefix uce_coxiella_ --designer rnplattii --design coxiella_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.fasta;
# NNNNGGGGGGGGGGGGGGNNGGGGGGGGGGGGGGGGGGGGNNNNNNNNNNNNNNNNNNNNNNNNNNNNNN
#
#
# Conserved locus count = 81
# Probe Count = 11076

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.fasta --query results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  09:47:11
# Ended:  Fri Feb 07, 2020  09:48:29
# Time for execution:  1.3013803641 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.fasta --lastz results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_coxiella_;
# Parsing lastz file...
# Screening results...
# Screened 11075 fasta sequences.  Filtered 0 duplicates. Kept 11076.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.fasta
#          -o
#          results/phyluce/coxiella/final_probe_design/coxiella_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 10:21:16 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 11076
# longest and shortest : 80 and 80
# Total letters: 886080
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 2M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 16M = 33M
# Miscellaneous   : 4M
# Total           : 89M
#
# Table limit with the given memory limit:
# Max number of representatives: 3946150
# Max number of word counting entries: 88827838
#
# # comparing sequences from          0  to       1846
# .---------- new table with       42 representatives
# # comparing sequences from       1846  to       3384
# ......................---------- new table with       38 representatives
# # comparing sequences from       3384  to       4666
# ....................---------- new table with       32 representatives
# # comparing sequences from       4666  to       5734
# .....................---------- new table with       24 representatives
# # comparing sequences from       5734  to       6624
# .....................---------- new table with       18 representatives
# # comparing sequences from       6624  to       7366
# ....................---------- new table with       15 representatives
# # comparing sequences from       7366  to       7984
# ....................---------- new table with       15 representatives
# # comparing sequences from       7984  to       8499
# 99.9%---------- new table with       12 representatives
# # comparing sequences from       8499  to       8928
# 99.8%---------- new table with        9 representatives
# # comparing sequences from       8928  to       9286
# ....................---------- new table with        5 representatives
# # comparing sequences from       9286  to       9584
# ...................---------- new table with        9 representatives
# # comparing sequences from       9584  to       9832
# 100.0%---------- new table with        3 representatives
# # comparing sequences from       9832  to      10039
# ..........    10000  finished        228  clusters
# 100.0%---------- new table with        6 representatives
# # comparing sequences from      10039  to      10211
# 100.0%---------- new table with        3 representatives
# # comparing sequences from      10211  to      11076
# ....................---------- new table with       20 representatives
#
#     11076  finished        251  clusters
#
# Approximated maximum memory consumption: 89M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.37

# %% [markdown]
# # Ehrlichia

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'ehrlichia'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Ehrlichia_chaffeensis_GCF_000013145",
               "Ehrlichia_minasensis_GCF_000825765",
               "Ehrlichia_muris_GCF_000508225",
               "Ehrlichia_ruminantium_GCF_000026005",
               "Ehrlichia_sp_GCF_000632845" ]
                    
reference_taxon = "Ehrlichia_canis_GCF_000012565"


all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000012565.1_ASM1256v1_genomic.fna.gz
#
# sent 42 bytes  received 373614 bytes  149462.40 bytes/sec
# total size is 373414  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000013145.1_ASM1314v1_genomic.fna.gz
#
# sent 42 bytes  received 334513 bytes  223036.67 bytes/sec
# total size is 334321  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000825765.1_Assembly_of_Ehrlichia_mineirensis_genomic.fna.gz
#
# sent 42 bytes  received 410310 bytes  273568.00 bytes/sec
# total size is 410078  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000508225.1_ASM50822v1_genomic.fna.gz
#
# sent 42 bytes  received 335163 bytes  134082.00 bytes/sec
# total size is 334970  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000026005.1_ASM2600v1_genomic.fna.gz
#
# sent 42 bytes  received 425221 bytes  170105.20 bytes/sec
# total size is 425013  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000632845.1_ASM63284v1_genomic.fna.gz
#
# sent 42 bytes  received 326450 bytes  217661.33 bytes/sec
# total size is 326265  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5482997 ("sim_Ehrlichia_chaffeensis_GCF_000013145") has been submitted
# Your job 5482998 ("sim_Ehrlichia_minasensis_GCF_000825765") has been submitted
# Your job 5482999 ("sim_Ehrlichia_muris_GCF_000508225") has been submitted
# Your job 5483000 ("sim_Ehrlichia_ruminantium_GCF_000026005") has been submitted
# Your job 5483001 ("sim_Ehrlichia_sp_GCF_000632845") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/ehrlichia/cleaned_genomes/Ehrlichia_canis_GCF_000012565_formatted.fas path=results/phyluce/ehrlichia/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483002 ("map_Ehrlichia_chaffeensis_GCF_000013145") has been submitted
# Your job 5483003 ("map_Ehrlichia_minasensis_GCF_000825765") has been submitted
# Your job 5483004 ("map_Ehrlichia_muris_GCF_000508225") has been submitted
# Your job 5483005 ("map_Ehrlichia_ruminantium_GCF_000026005") has been submitted
# Your job 5483006 ("map_Ehrlichia_sp_GCF_000632845") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483007 ("merge_Ehrlichia_chaffeensis_GCF_000013145") has been submitted
# Your job 5483008 ("merge_Ehrlichia_minasensis_GCF_000825765") has been submitted
# Your job 5483009 ("merge_Ehrlichia_muris_GCF_000508225") has been submitted
# Your job 5483010 ("merge_Ehrlichia_ruminantium_GCF_000026005") has been submitted
# Your job 5483011 ("merge_Ehrlichia_sp_GCF_000632845") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 1367 sequences from Ehrlichia_chaffeensis_GCF_000013145_merged.bed.  Filtered 697 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 670.
# Screened 1144 sequences from Ehrlichia_minasensis_GCF_000825765_merged.bed.  Filtered 254 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 890.
# Screened 1479 sequences from Ehrlichia_muris_GCF_000508225_merged.bed.  Filtered 813 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 666.
# Screened 480 sequences from Ehrlichia_ruminantium_GCF_000026005_merged.bed.  Filtered 321 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 159.
# Screened 1426 sequences from Ehrlichia_sp_GCF_000632845_merged.bed.  Filtered 777 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 649.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/ehrlichia/initial_intervals/Ehrlichia_sp_GCF_000632845_merged.bed --twobit results/phyluce/ehrlichia/cleaned_genomes/Ehrlichia_canis_GCF_000012565_formatted.2bit --output results/phyluce/ehrlichia/initial_intervals/Ehrlichia_sp_GCF_000632845_stripped.bed;
# ehrlichia_chaffeensis_gcf_000013145.
# ehrlichia_minasensis_gcf_000825765.
# ehrlichia_muris_gcf_000508225.
# ehrlichia_ruminantium_gcf_000026005.
# ehrlichia_sp_gcf_000632845.
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/ehrlichia/initial_intervals/Ehrlichia_sp_GCF_000632845_merged.bed --twobit results/phyluce/ehrlichia/cleaned_genomes/Ehrlichia_canis_GCF_000012565_formatted.2bit --output results/phyluce/ehrlichia/initial_intervals/Ehrlichia_sp_GCF_000632845_stripped.bed;
# Loci shared by Ehrlichia_canis_GCF_000012565 + 0 taxa:	1,397.0
# Loci shared by Ehrlichia_canis_GCF_000012565 + 1 taxa:	1,397.0
# Loci shared by Ehrlichia_canis_GCF_000012565 + 2 taxa:	830.0
# Loci shared by Ehrlichia_canis_GCF_000012565 + 3 taxa:	568.0
# Loci shared by Ehrlichia_canis_GCF_000012565 + 4 taxa:	426.0
# Loci shared by Ehrlichia_canis_GCF_000012565 + 5 taxa:	122.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 4
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/ehrlichia/initial_intervals/ehrlichia-to-Ehrlichia_canis_GCF_000012565.sqlite --base-taxon Ehrlichia_canis_GCF_000012565 --output results/phyluce/ehrlichia/initial_intervals/Ehrlichia_canis_GCF_000012565_+4.bed --specific-counts 4;
# Counter({'ehrlichia_minasensis_gcf_000825765': 426, 'ehrlichia_chaffeensis_gcf_000013145': 425, 'ehrlichia_sp_gcf_000632845': 423, 'ehrlichia_muris_gcf_000508225': 418, 'ehrlichia_ruminantium_gcf_000026005': 134})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/ehrlichia/initial_intervals/Ehrlichia_canis_GCF_000012565_+4.bed --twobit results/phyluce/ehrlichia/cleaned_genomes/Ehrlichia_canis_GCF_000012565_formatted.2bit --buffer-to 160 --output results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4.fasta;
# Screened 426 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 426.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4.fasta --probe-prefix uce_ehrlichia_ --design ehrlichia_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 345
# Probe Count = 611

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas --query results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  10:28:15
# Ended:  Fri Feb 07, 2020  10:28:15
# Time for execution:  0.00455739895503 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas                        --lastz results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes_vself.lastz                       --probe-prefix=uce_ehrlichia_;
# Parsing lastz file...
# Screening results...
# Screened 610 fasta sequences.  Filtered 2 duplicates. Kept 607.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/ehrlichia/validate_intervals/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas --scaffoldlist Ehrlichia_chaffeensis_GCF_000013145 Ehrlichia_minasensis_GCF_000825765 Ehrlichia_muris_GCF_000508225 Ehrlichia_ruminantium_GCF_000026005 Ehrlichia_sp_GCF_000632845 Ehrlichia_canis_GCF_000012565 --genome-base-path results/phyluce/ehrlichia/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/ehrlichia/validate_intervals/ehrlichia-to-Ehrlichia_canis_GCF_000012565.sqlite --output results/phyluce/ehrlichia/validate_intervals/lastz/;
#
# Running against Ehrlichia_chaffeensis_GCF_000013145.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp3B_2hh.fasta
#
# Writing the results file...
# 	/tmp/tmpaLFPwf.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_chaffeensis_GCF_000013145.lastz
# Creating Ehrlichia_chaffeensis_GCF_000013145 table
# Inserting data to Ehrlichia_chaffeensis_GCF_000013145 table
#
# Running against Ehrlichia_minasensis_GCF_000825765.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp9zQI4U.fasta
#
# Writing the results file...
# 	/tmp/tmpgmqvv0.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_minasensis_GCF_000825765.lastz
# Creating Ehrlichia_minasensis_GCF_000825765 table
# Inserting data to Ehrlichia_minasensis_GCF_000825765 table
#
# Running against Ehrlichia_muris_GCF_000508225.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpGEbG3J.fasta
#
# Writing the results file...
# 	/tmp/tmpraap7f.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_muris_GCF_000508225.lastz
# Creating Ehrlichia_muris_GCF_000508225 table
# Inserting data to Ehrlichia_muris_GCF_000508225 table
#
# Running against Ehrlichia_ruminantium_GCF_000026005.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDwg2Ll.fasta
#
# Writing the results file...
# 	/tmp/tmpwEZ8e7.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_ruminantium_GCF_000026005.lastz
# Creating Ehrlichia_ruminantium_GCF_000026005 table
# Inserting data to Ehrlichia_ruminantium_GCF_000026005 table
#
# Running against Ehrlichia_sp_GCF_000632845.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpA6EFB9.fasta
#
# Writing the results file...
# 	/tmp/tmpvtj9_x.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_sp_GCF_000632845.lastz
# Creating Ehrlichia_sp_GCF_000632845 table
# Inserting data to Ehrlichia_sp_GCF_000632845 table
#
# Running against Ehrlichia_canis_GCF_000012565.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp1WMczD.fasta
#
# Writing the results file...
# 	/tmp/tmpfYGi02.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/ehrlichia/validate_intervals/lastz/Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_Ehrlichia_canis_GCF_000012565.lastz
# Creating Ehrlichia_canis_GCF_000012565 table
# Inserting data to Ehrlichia_canis_GCF_000012565 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/ehrlichia/extract_probes_from_group/ehrlichia_genome.conf --lastz results/phyluce/ehrlichia/validate_intervals/lastz --probes 120 --probe-prefix uce_ehrlichia_ --name-pattern "Ehrlichia_canis_GCF_000012565_+4_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/ehrlichia/extract_probes_from_group/probe_fasta;
# 2020-02-07 10:28:27,920 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 10:28:27,922 - Phyluce - INFO - ----- Working on Ehrlichia_chaffeensis_GCF_000013145 genome -----
# 2020-02-07 10:28:27,923 - Phyluce - INFO - Reading Ehrlichia_chaffeensis_GCF_000013145 genome
# 2020-02-07 10:28:29,336 - Phyluce - INFO - Ehrlichia_chaffeensis_GCF_000013145: 345 uces, 0 dupes, 345 non-dupes, 4 orient drop, 5 length drop, 336 written
# 2020-02-07 10:28:29,337 - Phyluce - INFO - ------ Working on Ehrlichia_minasensis_GCF_000825765 genome -----
# 2020-02-07 10:28:29,337 - Phyluce - INFO - Reading Ehrlichia_minasensis_GCF_000825765 genome
# 2020-02-07 10:28:30,375 - Phyluce - INFO - Ehrlichia_minasensis_GCF_000825765: 345 uces, 10 dupes, 335 non-dupes, 1 orient drop, 3 length drop, 331 written
# 2020-02-07 10:28:30,375 - Phyluce - INFO - -------- Working on Ehrlichia_muris_GCF_000508225 genome --------
# 2020-02-07 10:28:30,376 - Phyluce - INFO - Reading Ehrlichia_muris_GCF_000508225 genome
# 2020-02-07 10:28:31,413 - Phyluce - INFO - Ehrlichia_muris_GCF_000508225: 345 uces, 0 dupes, 345 non-dupes, 3 orient drop, 12 length drop, 330 written
# 2020-02-07 10:28:31,413 - Phyluce - INFO - ----- Working on Ehrlichia_ruminantium_GCF_000026005 genome -----
# 2020-02-07 10:28:31,414 - Phyluce - INFO - Reading Ehrlichia_ruminantium_GCF_000026005 genome
# 2020-02-07 10:28:32,660 - Phyluce - INFO - Ehrlichia_ruminantium_GCF_000026005: 345 uces, 0 dupes, 345 non-dupes, 11 orient drop, 9 length drop, 325 written
# 2020-02-07 10:28:32,661 - Phyluce - INFO - ---------- Working on Ehrlichia_sp_GCF_000632845 genome ---------
# 2020-02-07 10:28:32,661 - Phyluce - INFO - Reading Ehrlichia_sp_GCF_000632845 genome
# 2020-02-07 10:28:33,865 - Phyluce - INFO - Ehrlichia_sp_GCF_000632845: 345 uces, 0 dupes, 345 non-dupes, 4 orient drop, 7 length drop, 334 written
# 2020-02-07 10:28:33,865 - Phyluce - INFO - -------- Working on Ehrlichia_canis_GCF_000012565 genome --------
# 2020-02-07 10:28:33,870 - Phyluce - INFO - Reading Ehrlichia_canis_GCF_000012565 genome
# 2020-02-07 10:28:35,054 - Phyluce - INFO - Ehrlichia_canis_GCF_000012565: 345 uces, 0 dupes, 345 non-dupes, 5 orient drop, 9 length drop, 331 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/ehrlichia/extract_probes_from_group/probe_fasta --output results/phyluce/ehrlichia/extract_probes_from_group/multifastas.sqlite --base-taxon Ehrlichia_canis_GCF_000012565;
# ehrlichia_chaffeensis_gcf_000013145.
# ehrlichia_minasensis_gcf_000825765.
# ehrlichia_muris_gcf_000508225.
# ehrlichia_ruminantium_gcf_000026005.
# ehrlichia_sp_gcf_000632845.
# ehrlichia_canis_gcf_000012565.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/ehrlichia/extract_probes_from_group/multifastas.sqlite --base-taxon Ehrlichia_canis_GCF_000012565;
# Loci shared by 0 taxa:	339.0
# Loci shared by 1 taxa:	339.0
# Loci shared by 2 taxa:	337.0
# Loci shared by 3 taxa:	335.0
# Loci shared by 4 taxa:	335.0
# Loci shared by 5 taxa:	329.0
# Loci shared by 6 taxa:	312.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(6)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/ehrlichia/extract_probes_from_group/multifastas.sqlite  --base-taxon Ehrlichia_canis_GCF_000012565 --output results/phyluce/ehrlichia/extract_probes_from_group/Ehrlichia_canis_GCF_000012565+4-back-to-6.conf --specific-counts 6;
# Counter({'ehrlichia_ruminantium_gcf_000026005': 312, 'ehrlichia_minasensis_gcf_000825765': 312, 'ehrlichia_muris_gcf_000508225': 312, 'ehrlichia_chaffeensis_gcf_000013145': 312, 'ehrlichia_canis_gcf_000012565': 312, 'ehrlichia_sp_gcf_000632845': 312})
# Total loci = 312

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/ehrlichia/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/ehrlichia/extract_probes_from_group/Ehrlichia_canis_GCF_000012565+4-back-to-6.conf --probe-prefix uce_ehrlichia_ --designer rnplattii --design ehrlichia_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.fasta;
# ...
#
#
# Conserved locus count = 312
# Probe Count = 3207

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.fasta --query results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  10:28:47
# Ended:  Fri Feb 07, 2020  10:28:50
# Time for execution:  0.0384563008944 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.fasta --lastz results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_ehrlichia_;
# Parsing lastz file...
# Screening results...
# Screened 3206 fasta sequences.  Filtered 0 duplicates. Kept 3207.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.fasta
#          -o
#          results/phyluce/ehrlichia/final_probe_design/ehrlichia_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 10:29:38 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 3207
# longest and shortest : 80 and 80
# Total letters: 256560
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 16M = 33M
# Miscellaneous   : 4M
# Total           : 86M
#
# Table limit with the given memory limit:
# Max number of representatives: 3959542
# Max number of word counting entries: 89129304
#
# # comparing sequences from          0  to        534
# ---------- new table with      449 representatives
# # comparing sequences from        534  to        979
# ----------    142 remaining sequences to the next cycle
# ---------- new table with      252 representatives
# # comparing sequences from        837  to       1232
# ----------    149 remaining sequences to the next cycle
# ---------- new table with      209 representatives
# # comparing sequences from       1083  to       1437
# ----------     57 remaining sequences to the next cycle
# ---------- new table with      239 representatives
# # comparing sequences from       1380  to       1684
# ----------     33 remaining sequences to the next cycle
# ---------- new table with      218 representatives
# # comparing sequences from       1651  to       1910
# ----------     14 remaining sequences to the next cycle
# ---------- new table with      197 representatives
# # comparing sequences from       1896  to       2114
# 99.9%---------- new table with      182 representatives
# # comparing sequences from       2114  to       2296
# ----------     53 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from       2243  to       3207
# .....................---------- new table with      793 representatives
#
#      3207  finished       2639  clusters
#
# Approximated maximum memory consumption: 87M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 0.80

# %% [markdown]
# # Francisella

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'francisella'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Francisella_adeliensis_GCF_003290445",
               "Francisella_frigiditurris_GCF_001880225",
               "Francisella_halioticida_GCF_002211785",
               "Francisella_hispniensis_GCF_001885235",
               "Francisella_marina_GCF_008369785",
               "Francisella_noatunensis_GCF_008330245",
               "Francisella_opportunistica_GCF_003347135",
               "Francisella_persica_GCF_001653955",
               "Francisella_philomiragia_GCF_000019285",
               "Francisella_salina_GCF_000219045",
               "Francisella_sp_GCF_000764555",
               "Francisella_uliginis_GCF_001895265" ]
                    
reference_taxon = "Francisella_tularensis_GCF_000008985"

all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003290445.1_ASM329044v1_genomic.fna.gz
#
# sent 42 bytes  received 597341 bytes  398255.33 bytes/sec
# total size is 597083  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001880225.1_ASM188022v1_genomic.fna.gz
#
# sent 42 bytes  received 536837 bytes  357919.33 bytes/sec
# total size is 536595  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002211785.1_ASM221178v1_genomic.fna.gz
#
# sent 42 bytes  received 620187 bytes  413486.00 bytes/sec
# total size is 619929  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001885235.1_ASM188523v1_genomic.fna.gz
#
# sent 42 bytes  received 561757 bytes  374532.67 bytes/sec
# total size is 561507  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_008369785.1_ASM836978v1_genomic.fna.gz
#
# sent 42 bytes  received 601266 bytes  400872.00 bytes/sec
# total size is 601008  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_008330245.1_ASM833024v1_genomic.fna.gz
#
# sent 42 bytes  received 542224 bytes  361510.67 bytes/sec
# total size is 541982  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003347135.1_ASM334713v1_genomic.fna.gz
#
# sent 42 bytes  received 533528 bytes  355713.33 bytes/sec
# total size is 533286  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001653955.1_ASM165395v1_genomic.fna.gz
#
# sent 42 bytes  received 444440 bytes  296321.33 bytes/sec
# total size is 444222  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000019285.1_ASM1928v1_genomic.fna.gz
#
# sent 42 bytes  received 593547 bytes  1187178.00 bytes/sec
# total size is 593291  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000219045.1_ASM21904v1_genomic.fna.gz
#
# sent 42 bytes  received 593045 bytes  395391.33 bytes/sec
# total size is 592788  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_000764555.1_ASM76455v1_genomic.fna.gz
#
# sent 42 bytes  received 584089 bytes  389420.67 bytes/sec
# total size is 583840  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000008985.1_ASM898v1_genomic.fna.gz
#
# sent 42 bytes  received 547773 bytes  365210.00 bytes/sec
# total size is 547534  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001895265.1_ASM189526v1_genomic.fna.gz
#
# sent 42 bytes  received 644544 bytes  429724.00 bytes/sec
# total size is 644278  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483012 ("sim_Francisella_adeliensis_GCF_003290445") has been submitted
# Your job 5483013 ("sim_Francisella_frigiditurris_GCF_001880225") has been submitted
# Your job 5483014 ("sim_Francisella_halioticida_GCF_002211785") has been submitted
# Your job 5483015 ("sim_Francisella_hispniensis_GCF_001885235") has been submitted
# Your job 5483016 ("sim_Francisella_marina_GCF_008369785") has been submitted
# Your job 5483017 ("sim_Francisella_noatunensis_GCF_008330245") has been submitted
# Your job 5483018 ("sim_Francisella_opportunistica_GCF_003347135") has been submitted
# Your job 5483019 ("sim_Francisella_persica_GCF_001653955") has been submitted
# Your job 5483020 ("sim_Francisella_philomiragia_GCF_000019285") has been submitted
# Your job 5483021 ("sim_Francisella_salina_GCF_000219045") has been submitted
# Your job 5483022 ("sim_Francisella_sp_GCF_000764555") has been submitted
# Your job 5483023 ("sim_Francisella_uliginis_GCF_001895265") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/francisella/cleaned_genomes/Francisella_tularensis_GCF_000008985_formatted.fas path=results/phyluce/francisella/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483024 ("map_Francisella_adeliensis_GCF_003290445") has been submitted
# Your job 5483025 ("map_Francisella_frigiditurris_GCF_001880225") has been submitted
# Your job 5483026 ("map_Francisella_halioticida_GCF_002211785") has been submitted
# Your job 5483027 ("map_Francisella_hispniensis_GCF_001885235") has been submitted
# Your job 5483028 ("map_Francisella_marina_GCF_008369785") has been submitted
# Your job 5483029 ("map_Francisella_noatunensis_GCF_008330245") has been submitted
# Your job 5483030 ("map_Francisella_opportunistica_GCF_003347135") has been submitted
# Your job 5483031 ("map_Francisella_persica_GCF_001653955") has been submitted
# Your job 5483032 ("map_Francisella_philomiragia_GCF_000019285") has been submitted
# Your job 5483033 ("map_Francisella_salina_GCF_000219045") has been submitted
# Your job 5483034 ("map_Francisella_sp_GCF_000764555") has been submitted
# Your job 5483035 ("map_Francisella_uliginis_GCF_001895265") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483036 ("merge_Francisella_adeliensis_GCF_003290445") has been submitted
# Your job 5483037 ("merge_Francisella_frigiditurris_GCF_001880225") has been submitted
# Your job 5483038 ("merge_Francisella_halioticida_GCF_002211785") has been submitted
# Your job 5483039 ("merge_Francisella_hispniensis_GCF_001885235") has been submitted
# Your job 5483040 ("merge_Francisella_marina_GCF_008369785") has been submitted
# Your job 5483041 ("merge_Francisella_noatunensis_GCF_008330245") has been submitted
# Your job 5483042 ("merge_Francisella_opportunistica_GCF_003347135") has been submitted
# Your job 5483043 ("merge_Francisella_persica_GCF_001653955") has been submitted
# Your job 5483044 ("merge_Francisella_philomiragia_GCF_000019285") has been submitted
# Your job 5483045 ("merge_Francisella_salina_GCF_000219045") has been submitted
# Your job 5483046 ("merge_Francisella_sp_GCF_000764555") has been submitted
# Your job 5483047 ("merge_Francisella_uliginis_GCF_001895265") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 295 sequences from Francisella_adeliensis_GCF_003290445_merged.bed.  Filtered 211 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 84.
# Screened 234 sequences from Francisella_frigiditurris_GCF_001880225_merged.bed.  Filtered 162 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 72.
# Screened 638 sequences from Francisella_halioticida_GCF_002211785_merged.bed.  Filtered 454 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 184.
# Screened 2181 sequences from Francisella_hispniensis_GCF_001885235_merged.bed.  Filtered 430 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 1751.
# Screened 1263 sequences from Francisella_marina_GCF_008369785_merged.bed.  Filtered 734 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 529.
# Screened 1242 sequences from Francisella_noatunensis_GCF_008330245_merged.bed.  Filtered 688 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 554.
# Screened 2919 sequences from Francisella_opportunistica_GCF_003347135_merged.bed.  Filtered 1059 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 1860.
# Screened 2406 sequences from Francisella_persica_GCF_001653955_merged.bed.  Filtered 844 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 1562.
# Screened 1382 sequences from Francisella_philomiragia_GCF_000019285_merged.bed.  Filtered 746 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 636.
# Screened 1261 sequences from Francisella_salina_GCF_000219045_merged.bed.  Filtered 689 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 572.
# Screened 737 sequences from Francisella_sp_GCF_000764555_merged.bed.  Filtered 499 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 238.
# Screened 829 sequences from Francisella_uliginis_GCF_001895265_merged.bed.  Filtered 546 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 283.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/francisella/initial_intervals/Francisella_uliginis_GCF_001895265_merged.bed --twobit results/phyluce/francisella/cleaned_genomes/Francisella_tularensis_GCF_000008985_formatted.2bit --output results/phyluce/francisella/initial_intervals/Francisella_uliginis_GCF_001895265_stripped.bed;
# francisella_adeliensis_gcf_003290445.
# francisella_frigiditurris_gcf_001880225.
# francisella_halioticida_gcf_002211785.
# francisella_hispniensis_gcf_001885235..
# francisella_marina_gcf_008369785.
# francisella_noatunensis_gcf_008330245.
# francisella_opportunistica_gcf_003347135..
# francisella_persica_gcf_001653955..
# francisella_philomiragia_gcf_000019285.
# francisella_salina_gcf_000219045.
# francisella_sp_gcf_000764555.
# francisella_uliginis_gcf_001895265.
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/francisella/initial_intervals/Francisella_uliginis_GCF_001895265_merged.bed --twobit results/phyluce/francisella/cleaned_genomes/Francisella_tularensis_GCF_000008985_formatted.2bit --output results/phyluce/francisella/initial_intervals/Francisella_uliginis_GCF_001895265_stripped.bed;
# Loci shared by Francisella_tularensis_GCF_000008985 + 0 taxa:	2,296.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 1 taxa:	2,296.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 2 taxa:	1,761.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 3 taxa:	1,286.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 4 taxa:	720.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 5 taxa:	543.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 6 taxa:	371.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 7 taxa:	269.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 8 taxa:	188.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 9 taxa:	128.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 10 taxa:	83.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 11 taxa:	48.0
# Loci shared by Francisella_tularensis_GCF_000008985 + 12 taxa:	27.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 7
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/francisella/initial_intervals/francisella-to-Francisella_tularensis_GCF_000008985.sqlite --base-taxon Francisella_tularensis_GCF_000008985 --output results/phyluce/francisella/initial_intervals/Francisella_tularensis_GCF_000008985_+7.bed --specific-counts 7;
# Counter({'francisella_philomiragia_gcf_000019285': 254, 'francisella_opportunistica_gcf_003347135': 252, 'francisella_hispniensis_gcf_001885235': 252, 'francisella_noatunensis_gcf_008330245': 247, 'francisella_persica_gcf_001653955': 244, 'francisella_salina_gcf_000219045': 242, 'francisella_marina_gcf_008369785': 241, 'francisella_uliginis_gcf_001895265': 198, 'francisella_sp_gcf_000764555': 168, 'francisella_halioticida_gcf_002211785': 148, 'francisella_adeliensis_gcf_003290445': 64, 'francisella_frigiditurris_gcf_001880225': 47})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/francisella/initial_intervals/Francisella_tularensis_GCF_000008985_+7.bed --twobit results/phyluce/francisella/cleaned_genomes/Francisella_tularensis_GCF_000008985_formatted.2bit --buffer-to 160 --output results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7.fasta;
# Screened 269 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 269.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7.fasta --probe-prefix uce_francisella_ --design francisella_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 253
# Probe Count = 470

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas --query results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  10:33:58
# Ended:  Fri Feb 07, 2020  10:34:00
# Time for execution:  0.0289617498716 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas                        --lastz results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes_vself.lastz                       --probe-prefix=uce_francisella_;
# Parsing lastz file...
# Screening results...
# Screened 469 fasta sequences.  Filtered 2 duplicates. Kept 466.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/francisella/validate_intervals/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas --scaffoldlist Francisella_adeliensis_GCF_003290445 Francisella_frigiditurris_GCF_001880225 Francisella_halioticida_GCF_002211785 Francisella_hispniensis_GCF_001885235 Francisella_marina_GCF_008369785 Francisella_noatunensis_GCF_008330245 Francisella_opportunistica_GCF_003347135 Francisella_persica_GCF_001653955 Francisella_philomiragia_GCF_000019285 Francisella_salina_GCF_000219045 Francisella_sp_GCF_000764555 Francisella_uliginis_GCF_001895265 Francisella_tularensis_GCF_000008985 --genome-base-path results/phyluce/francisella/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/francisella/validate_intervals/francisella-to-Francisella_tularensis_GCF_000008985.sqlite --output results/phyluce/francisella/validate_intervals/lastz/;
#
# Running against Francisella_adeliensis_GCF_003290445.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpnpfSee.fasta
#
# Writing the results file...
# 	/tmp/tmpxSdnzM.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_adeliensis_GCF_003290445.lastz
# Creating Francisella_adeliensis_GCF_003290445 table
# Inserting data to Francisella_adeliensis_GCF_003290445 table
#
# Running against Francisella_frigiditurris_GCF_001880225.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp8cwiT_.fasta
#
# Writing the results file...
# 	/tmp/tmpQQawu4.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_frigiditurris_GCF_001880225.lastz
# Creating Francisella_frigiditurris_GCF_001880225 table
# Inserting data to Francisella_frigiditurris_GCF_001880225 table
#
# Running against Francisella_halioticida_GCF_002211785.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpuLLHZ0.fasta
#
# Writing the results file...
# 	/tmp/tmp_Cs_cD.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_halioticida_GCF_002211785.lastz
# Creating Francisella_halioticida_GCF_002211785 table
# Inserting data to Francisella_halioticida_GCF_002211785 table
#
# Running against Francisella_hispniensis_GCF_001885235.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp3AkyCV.fasta
#
# Writing the results file...
# 	/tmp/tmpODHBrs.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_hispniensis_GCF_001885235.lastz
# Creating Francisella_hispniensis_GCF_001885235 table
# Inserting data to Francisella_hispniensis_GCF_001885235 table
#
# Running against Francisella_marina_GCF_008369785.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpkE3MaE.fasta
#
# Writing the results file...
# 	/tmp/tmpW5_5Wu.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_marina_GCF_008369785.lastz
# Creating Francisella_marina_GCF_008369785 table
# Inserting data to Francisella_marina_GCF_008369785 table
#
# Running against Francisella_noatunensis_GCF_008330245.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpjZBnxN.fasta
#
# Writing the results file...
# 	/tmp/tmpIlLwIT.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_noatunensis_GCF_008330245.lastz
# Creating Francisella_noatunensis_GCF_008330245 table
# Inserting data to Francisella_noatunensis_GCF_008330245 table
#
# Running against Francisella_opportunistica_GCF_003347135.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpVMcnFP.fasta
#
# Writing the results file...
# 	/tmp/tmp0wP2b_.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_opportunistica_GCF_003347135.lastz
# Creating Francisella_opportunistica_GCF_003347135 table
# Inserting data to Francisella_opportunistica_GCF_003347135 table
#
# Running against Francisella_persica_GCF_001653955.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp3NOW_E.fasta
#
# Writing the results file...
# 	/tmp/tmpqjqbBM.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_persica_GCF_001653955.lastz
# Creating Francisella_persica_GCF_001653955 table
# Inserting data to Francisella_persica_GCF_001653955 table
#
# Running against Francisella_philomiragia_GCF_000019285.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpWrpHgN.fasta
#
# Writing the results file...
# 	/tmp/tmphyiq9Z.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_philomiragia_GCF_000019285.lastz
# Creating Francisella_philomiragia_GCF_000019285 table
# Inserting data to Francisella_philomiragia_GCF_000019285 table
#
# Running against Francisella_salina_GCF_000219045.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDhvtUH.fasta
#
# Writing the results file...
# 	/tmp/tmpVbY2CU.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_salina_GCF_000219045.lastz
# Creating Francisella_salina_GCF_000219045 table
# Inserting data to Francisella_salina_GCF_000219045 table
#
# Running against Francisella_sp_GCF_000764555.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpQyEmkx.fasta
#
# Writing the results file...
# 	/tmp/tmpbVt1fc.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_sp_GCF_000764555.lastz
# Creating Francisella_sp_GCF_000764555 table
# Inserting data to Francisella_sp_GCF_000764555 table
#
# Running against Francisella_uliginis_GCF_001895265.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxOc8Bq.fasta
#
# Writing the results file...
# 	/tmp/tmppL_XLQ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_uliginis_GCF_001895265.lastz
# Creating Francisella_uliginis_GCF_001895265 table
# Inserting data to Francisella_uliginis_GCF_001895265 table
#
# Running against Francisella_tularensis_GCF_000008985.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpT9tMoV.fasta
#
# Writing the results file...
# 	/tmp/tmpqegYi9.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/francisella/validate_intervals/lastz/Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_Francisella_tularensis_GCF_000008985.lastz
# Creating Francisella_tularensis_GCF_000008985 table
# Inserting data to Francisella_tularensis_GCF_000008985 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/francisella/extract_probes_from_group/francisella_genome.conf --lastz results/phyluce/francisella/validate_intervals/lastz --probes 120 --probe-prefix uce_francisella_ --name-pattern "Francisella_tularensis_GCF_000008985_+7_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/francisella/extract_probes_from_group/probe_fasta;
# 2020-02-07 10:34:23,743 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 10:34:23,745 - Phyluce - INFO - ----- Working on Francisella_adeliensis_GCF_003290445 genome ----
# 2020-02-07 10:34:23,746 - Phyluce - INFO - Reading Francisella_adeliensis_GCF_003290445 genome
# 2020-02-07 10:34:24,610 - Phyluce - INFO - Francisella_adeliensis_GCF_003290445: 245 uces, 0 dupes, 245 non-dupes, 7 orient drop, 2 length drop, 236 written
# 2020-02-07 10:34:24,610 - Phyluce - INFO - --- Working on Francisella_frigiditurris_GCF_001880225 genome ---
# 2020-02-07 10:34:24,611 - Phyluce - INFO - Reading Francisella_frigiditurris_GCF_001880225 genome
# 2020-02-07 10:34:25,358 - Phyluce - INFO - Francisella_frigiditurris_GCF_001880225: 239 uces, 0 dupes, 239 non-dupes, 5 orient drop, 2 length drop, 232 written
# 2020-02-07 10:34:25,359 - Phyluce - INFO - ---- Working on Francisella_halioticida_GCF_002211785 genome ----
# 2020-02-07 10:34:25,359 - Phyluce - INFO - Reading Francisella_halioticida_GCF_002211785 genome
# 2020-02-07 10:34:26,172 - Phyluce - INFO - Francisella_halioticida_GCF_002211785: 248 uces, 0 dupes, 248 non-dupes, 9 orient drop, 5 length drop, 234 written
# 2020-02-07 10:34:26,172 - Phyluce - INFO - ---- Working on Francisella_hispniensis_GCF_001885235 genome ----
# 2020-02-07 10:34:26,173 - Phyluce - INFO - Reading Francisella_hispniensis_GCF_001885235 genome
# 2020-02-07 10:34:27,167 - Phyluce - INFO - Francisella_hispniensis_GCF_001885235: 253 uces, 0 dupes, 253 non-dupes, 9 orient drop, 3 length drop, 241 written
# 2020-02-07 10:34:27,167 - Phyluce - INFO - ------- Working on Francisella_marina_GCF_008369785 genome ------
# 2020-02-07 10:34:27,168 - Phyluce - INFO - Reading Francisella_marina_GCF_008369785 genome
# 2020-02-07 10:34:28,123 - Phyluce - INFO - Francisella_marina_GCF_008369785: 251 uces, 0 dupes, 251 non-dupes, 10 orient drop, 2 length drop, 239 written
# 2020-02-07 10:34:28,124 - Phyluce - INFO - ---- Working on Francisella_noatunensis_GCF_008330245 genome ----
# 2020-02-07 10:34:28,142 - Phyluce - INFO - Reading Francisella_noatunensis_GCF_008330245 genome
# 2020-02-07 10:34:28,989 - Phyluce - INFO - Francisella_noatunensis_GCF_008330245: 248 uces, 0 dupes, 248 non-dupes, 7 orient drop, 5 length drop, 236 written
# 2020-02-07 10:34:28,990 - Phyluce - INFO - --- Working on Francisella_opportunistica_GCF_003347135 genome --
# 2020-02-07 10:34:28,991 - Phyluce - INFO - Reading Francisella_opportunistica_GCF_003347135 genome
# 2020-02-07 10:34:29,784 - Phyluce - INFO - Francisella_opportunistica_GCF_003347135: 242 uces, 0 dupes, 242 non-dupes, 10 orient drop, 4 length drop, 228 written
# 2020-02-07 10:34:29,784 - Phyluce - INFO - ------ Working on Francisella_persica_GCF_001653955 genome ------
# 2020-02-07 10:34:29,785 - Phyluce - INFO - Reading Francisella_persica_GCF_001653955 genome
# 2020-02-07 10:34:30,636 - Phyluce - INFO - Francisella_persica_GCF_001653955: 243 uces, 0 dupes, 243 non-dupes, 6 orient drop, 5 length drop, 232 written
# 2020-02-07 10:34:30,637 - Phyluce - INFO - ---- Working on Francisella_philomiragia_GCF_000019285 genome ---
# 2020-02-07 10:34:30,637 - Phyluce - INFO - Reading Francisella_philomiragia_GCF_000019285 genome
# 2020-02-07 10:34:31,568 - Phyluce - INFO - Francisella_philomiragia_GCF_000019285: 251 uces, 0 dupes, 251 non-dupes, 8 orient drop, 8 length drop, 235 written
# 2020-02-07 10:34:31,569 - Phyluce - INFO - ------- Working on Francisella_salina_GCF_000219045 genome ------
# 2020-02-07 10:34:31,569 - Phyluce - INFO - Reading Francisella_salina_GCF_000219045 genome
# 2020-02-07 10:34:32,414 - Phyluce - INFO - Francisella_salina_GCF_000219045: 251 uces, 0 dupes, 251 non-dupes, 12 orient drop, 1 length drop, 238 written
# 2020-02-07 10:34:32,414 - Phyluce - INFO - --------- Working on Francisella_sp_GCF_000764555 genome --------
# 2020-02-07 10:34:32,415 - Phyluce - INFO - Reading Francisella_sp_GCF_000764555 genome
# 2020-02-07 10:34:33,443 - Phyluce - INFO - Francisella_sp_GCF_000764555: 246 uces, 0 dupes, 246 non-dupes, 8 orient drop, 1 length drop, 237 written
# 2020-02-07 10:34:33,444 - Phyluce - INFO - ------ Working on Francisella_uliginis_GCF_001895265 genome -----
# 2020-02-07 10:34:33,475 - Phyluce - INFO - Reading Francisella_uliginis_GCF_001895265 genome
# 2020-02-07 10:34:34,576 - Phyluce - INFO - Francisella_uliginis_GCF_001895265: 250 uces, 0 dupes, 250 non-dupes, 9 orient drop, 4 length drop, 237 written
# 2020-02-07 10:34:34,577 - Phyluce - INFO - ----- Working on Francisella_tularensis_GCF_000008985 genome ----
# 2020-02-07 10:34:34,577 - Phyluce - INFO - Reading Francisella_tularensis_GCF_000008985 genome
# 2020-02-07 10:34:35,551 - Phyluce - INFO - Francisella_tularensis_GCF_000008985: 253 uces, 0 dupes, 253 non-dupes, 6 orient drop, 7 length drop, 240 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/francisella/extract_probes_from_group/probe_fasta --output results/phyluce/francisella/extract_probes_from_group/multifastas.sqlite --base-taxon Francisella_tularensis_GCF_000008985;
# francisella_adeliensis_gcf_003290445.
# francisella_frigiditurris_gcf_001880225.
# francisella_halioticida_gcf_002211785.
# francisella_hispniensis_gcf_001885235.
# francisella_marina_gcf_008369785.
# francisella_noatunensis_gcf_008330245.
# francisella_opportunistica_gcf_003347135.
# francisella_persica_gcf_001653955.
# francisella_philomiragia_gcf_000019285.
# francisella_salina_gcf_000219045.
# francisella_sp_gcf_000764555.
# francisella_uliginis_gcf_001895265.
# francisella_tularensis_gcf_000008985.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/francisella/extract_probes_from_group/multifastas.sqlite --base-taxon Francisella_tularensis_GCF_000008985;
# Loci shared by 0 taxa:	248.0
# Loci shared by 1 taxa:	248.0
# Loci shared by 2 taxa:	248.0
# Loci shared by 3 taxa:	243.0
# Loci shared by 4 taxa:	243.0
# Loci shared by 5 taxa:	243.0
# Loci shared by 6 taxa:	242.0
# Loci shared by 7 taxa:	242.0
# Loci shared by 8 taxa:	239.0
# Loci shared by 9 taxa:	238.0
# Loci shared by 10 taxa:	232.0
# Loci shared by 11 taxa:	225.0
# Loci shared by 12 taxa:	221.0
# Loci shared by 13 taxa:	201.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(13)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/francisella/extract_probes_from_group/multifastas.sqlite  --base-taxon Francisella_tularensis_GCF_000008985 --output results/phyluce/francisella/extract_probes_from_group/Francisella_tularensis_GCF_000008985+7-back-to-13.conf --specific-counts 13;
# Counter({'francisella_persica_gcf_001653955': 201, 'francisella_sp_gcf_000764555': 201, 'francisella_salina_gcf_000219045': 201, 'francisella_frigiditurris_gcf_001880225': 201, 'francisella_opportunistica_gcf_003347135': 201, 'francisella_noatunensis_gcf_008330245': 201, 'francisella_hispniensis_gcf_001885235': 201, 'francisella_marina_gcf_008369785': 201, 'francisella_philomiragia_gcf_000019285': 201, 'francisella_adeliensis_gcf_003290445': 201, 'francisella_halioticida_gcf_002211785': 201, 'francisella_tularensis_gcf_000008985': 201, 'francisella_uliginis_gcf_001895265': 201})
# Total loci = 201

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/francisella/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/francisella/extract_probes_from_group/Francisella_tularensis_GCF_000008985+7-back-to-13.conf --probe-prefix uce_francisella_ --designer rnplattii --design francisella_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.fasta;
# ...
#
#
# Conserved locus count = 201
# Probe Count = 4671

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.fasta --query results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  10:34:49
# Ended:  Fri Feb 07, 2020  10:34:56
# Time for execution:  0.113882136345 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.fasta --lastz results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_francisella_;
# Parsing lastz file...
# Screening results...
# Screened 4670 fasta sequences.  Filtered 0 duplicates. Kept 4671.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.fasta
#          -o
#          results/phyluce/francisella/final_probe_design/francisella_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 10:37:22 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 4671
# longest and shortest : 80 and 80
# Total letters: 373680
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 0M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 16M = 33M
# Miscellaneous   : 4M
# Total           : 87M
#
# Table limit with the given memory limit:
# Max number of representatives: 3957054
# Max number of word counting entries: 89073306
#
# # comparing sequences from          0  to        778
# ---------- new table with      618 representatives
# # comparing sequences from        778  to       1426
# ----------    212 remaining sequences to the next cycle
# ---------- new table with      335 representatives
# # comparing sequences from       1214  to       1790
# ----------    172 remaining sequences to the next cycle
# ---------- new table with      312 representatives
# # comparing sequences from       1618  to       2126
# ----------    120 remaining sequences to the next cycle
# ---------- new table with      299 representatives
# # comparing sequences from       2006  to       2450
# ----------    115 remaining sequences to the next cycle
# ---------- new table with      234 representatives
# # comparing sequences from       2335  to       2724
# ----------    127 remaining sequences to the next cycle
# ---------- new table with      186 representatives
# # comparing sequences from       2597  to       2942
# ----------     88 remaining sequences to the next cycle
# ---------- new table with      184 representatives
# # comparing sequences from       2854  to       3156
# ----------    136 remaining sequences to the next cycle
# ---------- new table with      122 representatives
# # comparing sequences from       3020  to       3295
# ----------     62 remaining sequences to the next cycle
# ---------- new table with      163 representatives
# # comparing sequences from       3233  to       3472
# ----------     39 remaining sequences to the next cycle
# ---------- new table with      142 representatives
# # comparing sequences from       3433  to       3639
# ----------     59 remaining sequences to the next cycle
# ---------- new table with      115 representatives
# # comparing sequences from       3580  to       3761
# ----------      6 remaining sequences to the next cycle
# ---------- new table with      142 representatives
# # comparing sequences from       3755  to       4671
# .....................---------- new table with      603 representatives
#
#      4671  finished       3455  clusters
#
# Approximated maximum memory consumption: 87M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.09

# %% [markdown]
# # Leptospira

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'leptospira'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Leptospira_adleri_GCF_002811985",
               "Leptospira_alexanderi_GCF_000243815",
               "Leptospira_alstonii_GCF_000347175",
               "Leptospira_andrefontaineae_GCF_004770105",
               "Leptospira_bandrabouensis_GCF_004770905",
               "Leptospira_barantonii_GCF_002811925",
               "Leptospira_biflexa_GCF_000017685",
               "Leptospira_borgpetersenii_GCF_000013945",
               "Leptospira_bourretii_GCF_004769285",
               "Leptospira_bouyouniensis_GCF_004770625",
               "Leptospira_brenneri_GCF_002812125",
               "Leptospira_broomii_GCF_000243715",
               "Leptospira_congkakensis_GCF_004770265",
               "Leptospira_dzianensis_GCF_004770135",
               "Leptospira_dzoumogneensis_GCF_004770895",
               "Leptospira_ellinghausenii_GCF_003114815",
               "Leptospira_elllisii_GCF_002811955",
               "Leptospira_fainei_GCF_000306235",
               "Leptospira_fletcheri_GCF_004769195",
               "Leptospira_fluminis_GCF_004771275",
               "Leptospira_gomenensis_GCF_004770155",
               "Leptospira_haakeii_GCF_002812045",
               "Leptospira_harrisiae_GCF_002811945",
               "Leptospira_hartskeerlii_GCF_002811475",
               "Leptospira_idonii_GCF_004770995",
               "Leptospira_ilyithenensis_GCF_004771005",
               "Leptospira_inadai_GCF_000243675",
               "Leptospira_jelokensis_GCF_004769775",
               "Leptospira_johnsonii_GCF_003112675",
               "Leptospira_kanakyensis_GCF_004769235",
               "Leptospira_kemamanensis_GCF_004769665",
               "Leptospira_kirschneri_GCF_000243695",
               "Leptospira_kmetyi_GCF_000243735",
               "Leptospira_kobayashii_GCF_003114835",
               "Leptospira_koniamboensis_GCF_004769555",
               "Leptospira_langatensis_GCF_004770615",
               "Leptospira_levettii_GCF_002812085",
               "Leptospira_licerasiae_GCF_000244755",
               "Leptospira_macculloughii_GCF_002811975",
               "Leptospira_mayottensis_GCF_000306675",
               "Leptospira_meyeri_GCF_000304275",
               "Leptospira_montravelensis_GCF_004769455",
               "Leptospira_mtsangambouensis_GCF_004770475",
               "Leptospira_neocaledonica_GCF_002812205",
               "Leptospira_noguchii_GCF_000306255",
               "Leptospira_noumeaensis_GCF_004770765",
               "Leptospira_ognonensis_GCF_004770745",
               "Leptospira_perdikensis_GCF_004769575",
               "Leptospira_perolatii_GCF_002811875",
               "Leptospira_putramalaysiae_GCF_004770035",
               "Leptospira_ryugenii_GCF_003114855",
               "Leptospira_saintgironsiae_GCF_002811765",
               "Leptospira_santarosai_GCF_000313175",
               "Leptospira_sarikeiensis_GCF_004769615",
               "Leptospira_selangorensis_GCF_004769405",
               "Leptospira_semungkisensis_GCF_004770055",
               "Leptospira_sp_GCF_000347035",
               "Leptospira_stimsonii_GCF_003545885",
               "Leptospira_terpstrae_GCF_000332495",
               "Leptospira_tipperaryensis_GCF_001729245",
               "Leptospira_vanthielii_GCF_000332455",
               "Leptospira_venezuelensis_GCF_002150035",
               "Leptospira_weilii_GCF_000244815",
               "Leptospira_wolbachii_GCF_000332515",
               "Leptospira_wolffii_GCF_000306115",
               "Leptospira_yanagawae_GCF_000332475",
               "Leptospira_yasudae_GCF_003545925" ]
                    
reference_taxon = "Leptospira_interrogans_GCF_000092565"


all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip -f data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811985.1_ASM281198v1_genomic.fna.gz
#
# sent 42 bytes  received 1422418 bytes  948306.67 bytes/sec
# total size is 1421960  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000243815.3_gls454062v02_genomic.fna.gz
#
# sent 42 bytes  received 1245686 bytes  830485.33 bytes/sec
# total size is 1245267  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000347175.1_gls454194v01_genomic.fna.gz
#
# sent 42 bytes  received 1310884 bytes  873950.67 bytes/sec
# total size is 1310457  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770105.1_ASM477010v1_genomic.fna.gz
#
# sent 42 bytes  received 1266828 bytes  506748.00 bytes/sec
# total size is 1266410  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770905.1_ASM477090v1_genomic.fna.gz
#
# sent 42 bytes  received 1188743 bytes  792523.33 bytes/sec
# total size is 1188341  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811925.1_ASM281192v1_genomic.fna.gz
#
# sent 42 bytes  received 1284483 bytes  856350.00 bytes/sec
# total size is 1284057  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000017685.1_ASM1768v1_genomic.fna.gz
#
# sent 42 bytes  received 1162081 bytes  774748.67 bytes/sec
# total size is 1161689  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000013945.1_ASM1394v1_genomic.fna.gz
#
# sent 42 bytes  received 1143180 bytes  762148.00 bytes/sec
# total size is 1142796  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769285.1_ASM476928v1_genomic.fna.gz
#
# sent 42 bytes  received 1248227 bytes  832179.33 bytes/sec
# total size is 1247809  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770625.1_ASM477062v1_genomic.fna.gz
#
# sent 42 bytes  received 1213489 bytes  809020.67 bytes/sec
# total size is 1213079  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002812125.1_ASM281212v1_genomic.fna.gz
#
# sent 42 bytes  received 1213988 bytes  809353.33 bytes/sec
# total size is 1213578  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000243715.3_gls454050v02_genomic.fna.gz
#
# sent 42 bytes  received 1306348 bytes  870926.67 bytes/sec
# total size is 1305921  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770265.1_ASM477026v1_genomic.fna.gz
#
# sent 42 bytes  received 1180525 bytes  787044.67 bytes/sec
# total size is 1180123  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770135.1_ASM477013v1_genomic.fna.gz
#
# sent 42 bytes  received 1263524 bytes  842377.33 bytes/sec
# total size is 1263106  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770895.1_ASM477089v1_genomic.fna.gz
#
# sent 42 bytes  received 1217354 bytes  811597.33 bytes/sec
# total size is 1216944  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003114815.1_ASM311481v1_genomic.fna.gz
#
# sent 42 bytes  received 1233831 bytes  822582.00 bytes/sec
# total size is 1233421  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811955.1_ASM281195v1_genomic.fna.gz
#
# sent 42 bytes  received 1275125 bytes  850111.33 bytes/sec
# total size is 1274707  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000306235.2_gls454058v2.0_genomic.fna.gz
#
# sent 42 bytes  received 1273907 bytes  849299.33 bytes/sec
# total size is 1273487  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769195.1_ASM476919v1_genomic.fna.gz
#
# sent 42 bytes  received 1107337 bytes  130279.88 bytes/sec
# total size is 1106959  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004771275.1_ASM477127v1_genomic.fna.gz
#
# sent 42 bytes  received 1111588 bytes  741086.67 bytes/sec
# total size is 1111210  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770155.1_ASM477015v1_genomic.fna.gz
#
# sent 42 bytes  received 1256745 bytes  837858.00 bytes/sec
# total size is 1256327  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_002812045.1_ASM281204v1_genomic.fna.gz
#
# sent 42 bytes  received 1240941 bytes  107911.57 bytes/sec
# total size is 1240531  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811945.1_ASM281194v1_genomic.fna.gz
#
# sent 42 bytes  received 1164568 bytes  776406.67 bytes/sec
# total size is 1164174  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811475.1_ASM281147v1_genomic.fna.gz
#
# sent 42 bytes  received 1199790 bytes  799888.00 bytes/sec
# total size is 1199388  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770995.1_ASM477099v1_genomic.fna.gz
#
# sent 42 bytes  received 1210897 bytes  807292.67 bytes/sec
# total size is 1210495  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004771005.1_ASM477100v1_genomic.fna.gz
#
# sent 42 bytes  received 1251153 bytes  834130.00 bytes/sec
# total size is 1250735  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000243675.3_gls454047v02_genomic.fna.gz
#
# sent 42 bytes  received 1320651 bytes  880462.00 bytes/sec
# total size is 1320216  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000092565.1_ASM9256v1_genomic.fna.gz
#
# sent 42 bytes  received 1361938 bytes  907986.67 bytes/sec
# total size is 1361498  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769775.1_ASM476977v1_genomic.fna.gz
#
# sent 42 bytes  received 1214005 bytes  809364.67 bytes/sec
# total size is 1213595  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003112675.1_ASM311267v1_genomic.fna.gz
#
# sent 42 bytes  received 1203203 bytes  802163.33 bytes/sec
# total size is 1202801  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769235.1_ASM476923v1_genomic.fna.gz
#
# sent 42 bytes  received 1220145 bytes  813458.00 bytes/sec
# total size is 1219735  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769665.1_ASM476966v1_genomic.fna.gz
#
# sent 42 bytes  received 1113001 bytes  742028.67 bytes/sec
# total size is 1112623  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_000243695.3_gls454049v02_genomic.fna.gz
#
# sent 42 bytes  received 1284980 bytes  856681.33 bytes/sec
# total size is 1284553  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000243735.3_gls454052v1.0_genomic.fna.gz
#
# sent 42 bytes  received 1286415 bytes  857638.00 bytes/sec
# total size is 1285987  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003114835.1_ASM311483v1_genomic.fna.gz
#
# sent 42 bytes  received 1268806 bytes  845898.67 bytes/sec
# total size is 1268388  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769555.1_ASM476955v1_genomic.fna.gz
#
# sent 42 bytes  received 1273296 bytes  848892.00 bytes/sec
# total size is 1272878  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770615.1_ASM477061v1_genomic.fna.gz
#
# sent 42 bytes  received 1214391 bytes  809622.00 bytes/sec
# total size is 1213981  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002812085.1_ASM281208v1_genomic.fna.gz
#
# sent 42 bytes  received 1141066 bytes  760738.67 bytes/sec
# total size is 1140680  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000244755.3_ASM24475v3_genomic.fna.gz
#
# sent 42 bytes  received 1247850 bytes  831928.00 bytes/sec
# total size is 1247433  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811975.1_ASM281197v1_genomic.fna.gz
#
# sent 42 bytes  received 2051170 bytes  1367474.67 bytes/sec
# total size is 2050560  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000306675.3_ASM30667v3_genomic.fna.gz
#
# sent 42 bytes  received 1222557 bytes  815066.00 bytes/sec
# total size is 1222148  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000304275.1_gls454017v1.0_genomic.fna.gz
#
# sent 42 bytes  received 1234380 bytes  822948.00 bytes/sec
# total size is 1233968  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769455.1_ASM476945v1_genomic.fna.gz
#
# sent 42 bytes  received 1202634 bytes  801784.00 bytes/sec
# total size is 1202232  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_004770475.1_ASM477047v1_genomic.fna.gz
#
# sent 42 bytes  received 1203143 bytes  802123.33 bytes/sec
# total size is 1202741  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002812205.1_ASM281220v1_genomic.fna.gz
#
# sent 42 bytes  received 1246331 bytes  830915.33 bytes/sec
# total size is 1245913  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000306255.2_gls454059v02_genomic.fna.gz
#
# sent 42 bytes  received 1378200 bytes  918828.00 bytes/sec
# total size is 1377749  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770765.1_ASM477076v1_genomic.fna.gz
#
# sent 42 bytes  received 1210528 bytes  807046.67 bytes/sec
# total size is 1210126  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770745.1_ASM477074v1_genomic.fna.gz
#
# sent 42 bytes  received 1191241 bytes  794188.67 bytes/sec
# total size is 1190839  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769575.1_ASM476957v1_genomic.fna.gz
#
# sent 42 bytes  received 1183039 bytes  788720.67 bytes/sec
# total size is 1182637  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811875.1_ASM281187v1_genomic.fna.gz
#
# sent 42 bytes  received 1189581 bytes  793082.00 bytes/sec
# total size is 1189179  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770035.1_ASM477003v1_genomic.fna.gz
#
# sent 42 bytes  received 1467280 bytes  978214.67 bytes/sec
# total size is 1466814  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003114855.1_ASM311485v1_genomic.fna.gz
#
# sent 42 bytes  received 1173617 bytes  782439.33 bytes/sec
# total size is 1173223  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002811765.1_ASM281176v1_genomic.fna.gz
#
# sent 42 bytes  received 1206094 bytes  804090.67 bytes/sec
# total size is 1205692  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000313175.2_ASM31317v2_genomic.fna.gz
#
# sent 42 bytes  received 1163695 bytes  775824.67 bytes/sec
# total size is 1163302  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_004769615.1_ASM476961v1_genomic.fna.gz
#
# sent 42 bytes  received 1293778 bytes  862546.67 bytes/sec
# total size is 1293352  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004769405.1_ASM476940v1_genomic.fna.gz
#
# sent 42 bytes  received 1237738 bytes  825186.67 bytes/sec
# total size is 1237328  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_004770055.1_ASM477005v1_genomic.fna.gz
#
# sent 42 bytes  received 1169389 bytes  779620.67 bytes/sec
# total size is 1168995  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000347035.1_gls454192v01_genomic.fna.gz
#
# sent 42 bytes  received 1239149 bytes  826127.33 bytes/sec
# total size is 1238738  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003545885.1_ASM354588v1_genomic.fna.gz
#
# sent 42 bytes  received 1420180 bytes  946814.67 bytes/sec
# total size is 1419722  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000332495.2_gls454203v02_genomic.fna.gz
#
# sent 42 bytes  received 1209529 bytes  806380.67 bytes/sec
# total size is 1209126  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_001729245.1_ASM172924v1_genomic.fna.gz
#
# sent 42 bytes  received 1343708 bytes  895833.33 bytes/sec
# total size is 1343274  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000332455.2_gls454199v02_genomic.fna.gz
#
# sent 42 bytes  received 1255096 bytes  836758.67 bytes/sec
# total size is 1254677  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_002150035.1_ASM215003v1_genomic.fna.gz
#
# sent 42 bytes  received 1273277 bytes  848879.33 bytes/sec
# total size is 1272859  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000244815.3_gls454188v02_genomic.fna.gz
#
# sent 42 bytes  received 1273266 bytes  848872.00 bytes/sec
# total size is 1272847  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000332515.2_gls454195v02_genomic.fna.gz
#
# sent 42 bytes  received 1206267 bytes  804206.00 bytes/sec
# total size is 1205864  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_000306115.2_gls454061v02_genomic.fna.gz
#
# sent 42 bytes  received 1301152 bytes  867462.67 bytes/sec
# total size is 1300725  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000332475.2_gls454202v02_genomic.fna.gz
#
# sent 42 bytes  received 1195500 bytes  797028.00 bytes/sec
# total size is 1195097  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003545925.1_ASM354592v1_genomic.fna.gz
#
# sent 42 bytes  received 1303185 bytes  868818.00 bytes/sec
# total size is 1302759  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5484051 ("sim_Leptospira_adleri_GCF_002811985") has been submitted
# Your job 5484052 ("sim_Leptospira_alexanderi_GCF_000243815") has been submitted
# Your job 5484053 ("sim_Leptospira_alstonii_GCF_000347175") has been submitted
# Your job 5484054 ("sim_Leptospira_andrefontaineae_GCF_004770105") has been submitted
# Your job 5484055 ("sim_Leptospira_bandrabouensis_GCF_004770905") has been submitted
# Your job 5484056 ("sim_Leptospira_barantonii_GCF_002811925") has been submitted
# Your job 5484057 ("sim_Leptospira_biflexa_GCF_000017685") has been submitted
# Your job 5484058 ("sim_Leptospira_borgpetersenii_GCF_000013945") has been submitted
# Your job 5484059 ("sim_Leptospira_bourretii_GCF_004769285") has been submitted
# Your job 5484060 ("sim_Leptospira_bouyouniensis_GCF_004770625") has been submitted
# Your job 5484061 ("sim_Leptospira_brenneri_GCF_002812125") has been submitted
# Your job 5484062 ("sim_Leptospira_broomii_GCF_000243715") has been submitted
# Your job 5484063 ("sim_Leptospira_congkakensis_GCF_004770265") has been submitted
# Your job 5484064 ("sim_Leptospira_dzianensis_GCF_004770135") has been submitted
# Your job 5484065 ("sim_Leptospira_dzoumogneensis_GCF_004770895") has been submitted
# Your job 5484066 ("sim_Leptospira_ellinghausenii_GCF_003114815") has been submitted
# Your job 5484067 ("sim_Leptospira_elllisii_GCF_002811955") has been submitted
# Your job 5484068 ("sim_Leptospira_fainei_GCF_000306235") has been submitted
# Your job 5484069 ("sim_Leptospira_fletcheri_GCF_004769195") has been submitted
# Your job 5484070 ("sim_Leptospira_fluminis_GCF_004771275") has been submitted
# Your job 5484071 ("sim_Leptospira_gomenensis_GCF_004770155") has been submitted
# Your job 5484072 ("sim_Leptospira_haakeii_GCF_002812045") has been submitted
# Your job 5484073 ("sim_Leptospira_harrisiae_GCF_002811945") has been submitted
# Your job 5484074 ("sim_Leptospira_hartskeerlii_GCF_002811475") has been submitted
# Your job 5484075 ("sim_Leptospira_idonii_GCF_004770995") has been submitted
# Your job 5484076 ("sim_Leptospira_ilyithenensis_GCF_004771005") has been submitted
# Your job 5484077 ("sim_Leptospira_inadai_GCF_000243675") has been submitted
# Your job 5484078 ("sim_Leptospira_jelokensis_GCF_004769775") has been submitted
# Your job 5484079 ("sim_Leptospira_johnsonii_GCF_003112675") has been submitted
# Your job 5484080 ("sim_Leptospira_kanakyensis_GCF_004769235") has been submitted
# Your job 5484081 ("sim_Leptospira_kemamanensis_GCF_004769665") has been submitted
# Your job 5484082 ("sim_Leptospira_kirschneri_GCF_000243695") has been submitted
# Your job 5484083 ("sim_Leptospira_kmetyi_GCF_000243735") has been submitted
# Your job 5484084 ("sim_Leptospira_kobayashii_GCF_003114835") has been submitted
# Your job 5484085 ("sim_Leptospira_koniamboensis_GCF_004769555") has been submitted
# Your job 5484086 ("sim_Leptospira_langatensis_GCF_004770615") has been submitted
# Your job 5484087 ("sim_Leptospira_levettii_GCF_002812085") has been submitted
# Your job 5484088 ("sim_Leptospira_licerasiae_GCF_000244755") has been submitted
# Your job 5484089 ("sim_Leptospira_macculloughii_GCF_002811975") has been submitted
# Your job 5484090 ("sim_Leptospira_mayottensis_GCF_000306675") has been submitted
# Your job 5484091 ("sim_Leptospira_meyeri_GCF_000304275") has been submitted
# Your job 5484092 ("sim_Leptospira_montravelensis_GCF_004769455") has been submitted
# Your job 5484093 ("sim_Leptospira_mtsangambouensis_GCF_004770475") has been submitted
# Your job 5484094 ("sim_Leptospira_neocaledonica_GCF_002812205") has been submitted
# Your job 5484095 ("sim_Leptospira_noguchii_GCF_000306255") has been submitted
# Your job 5484096 ("sim_Leptospira_noumeaensis_GCF_004770765") has been submitted
# Your job 5484097 ("sim_Leptospira_ognonensis_GCF_004770745") has been submitted
# Your job 5484098 ("sim_Leptospira_perdikensis_GCF_004769575") has been submitted
# Your job 5484099 ("sim_Leptospira_perolatii_GCF_002811875") has been submitted
# Your job 5484100 ("sim_Leptospira_putramalaysiae_GCF_004770035") has been submitted
# Your job 5484101 ("sim_Leptospira_ryugenii_GCF_003114855") has been submitted
# Your job 5484102 ("sim_Leptospira_saintgironsiae_GCF_002811765") has been submitted
# Your job 5484103 ("sim_Leptospira_santarosai_GCF_000313175") has been submitted
# Your job 5484104 ("sim_Leptospira_sarikeiensis_GCF_004769615") has been submitted
# Your job 5484105 ("sim_Leptospira_selangorensis_GCF_004769405") has been submitted
# Your job 5484106 ("sim_Leptospira_semungkisensis_GCF_004770055") has been submitted
# Your job 5484107 ("sim_Leptospira_sp_GCF_000347035") has been submitted
# Your job 5484108 ("sim_Leptospira_stimsonii_GCF_003545885") has been submitted
# Your job 5484109 ("sim_Leptospira_terpstrae_GCF_000332495") has been submitted
# Your job 5484110 ("sim_Leptospira_tipperaryensis_GCF_001729245") has been submitted
# Your job 5484111 ("sim_Leptospira_vanthielii_GCF_000332455") has been submitted
# Your job 5484112 ("sim_Leptospira_venezuelensis_GCF_002150035") has been submitted
# Your job 5484113 ("sim_Leptospira_weilii_GCF_000244815") has been submitted
# Your job 5484114 ("sim_Leptospira_wolbachii_GCF_000332515") has been submitted
# Your job 5484115 ("sim_Leptospira_wolffii_GCF_000306115") has been submitted
# Your job 5484116 ("sim_Leptospira_yanagawae_GCF_000332475") has been submitted
# Your job 5484117 ("sim_Leptospira_yasudae_GCF_003545925") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/leptospira/cleaned_genomes/Leptospira_interrogans_GCF_000092565_formatted.fas path=results/phyluce/leptospira/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5484118 ("map_Leptospira_adleri_GCF_002811985") has been submitted
# Your job 5484119 ("map_Leptospira_alexanderi_GCF_000243815") has been submitted
# Your job 5484120 ("map_Leptospira_alstonii_GCF_000347175") has been submitted
# Your job 5484121 ("map_Leptospira_andrefontaineae_GCF_004770105") has been submitted
# Your job 5484122 ("map_Leptospira_bandrabouensis_GCF_004770905") has been submitted
# Your job 5484123 ("map_Leptospira_barantonii_GCF_002811925") has been submitted
# Your job 5484124 ("map_Leptospira_biflexa_GCF_000017685") has been submitted
# Your job 5484125 ("map_Leptospira_borgpetersenii_GCF_000013945") has been submitted
# Your job 5484126 ("map_Leptospira_bourretii_GCF_004769285") has been submitted
# Your job 5484127 ("map_Leptospira_bouyouniensis_GCF_004770625") has been submitted
# Your job 5484128 ("map_Leptospira_brenneri_GCF_002812125") has been submitted
# Your job 5484129 ("map_Leptospira_broomii_GCF_000243715") has been submitted
# Your job 5484130 ("map_Leptospira_congkakensis_GCF_004770265") has been submitted
# Your job 5484131 ("map_Leptospira_dzianensis_GCF_004770135") has been submitted
# Your job 5484132 ("map_Leptospira_dzoumogneensis_GCF_004770895") has been submitted
# Your job 5484133 ("map_Leptospira_ellinghausenii_GCF_003114815") has been submitted
# Your job 5484134 ("map_Leptospira_elllisii_GCF_002811955") has been submitted
# Your job 5484135 ("map_Leptospira_fainei_GCF_000306235") has been submitted
# Your job 5484136 ("map_Leptospira_fletcheri_GCF_004769195") has been submitted
# Your job 5484137 ("map_Leptospira_fluminis_GCF_004771275") has been submitted
# Your job 5484138 ("map_Leptospira_gomenensis_GCF_004770155") has been submitted
# Your job 5484139 ("map_Leptospira_haakeii_GCF_002812045") has been submitted
# Your job 5484140 ("map_Leptospira_harrisiae_GCF_002811945") has been submitted
# Your job 5484141 ("map_Leptospira_hartskeerlii_GCF_002811475") has been submitted
# Your job 5484142 ("map_Leptospira_idonii_GCF_004770995") has been submitted
# Your job 5484143 ("map_Leptospira_ilyithenensis_GCF_004771005") has been submitted
# Your job 5484144 ("map_Leptospira_inadai_GCF_000243675") has been submitted
# Your job 5484145 ("map_Leptospira_jelokensis_GCF_004769775") has been submitted
# Your job 5484146 ("map_Leptospira_johnsonii_GCF_003112675") has been submitted
# Your job 5484147 ("map_Leptospira_kanakyensis_GCF_004769235") has been submitted
# Your job 5484148 ("map_Leptospira_kemamanensis_GCF_004769665") has been submitted
# Your job 5484149 ("map_Leptospira_kirschneri_GCF_000243695") has been submitted
# Your job 5484150 ("map_Leptospira_kmetyi_GCF_000243735") has been submitted
# Your job 5484151 ("map_Leptospira_kobayashii_GCF_003114835") has been submitted
# Your job 5484152 ("map_Leptospira_koniamboensis_GCF_004769555") has been submitted
# Your job 5484153 ("map_Leptospira_langatensis_GCF_004770615") has been submitted
# Your job 5484154 ("map_Leptospira_levettii_GCF_002812085") has been submitted
# Your job 5484155 ("map_Leptospira_licerasiae_GCF_000244755") has been submitted
# Your job 5484156 ("map_Leptospira_macculloughii_GCF_002811975") has been submitted
# Your job 5484157 ("map_Leptospira_mayottensis_GCF_000306675") has been submitted
# Your job 5484158 ("map_Leptospira_meyeri_GCF_000304275") has been submitted
# Your job 5484159 ("map_Leptospira_montravelensis_GCF_004769455") has been submitted
# Your job 5484160 ("map_Leptospira_mtsangambouensis_GCF_004770475") has been submitted
# Your job 5484161 ("map_Leptospira_neocaledonica_GCF_002812205") has been submitted
# Your job 5484162 ("map_Leptospira_noguchii_GCF_000306255") has been submitted
# Your job 5484163 ("map_Leptospira_noumeaensis_GCF_004770765") has been submitted
# Your job 5484164 ("map_Leptospira_ognonensis_GCF_004770745") has been submitted
# Your job 5484165 ("map_Leptospira_perdikensis_GCF_004769575") has been submitted
# Your job 5484166 ("map_Leptospira_perolatii_GCF_002811875") has been submitted
# Your job 5484167 ("map_Leptospira_putramalaysiae_GCF_004770035") has been submitted
# Your job 5484168 ("map_Leptospira_ryugenii_GCF_003114855") has been submitted
# Your job 5484169 ("map_Leptospira_saintgironsiae_GCF_002811765") has been submitted
# Your job 5484170 ("map_Leptospira_santarosai_GCF_000313175") has been submitted
# Your job 5484171 ("map_Leptospira_sarikeiensis_GCF_004769615") has been submitted
# Your job 5484172 ("map_Leptospira_selangorensis_GCF_004769405") has been submitted
# Your job 5484173 ("map_Leptospira_semungkisensis_GCF_004770055") has been submitted
# Your job 5484174 ("map_Leptospira_sp_GCF_000347035") has been submitted
# Your job 5484175 ("map_Leptospira_stimsonii_GCF_003545885") has been submitted
# Your job 5484176 ("map_Leptospira_terpstrae_GCF_000332495") has been submitted
# Your job 5484177 ("map_Leptospira_tipperaryensis_GCF_001729245") has been submitted
# Your job 5484178 ("map_Leptospira_vanthielii_GCF_000332455") has been submitted
# Your job 5484179 ("map_Leptospira_venezuelensis_GCF_002150035") has been submitted
# Your job 5484180 ("map_Leptospira_weilii_GCF_000244815") has been submitted
# Your job 5484181 ("map_Leptospira_wolbachii_GCF_000332515") has been submitted
# Your job 5484182 ("map_Leptospira_wolffii_GCF_000306115") has been submitted
# Your job 5484183 ("map_Leptospira_yanagawae_GCF_000332475") has been submitted
# Your job 5484184 ("map_Leptospira_yasudae_GCF_003545925") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5484185 ("merge_Leptospira_adleri_GCF_002811985") has been submitted
# Your job 5484186 ("merge_Leptospira_alexanderi_GCF_000243815") has been submitted
# Your job 5484187 ("merge_Leptospira_alstonii_GCF_000347175") has been submitted
# Your job 5484188 ("merge_Leptospira_andrefontaineae_GCF_004770105") has been submitted
# Your job 5484189 ("merge_Leptospira_bandrabouensis_GCF_004770905") has been submitted
# Your job 5484190 ("merge_Leptospira_barantonii_GCF_002811925") has been submitted
# Your job 5484191 ("merge_Leptospira_biflexa_GCF_000017685") has been submitted
# Your job 5484192 ("merge_Leptospira_borgpetersenii_GCF_000013945") has been submitted
# Your job 5484193 ("merge_Leptospira_bourretii_GCF_004769285") has been submitted
# Your job 5484194 ("merge_Leptospira_bouyouniensis_GCF_004770625") has been submitted
# Your job 5484195 ("merge_Leptospira_brenneri_GCF_002812125") has been submitted
# Your job 5484196 ("merge_Leptospira_broomii_GCF_000243715") has been submitted
# Your job 5484197 ("merge_Leptospira_congkakensis_GCF_004770265") has been submitted
# Your job 5484198 ("merge_Leptospira_dzianensis_GCF_004770135") has been submitted
# Your job 5484199 ("merge_Leptospira_dzoumogneensis_GCF_004770895") has been submitted
# Your job 5484200 ("merge_Leptospira_ellinghausenii_GCF_003114815") has been submitted
# Your job 5484201 ("merge_Leptospira_elllisii_GCF_002811955") has been submitted
# Your job 5484202 ("merge_Leptospira_fainei_GCF_000306235") has been submitted
# Your job 5484203 ("merge_Leptospira_fletcheri_GCF_004769195") has been submitted
# Your job 5484204 ("merge_Leptospira_fluminis_GCF_004771275") has been submitted
# Your job 5484205 ("merge_Leptospira_gomenensis_GCF_004770155") has been submitted
# Your job 5484206 ("merge_Leptospira_haakeii_GCF_002812045") has been submitted
# Your job 5484207 ("merge_Leptospira_harrisiae_GCF_002811945") has been submitted
# Your job 5484208 ("merge_Leptospira_hartskeerlii_GCF_002811475") has been submitted
# Your job 5484209 ("merge_Leptospira_idonii_GCF_004770995") has been submitted
# Your job 5484210 ("merge_Leptospira_ilyithenensis_GCF_004771005") has been submitted
# Your job 5484211 ("merge_Leptospira_inadai_GCF_000243675") has been submitted
# Your job 5484212 ("merge_Leptospira_jelokensis_GCF_004769775") has been submitted
# Your job 5484213 ("merge_Leptospira_johnsonii_GCF_003112675") has been submitted
# Your job 5484214 ("merge_Leptospira_kanakyensis_GCF_004769235") has been submitted
# Your job 5484215 ("merge_Leptospira_kemamanensis_GCF_004769665") has been submitted
# Your job 5484216 ("merge_Leptospira_kirschneri_GCF_000243695") has been submitted
# Your job 5484217 ("merge_Leptospira_kmetyi_GCF_000243735") has been submitted
# Your job 5484218 ("merge_Leptospira_kobayashii_GCF_003114835") has been submitted
# Your job 5484219 ("merge_Leptospira_koniamboensis_GCF_004769555") has been submitted
# Your job 5484220 ("merge_Leptospira_langatensis_GCF_004770615") has been submitted
# Your job 5484221 ("merge_Leptospira_levettii_GCF_002812085") has been submitted
# Your job 5484222 ("merge_Leptospira_licerasiae_GCF_000244755") has been submitted
# Your job 5484223 ("merge_Leptospira_macculloughii_GCF_002811975") has been submitted
# Your job 5484224 ("merge_Leptospira_mayottensis_GCF_000306675") has been submitted
# Your job 5484225 ("merge_Leptospira_meyeri_GCF_000304275") has been submitted
# Your job 5484226 ("merge_Leptospira_montravelensis_GCF_004769455") has been submitted
# Your job 5484227 ("merge_Leptospira_mtsangambouensis_GCF_004770475") has been submitted
# Your job 5484228 ("merge_Leptospira_neocaledonica_GCF_002812205") has been submitted
# Your job 5484229 ("merge_Leptospira_noguchii_GCF_000306255") has been submitted
# Your job 5484230 ("merge_Leptospira_noumeaensis_GCF_004770765") has been submitted
# Your job 5484231 ("merge_Leptospira_ognonensis_GCF_004770745") has been submitted
# Your job 5484232 ("merge_Leptospira_perdikensis_GCF_004769575") has been submitted
# Your job 5484233 ("merge_Leptospira_perolatii_GCF_002811875") has been submitted
# Your job 5484234 ("merge_Leptospira_putramalaysiae_GCF_004770035") has been submitted
# Your job 5484235 ("merge_Leptospira_ryugenii_GCF_003114855") has been submitted
# Your job 5484236 ("merge_Leptospira_saintgironsiae_GCF_002811765") has been submitted
# Your job 5484237 ("merge_Leptospira_santarosai_GCF_000313175") has been submitted
# Your job 5484238 ("merge_Leptospira_sarikeiensis_GCF_004769615") has been submitted
# Your job 5484239 ("merge_Leptospira_selangorensis_GCF_004769405") has been submitted
# Your job 5484240 ("merge_Leptospira_semungkisensis_GCF_004770055") has been submitted
# Your job 5484241 ("merge_Leptospira_sp_GCF_000347035") has been submitted
# Your job 5484242 ("merge_Leptospira_stimsonii_GCF_003545885") has been submitted
# Your job 5484243 ("merge_Leptospira_terpstrae_GCF_000332495") has been submitted
# Your job 5484244 ("merge_Leptospira_tipperaryensis_GCF_001729245") has been submitted
# Your job 5484245 ("merge_Leptospira_vanthielii_GCF_000332455") has been submitted
# Your job 5484246 ("merge_Leptospira_venezuelensis_GCF_002150035") has been submitted
# Your job 5484247 ("merge_Leptospira_weilii_GCF_000244815") has been submitted
# Your job 5484248 ("merge_Leptospira_wolbachii_GCF_000332515") has been submitted
# Your job 5484249 ("merge_Leptospira_wolffii_GCF_000306115") has been submitted
# Your job 5484250 ("merge_Leptospira_yanagawae_GCF_000332475") has been submitted
# Your job 5484251 ("merge_Leptospira_yasudae_GCF_003545925") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 913 sequences from Leptospira_adleri_GCF_002811985_merged.bed.  Filtered 630 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 283.
# Screened 2402 sequences from Leptospira_alexanderi_GCF_000243815_merged.bed.  Filtered 1640 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 762.
# Screened 2609 sequences from Leptospira_alstonii_GCF_000347175_merged.bed.  Filtered 1806 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 803.
# Screened 50 sequences from Leptospira_andrefontaineae_GCF_004770105_merged.bed.  Filtered 44 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 24 sequences from Leptospira_bandrabouensis_GCF_004770905_merged.bed.  Filtered 17 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 1492 sequences from Leptospira_barantonii_GCF_002811925_merged.bed.  Filtered 1000 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 492.
# Screened 21 sequences from Leptospira_biflexa_GCF_000017685_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 2155 sequences from Leptospira_borgpetersenii_GCF_000013945_merged.bed.  Filtered 1510 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 645.
# Screened 19 sequences from Leptospira_bourretii_GCF_004769285_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 23 sequences from Leptospira_bouyouniensis_GCF_004770625_merged.bed.  Filtered 16 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 21 sequences from Leptospira_brenneri_GCF_002812125_merged.bed.  Filtered 14 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 36 sequences from Leptospira_broomii_GCF_000243715_merged.bed.  Filtered 28 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 8.
# Screened 20 sequences from Leptospira_congkakensis_GCF_004770265_merged.bed.  Filtered 13 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 1173 sequences from Leptospira_dzianensis_GCF_004770135_merged.bed.  Filtered 761 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 412.
# Screened 53 sequences from Leptospira_dzoumogneensis_GCF_004770895_merged.bed.  Filtered 46 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 22 sequences from Leptospira_ellinghausenii_GCF_003114815_merged.bed.  Filtered 16 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 639 sequences from Leptospira_elllisii_GCF_002811955_merged.bed.  Filtered 412 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 227.
# Screened 40 sequences from Leptospira_fainei_GCF_000306235_merged.bed.  Filtered 34 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 35 sequences from Leptospira_fletcheri_GCF_004769195_merged.bed.  Filtered 28 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 40 sequences from Leptospira_fluminis_GCF_004771275_merged.bed.  Filtered 33 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 679 sequences from Leptospira_gomenensis_GCF_004770155_merged.bed.  Filtered 455 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 224.
# Screened 45 sequences from Leptospira_haakeii_GCF_002812045_merged.bed.  Filtered 42 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 3.
# Screened 24 sequences from Leptospira_harrisiae_GCF_002811945_merged.bed.  Filtered 18 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 48 sequences from Leptospira_hartskeerlii_GCF_002811475_merged.bed.  Filtered 42 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 30 sequences from Leptospira_idonii_GCF_004770995_merged.bed.  Filtered 18 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 12.
# Screened 28 sequences from Leptospira_ilyithenensis_GCF_004771005_merged.bed.  Filtered 19 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 34 sequences from Leptospira_inadai_GCF_000243675_merged.bed.  Filtered 25 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 20 sequences from Leptospira_jelokensis_GCF_004769775_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 8.
# Screened 45 sequences from Leptospira_johnsonii_GCF_003112675_merged.bed.  Filtered 39 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 25 sequences from Leptospira_kanakyensis_GCF_004769235_merged.bed.  Filtered 18 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 23 sequences from Leptospira_kemamanensis_GCF_004769665_merged.bed.  Filtered 17 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 4862 sequences from Leptospira_kirschneri_GCF_000243695_merged.bed.  Filtered 1114 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 3748.
# Screened 1428 sequences from Leptospira_kmetyi_GCF_000243735_merged.bed.  Filtered 934 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 494.
# Screened 28 sequences from Leptospira_kobayashii_GCF_003114835_merged.bed.  Filtered 23 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 5.
# Screened 39 sequences from Leptospira_koniamboensis_GCF_004769555_merged.bed.  Filtered 33 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 34 sequences from Leptospira_langatensis_GCF_004770615_merged.bed.  Filtered 27 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 19 sequences from Leptospira_levettii_GCF_002812085_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 48 sequences from Leptospira_licerasiae_GCF_000244755_merged.bed.  Filtered 41 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 27 sequences from Leptospira_macculloughii_GCF_002811975_merged.bed.  Filtered 21 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 2225 sequences from Leptospira_mayottensis_GCF_000306675_merged.bed.  Filtered 1531 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 694.
# Screened 25 sequences from Leptospira_meyeri_GCF_000304275_merged.bed.  Filtered 16 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 19 sequences from Leptospira_montravelensis_GCF_004769455_merged.bed.  Filtered 12 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 24 sequences from Leptospira_mtsangambouensis_GCF_004770475_merged.bed.  Filtered 17 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 51 sequences from Leptospira_neocaledonica_GCF_002812205_merged.bed.  Filtered 43 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 8.
# Screened 6267 sequences from Leptospira_noguchii_GCF_000306255_merged.bed.  Filtered 1625 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 4642.
# Screened 22 sequences from Leptospira_noumeaensis_GCF_004770765_merged.bed.  Filtered 15 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 18 sequences from Leptospira_ognonensis_GCF_004770745_merged.bed.  Filtered 11 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 21 sequences from Leptospira_perdikensis_GCF_004769575_merged.bed.  Filtered 13 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 8.
# Screened 40 sequences from Leptospira_perolatii_GCF_002811875_merged.bed.  Filtered 36 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 4.
# Screened 886 sequences from Leptospira_putramalaysiae_GCF_004770035_merged.bed.  Filtered 607 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 279.
# Screened 16 sequences from Leptospira_ryugenii_GCF_003114855_merged.bed.  Filtered 10 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 52 sequences from Leptospira_saintgironsiae_GCF_002811765_merged.bed.  Filtered 47 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 5.
# Screened 2037 sequences from Leptospira_santarosai_GCF_000313175_merged.bed.  Filtered 1443 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 594.
# Screened 55 sequences from Leptospira_sarikeiensis_GCF_004769615_merged.bed.  Filtered 49 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 49 sequences from Leptospira_selangorensis_GCF_004769405_merged.bed.  Filtered 43 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 6.
# Screened 44 sequences from Leptospira_semungkisensis_GCF_004770055_merged.bed.  Filtered 37 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 41 sequences from Leptospira_sp_GCF_000347035_merged.bed.  Filtered 34 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 7.
# Screened 897 sequences from Leptospira_stimsonii_GCF_003545885_merged.bed.  Filtered 608 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 289.
# Screened 40 sequences from Leptospira_terpstrae_GCF_000332495_merged.bed.  Filtered 20 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 20.
# Screened 1035 sequences from Leptospira_tipperaryensis_GCF_001729245_merged.bed.  Filtered 737 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 298.
# Screened 24 sequences from Leptospira_vanthielii_GCF_000332455_merged.bed.  Filtered 15 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 40 sequences from Leptospira_venezuelensis_GCF_002150035_merged.bed.  Filtered 35 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 5.
# Screened 2215 sequences from Leptospira_weilii_GCF_000244815_merged.bed.  Filtered 1539 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 676.
# Screened 23 sequences from Leptospira_wolbachii_GCF_000332515_merged.bed.  Filtered 14 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 9.
# Screened 53 sequences from Leptospira_wolffii_GCF_000306115_merged.bed.  Filtered 40 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 13.
# Screened 47 sequences from Leptospira_yanagawae_GCF_000332475_merged.bed.  Filtered 29 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 18.
# Screened 1227 sequences from Leptospira_yasudae_GCF_003545925_merged.bed.  Filtered 815 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 412.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/leptospira/initial_intervals/Leptospira_yasudae_GCF_003545925_merged.bed --twobit results/phyluce/leptospira/cleaned_genomes/Leptospira_interrogans_GCF_000092565_formatted.2bit --output results/phyluce/leptospira/initial_intervals/Leptospira_yasudae_GCF_003545925_stripped.bed;
# leptospira_adleri_gcf_002811985.
# leptospira_alexanderi_gcf_000243815.
# leptospira_alstonii_gcf_000347175.
# leptospira_andrefontaineae_gcf_004770105.
# leptospira_bandrabouensis_gcf_004770905.
# leptospira_barantonii_gcf_002811925.
# leptospira_biflexa_gcf_000017685.
# leptospira_borgpetersenii_gcf_000013945.
# leptospira_bourretii_gcf_004769285.
# leptospira_bouyouniensis_gcf_004770625.
# leptospira_brenneri_gcf_002812125.
# leptospira_broomii_gcf_000243715.
# leptospira_congkakensis_gcf_004770265.
# leptospira_dzianensis_gcf_004770135.
# leptospira_dzoumogneensis_gcf_004770895.
# leptospira_ellinghausenii_gcf_003114815.
# leptospira_elllisii_gcf_002811955.
# leptospira_fainei_gcf_000306235.
# leptospira_fletcheri_gcf_004769195.
# leptospira_fluminis_gcf_004771275.
# leptospira_gomenensis_gcf_004770155.
# leptospira_haakeii_gcf_002812045.
# leptospira_harrisiae_gcf_002811945.
# leptospira_hartskeerlii_gcf_002811475.
# leptospira_idonii_gcf_004770995.
# leptospira_ilyithenensis_gcf_004771005.
# leptospira_inadai_gcf_000243675.
# leptospira_jelokensis_gcf_004769775.
# leptospira_johnsonii_gcf_003112675.
# leptospira_kanakyensis_gcf_004769235.
# leptospira_kemamanensis_gcf_004769665.
# leptospira_kirschneri_gcf_000243695....
# leptospira_kmetyi_gcf_000243735.
# leptospira_kobayashii_gcf_003114835.
# leptospira_koniamboensis_gcf_004769555.
# leptospira_langatensis_gcf_004770615.
# leptospira_levettii_gcf_002812085.
# leptospira_licerasiae_gcf_000244755.
# leptospira_macculloughii_gcf_002811975.
# leptospira_mayottensis_gcf_000306675.
# leptospira_meyeri_gcf_000304275.
# leptospira_montravelensis_gcf_004769455.
# leptospira_mtsangambouensis_gcf_004770475.
# leptospira_neocaledonica_gcf_002812205.
# leptospira_noguchii_gcf_000306255.....
# leptospira_noumeaensis_gcf_004770765.
# leptospira_ognonensis_gcf_004770745.
# leptospira_perdikensis_gcf_004769575.
# leptospira_perolatii_gcf_002811875.
# leptospira_putramalaysiae_gcf_004770035.
# leptospira_ryugenii_gcf_003114855.
# leptospira_saintgironsiae_gcf_002811765.
# leptospira_santarosai_gcf_000313175.
# leptospira_sarikeiensis_gcf_004769615.
# leptospira_selangorensis_gcf_004769405.
# leptospira_semungkisensis_gcf_004770055.
# leptospira_sp_gcf_000347035.
# leptospira_stimsonii_gcf_003545885.
# leptospira_terpstrae_gcf_000332495.
# leptospira_tipperaryensis_gcf_001729245.
# leptospira_vanthielii_gcf_000332455.
# leptospira_venezuelensis_gcf_002150035.
# leptospira_weilii_gcf_000244815.
# leptospira_wolbachii_gcf_000332515.
# leptospira_wolffii_gcf_000306115.
# leptospira_yanagawae_gcf_000332475.
# leptospira_yasudae_gcf_003545925.
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/leptospira/initial_intervals/Leptospira_yasudae_GCF_003545925_merged.bed --twobit results/phyluce/leptospira/cleaned_genomes/Leptospira_interrogans_GCF_000092565_formatted.2bit --output results/phyluce/leptospira/initial_intervals/Leptospira_yasudae_GCF_003545925_stripped.bed;
# Loci shared by Leptospira_interrogans_GCF_000092565 + 0 taxa:	5,335.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 1 taxa:	5,335.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 2 taxa:	3,863.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 3 taxa:	1,553.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 4 taxa:	1,072.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 5 taxa:	812.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 6 taxa:	660.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 7 taxa:	570.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 8 taxa:	466.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 9 taxa:	400.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 10 taxa:	356.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 11 taxa:	320.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 12 taxa:	281.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 13 taxa:	240.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 14 taxa:	208.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 15 taxa:	182.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 16 taxa:	158.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 17 taxa:	127.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 18 taxa:	87.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 19 taxa:	10.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 20 taxa:	7.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 21 taxa:	6.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 22 taxa:	6.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 23 taxa:	6.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 24 taxa:	4.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 25 taxa:	4.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 26 taxa:	4.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 27 taxa:	3.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 28 taxa:	3.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 29 taxa:	3.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 30 taxa:	3.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 31 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 32 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 33 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 34 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 35 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 36 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 37 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 38 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 39 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 40 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 41 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 42 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 43 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 44 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 45 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 46 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 47 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 48 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 49 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 50 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 51 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 52 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 53 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 54 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 55 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 56 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 57 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 58 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 59 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 60 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 61 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 62 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 63 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 64 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 65 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 66 taxa:	2.0
# Loci shared by Leptospira_interrogans_GCF_000092565 + 67 taxa:	2.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 10
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/leptospira/initial_intervals/leptospira-to-Leptospira_interrogans_GCF_000092565.sqlite --base-taxon Leptospira_interrogans_GCF_000092565 --output results/phyluce/leptospira/initial_intervals/Leptospira_interrogans_GCF_000092565_+10.bed --specific-counts 10;
# Counter({'leptospira_noguchii_gcf_000306255': 353, 'leptospira_kirschneri_gcf_000243695': 352, 'leptospira_alstonii_gcf_000347175': 318, 'leptospira_weilii_gcf_000244815': 315, 'leptospira_kmetyi_gcf_000243735': 314, 'leptospira_dzianensis_gcf_004770135': 312, 'leptospira_yasudae_gcf_003545925': 311, 'leptospira_mayottensis_gcf_000306675': 308, 'leptospira_alexanderi_gcf_000243815': 306, 'leptospira_barantonii_gcf_002811925': 301, 'leptospira_santarosai_gcf_000313175': 300, 'leptospira_borgpetersenii_gcf_000013945': 298, 'leptospira_putramalaysiae_gcf_004770035': 246, 'leptospira_stimsonii_gcf_003545885': 244, 'leptospira_tipperaryensis_gcf_001729245': 233, 'leptospira_adleri_gcf_002811985': 228, 'leptospira_elllisii_gcf_002811955': 208, 'leptospira_gomenensis_gcf_004770155': 196, 'leptospira_neocaledonica_gcf_002812205': 7, 'leptospira_licerasiae_gcf_000244755': 6, 'leptospira_langatensis_gcf_004770615': 6, 'leptospira_andrefontaineae_gcf_004770105': 5, 'leptospira_hartskeerlii_gcf_002811475': 5, 'leptospira_dzoumogneensis_gcf_004770895': 5, 'leptospira_johnsonii_gcf_003112675': 4, 'leptospira_sp_gcf_000347035': 4, 'leptospira_fletcheri_gcf_004769195': 4, 'leptospira_semungkisensis_gcf_004770055': 4, 'leptospira_meyeri_gcf_000304275': 4, 'leptospira_saintgironsiae_gcf_002811765': 4, 'leptospira_fainei_gcf_000306235': 4, 'leptospira_levettii_gcf_002812085': 4, 'leptospira_vanthielii_gcf_000332455': 4, 'leptospira_idonii_gcf_004770995': 4, 'leptospira_jelokensis_gcf_004769775': 3, 'leptospira_selangorensis_gcf_004769405': 3, 'leptospira_broomii_gcf_000243715': 3, 'leptospira_inadai_gcf_000243675': 3, 'leptospira_terpstrae_gcf_000332495': 3, 'leptospira_koniamboensis_gcf_004769555': 3, 'leptospira_wolbachii_gcf_000332515': 3, 'leptospira_perolatii_gcf_002811875': 3, 'leptospira_macculloughii_gcf_002811975': 3, 'leptospira_sarikeiensis_gcf_004769615': 3, 'leptospira_ilyithenensis_gcf_004771005': 3, 'leptospira_wolffii_gcf_000306115': 3, 'leptospira_fluminis_gcf_004771275': 3, 'leptospira_ellinghausenii_gcf_003114815': 2, 'leptospira_venezuelensis_gcf_002150035': 2, 'leptospira_bouyouniensis_gcf_004770625': 2, 'leptospira_ryugenii_gcf_003114855': 2, 'leptospira_kobayashii_gcf_003114835': 2, 'leptospira_yanagawae_gcf_000332475': 2, 'leptospira_congkakensis_gcf_004770265': 2, 'leptospira_ognonensis_gcf_004770745': 2, 'leptospira_mtsangambouensis_gcf_004770475': 2, 'leptospira_bourretii_gcf_004769285': 2, 'leptospira_kemamanensis_gcf_004769665': 2, 'leptospira_kanakyensis_gcf_004769235': 2, 'leptospira_haakeii_gcf_002812045': 2, 'leptospira_montravelensis_gcf_004769455': 2, 'leptospira_noumeaensis_gcf_004770765': 2, 'leptospira_biflexa_gcf_000017685': 2, 'leptospira_bandrabouensis_gcf_004770905': 2, 'leptospira_brenneri_gcf_002812125': 2, 'leptospira_harrisiae_gcf_002811945': 2, 'leptospira_perdikensis_gcf_004769575': 2})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/leptospira/initial_intervals/Leptospira_interrogans_GCF_000092565_+10.bed --twobit results/phyluce/leptospira/cleaned_genomes/Leptospira_interrogans_GCF_000092565_formatted.2bit --buffer-to 160 --output results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10.fasta;
# Screened 356 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 356.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10.fasta --probe-prefix uce_leptospira_ --design leptospira_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGGGGGGGG
#
#
# Conserved locus count = 354
# Probe Count = 702

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas --query results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  13:12:57
# Ended:  Fri Feb 07, 2020  13:12:57
# Time for execution:  0.00522816578547 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas                        --lastz results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes_vself.lastz                       --probe-prefix=uce_leptospira_;
# Parsing lastz file...
# Screening results...
# Screened 701 fasta sequences.  Filtered 12 duplicates. Kept 678.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/leptospira/validate_intervals/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas --scaffoldlist Leptospira_adleri_GCF_002811985 Leptospira_alexanderi_GCF_000243815 Leptospira_alstonii_GCF_000347175 Leptospira_andrefontaineae_GCF_004770105 Leptospira_bandrabouensis_GCF_004770905 Leptospira_barantonii_GCF_002811925 Leptospira_biflexa_GCF_000017685 Leptospira_borgpetersenii_GCF_000013945 Leptospira_bourretii_GCF_004769285 Leptospira_bouyouniensis_GCF_004770625 Leptospira_brenneri_GCF_002812125 Leptospira_broomii_GCF_000243715 Leptospira_congkakensis_GCF_004770265 Leptospira_dzianensis_GCF_004770135 Leptospira_dzoumogneensis_GCF_004770895 Leptospira_ellinghausenii_GCF_003114815 Leptospira_elllisii_GCF_002811955 Leptospira_fainei_GCF_000306235 Leptospira_fletcheri_GCF_004769195 Leptospira_fluminis_GCF_004771275 Leptospira_gomenensis_GCF_004770155 Leptospira_haakeii_GCF_002812045 Leptospira_harrisiae_GCF_002811945 Leptospira_hartskeerlii_GCF_002811475 Leptospira_idonii_GCF_004770995 Leptospira_ilyithenensis_GCF_004771005 Leptospira_inadai_GCF_000243675 Leptospira_jelokensis_GCF_004769775 Leptospira_johnsonii_GCF_003112675 Leptospira_kanakyensis_GCF_004769235 Leptospira_kemamanensis_GCF_004769665 Leptospira_kirschneri_GCF_000243695 Leptospira_kmetyi_GCF_000243735 Leptospira_kobayashii_GCF_003114835 Leptospira_koniamboensis_GCF_004769555 Leptospira_langatensis_GCF_004770615 Leptospira_levettii_GCF_002812085 Leptospira_licerasiae_GCF_000244755 Leptospira_macculloughii_GCF_002811975 Leptospira_mayottensis_GCF_000306675 Leptospira_meyeri_GCF_000304275 Leptospira_montravelensis_GCF_004769455 Leptospira_mtsangambouensis_GCF_004770475 Leptospira_neocaledonica_GCF_002812205 Leptospira_noguchii_GCF_000306255 Leptospira_noumeaensis_GCF_004770765 Leptospira_ognonensis_GCF_004770745 Leptospira_perdikensis_GCF_004769575 Leptospira_perolatii_GCF_002811875 Leptospira_putramalaysiae_GCF_004770035 Leptospira_ryugenii_GCF_003114855 Leptospira_saintgironsiae_GCF_002811765 Leptospira_santarosai_GCF_000313175 Leptospira_sarikeiensis_GCF_004769615 Leptospira_selangorensis_GCF_004769405 Leptospira_semungkisensis_GCF_004770055 Leptospira_sp_GCF_000347035 Leptospira_stimsonii_GCF_003545885 Leptospira_terpstrae_GCF_000332495 Leptospira_tipperaryensis_GCF_001729245 Leptospira_vanthielii_GCF_000332455 Leptospira_venezuelensis_GCF_002150035 Leptospira_weilii_GCF_000244815 Leptospira_wolbachii_GCF_000332515 Leptospira_wolffii_GCF_000306115 Leptospira_yanagawae_GCF_000332475 Leptospira_yasudae_GCF_003545925 Leptospira_interrogans_GCF_000092565 --genome-base-path results/phyluce/leptospira/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/leptospira/validate_intervals/leptospira-to-Leptospira_interrogans_GCF_000092565.sqlite --output results/phyluce/leptospira/validate_intervals/lastz/;
#
# Running against Leptospira_adleri_GCF_002811985.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp1Mb19U.fasta
#
# Writing the results file...
# 	/tmp/tmpmy7vT3.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_adleri_GCF_002811985.lastz
# Creating Leptospira_adleri_GCF_002811985 table
# Inserting data to Leptospira_adleri_GCF_002811985 table
#
# Running against Leptospira_alexanderi_GCF_000243815.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDguEYt.fasta
#
# Writing the results file...
# 	/tmp/tmpXUtSwR.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_alexanderi_GCF_000243815.lastz
# Creating Leptospira_alexanderi_GCF_000243815 table
# Inserting data to Leptospira_alexanderi_GCF_000243815 table
#
# Running against Leptospira_alstonii_GCF_000347175.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpRZT8yj.fasta
#
# Writing the results file...
# 	/tmp/tmpz2wIyE.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_alstonii_GCF_000347175.lastz
# Creating Leptospira_alstonii_GCF_000347175 table
# Inserting data to Leptospira_alstonii_GCF_000347175 table
#
# Running against Leptospira_andrefontaineae_GCF_004770105.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpZ2T2_D.fasta
#
# Writing the results file...
# 	/tmp/tmpM88o7O.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_andrefontaineae_GCF_004770105.lastz
# Creating Leptospira_andrefontaineae_GCF_004770105 table
# Inserting data to Leptospira_andrefontaineae_GCF_004770105 table
#
# Running against Leptospira_bandrabouensis_GCF_004770905.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpR7Yj_T.fasta
#
# Writing the results file...
# 	/tmp/tmpVJqT2S.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_bandrabouensis_GCF_004770905.lastz
# Creating Leptospira_bandrabouensis_GCF_004770905 table
# Inserting data to Leptospira_bandrabouensis_GCF_004770905 table
#
# Running against Leptospira_barantonii_GCF_002811925.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmplqZSEb.fasta
#
# Writing the results file...
# 	/tmp/tmpsLb0oO.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_barantonii_GCF_002811925.lastz
# Creating Leptospira_barantonii_GCF_002811925 table
# Inserting data to Leptospira_barantonii_GCF_002811925 table
#
# Running against Leptospira_biflexa_GCF_000017685.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmB7adU.fasta
#
# Writing the results file...
# 	/tmp/tmpNz1brs.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_biflexa_GCF_000017685.lastz
# Creating Leptospira_biflexa_GCF_000017685 table
# Inserting data to Leptospira_biflexa_GCF_000017685 table
#
# Running against Leptospira_borgpetersenii_GCF_000013945.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmphajgNU.fasta
#
# Writing the results file...
# 	/tmp/tmpeXzPIa.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_borgpetersenii_GCF_000013945.lastz
# Creating Leptospira_borgpetersenii_GCF_000013945 table
# Inserting data to Leptospira_borgpetersenii_GCF_000013945 table
#
# Running against Leptospira_bourretii_GCF_004769285.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpFqTnyA.fasta
#
# Writing the results file...
# 	/tmp/tmp_qDwfL.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_bourretii_GCF_004769285.lastz
# Creating Leptospira_bourretii_GCF_004769285 table
# Inserting data to Leptospira_bourretii_GCF_004769285 table
#
# Running against Leptospira_bouyouniensis_GCF_004770625.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpVjo6lW.fasta
#
# Writing the results file...
# 	/tmp/tmpTJgfFk.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_bouyouniensis_GCF_004770625.lastz
# Creating Leptospira_bouyouniensis_GCF_004770625 table
# Inserting data to Leptospira_bouyouniensis_GCF_004770625 table
#
# Running against Leptospira_brenneri_GCF_002812125.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp4u1Bej.fasta
#
# Writing the results file...
# 	/tmp/tmpcNfbl7.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_brenneri_GCF_002812125.lastz
# Creating Leptospira_brenneri_GCF_002812125 table
# Inserting data to Leptospira_brenneri_GCF_002812125 table
#
# Running against Leptospira_broomii_GCF_000243715.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpNFQgJn.fasta
#
# Writing the results file...
# 	/tmp/tmpnCFj7f.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_broomii_GCF_000243715.lastz
# Creating Leptospira_broomii_GCF_000243715 table
# Inserting data to Leptospira_broomii_GCF_000243715 table
#
# Running against Leptospira_congkakensis_GCF_004770265.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJDaUOL.fasta
#
# Writing the results file...
# 	/tmp/tmpg6I_ib.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_congkakensis_GCF_004770265.lastz
# Creating Leptospira_congkakensis_GCF_004770265 table
# Inserting data to Leptospira_congkakensis_GCF_004770265 table
#
# Running against Leptospira_dzianensis_GCF_004770135.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpgbr2EM.fasta
#
# Writing the results file...
# 	/tmp/tmpcegLv0.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_dzianensis_GCF_004770135.lastz
# Creating Leptospira_dzianensis_GCF_004770135 table
# Inserting data to Leptospira_dzianensis_GCF_004770135 table
#
# Running against Leptospira_dzoumogneensis_GCF_004770895.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpqrr3dZ.fasta
#
# Writing the results file...
# 	/tmp/tmpuqxYo1.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_dzoumogneensis_GCF_004770895.lastz
# Creating Leptospira_dzoumogneensis_GCF_004770895 table
# Inserting data to Leptospira_dzoumogneensis_GCF_004770895 table
#
# Running against Leptospira_ellinghausenii_GCF_003114815.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpQzBRuj.fasta
#
# Writing the results file...
# 	/tmp/tmpambQXm.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_ellinghausenii_GCF_003114815.lastz
# Creating Leptospira_ellinghausenii_GCF_003114815 table
# Inserting data to Leptospira_ellinghausenii_GCF_003114815 table
#
# Running against Leptospira_elllisii_GCF_002811955.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpK5vlgw.fasta
#
# Writing the results file...
# 	/tmp/tmp0yjaiw.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_elllisii_GCF_002811955.lastz
# Creating Leptospira_elllisii_GCF_002811955 table
# Inserting data to Leptospira_elllisii_GCF_002811955 table
#
# Running against Leptospira_fainei_GCF_000306235.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpPr2nZL.fasta
#
# Writing the results file...
# 	/tmp/tmplVW4Ie.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_fainei_GCF_000306235.lastz
# Creating Leptospira_fainei_GCF_000306235 table
# Inserting data to Leptospira_fainei_GCF_000306235 table
#
# Running against Leptospira_fletcheri_GCF_004769195.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmptEzZuu.fasta
#
# Writing the results file...
# 	/tmp/tmp1VKBqQ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_fletcheri_GCF_004769195.lastz
# Creating Leptospira_fletcheri_GCF_004769195 table
# Inserting data to Leptospira_fletcheri_GCF_004769195 table
#
# Running against Leptospira_fluminis_GCF_004771275.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp2gpDFG.fasta
#
# Writing the results file...
# 	/tmp/tmpFjfpdv.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_fluminis_GCF_004771275.lastz
# Creating Leptospira_fluminis_GCF_004771275 table
# Inserting data to Leptospira_fluminis_GCF_004771275 table
#
# Running against Leptospira_gomenensis_GCF_004770155.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp_NACj9.fasta
#
# Writing the results file...
# 	/tmp/tmp7AP_QO.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_gomenensis_GCF_004770155.lastz
# Creating Leptospira_gomenensis_GCF_004770155 table
# Inserting data to Leptospira_gomenensis_GCF_004770155 table
#
# Running against Leptospira_haakeii_GCF_002812045.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpcR2bz6.fasta
#
# Writing the results file...
# 	/tmp/tmph5IuHJ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_haakeii_GCF_002812045.lastz
# Creating Leptospira_haakeii_GCF_002812045 table
# Inserting data to Leptospira_haakeii_GCF_002812045 table
#
# Running against Leptospira_harrisiae_GCF_002811945.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpgPbBh4.fasta
#
# Writing the results file...
# 	/tmp/tmpCIPvca.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_harrisiae_GCF_002811945.lastz
# Creating Leptospira_harrisiae_GCF_002811945 table
# Inserting data to Leptospira_harrisiae_GCF_002811945 table
#
# Running against Leptospira_hartskeerlii_GCF_002811475.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpi1_335.fasta
#
# Writing the results file...
# 	/tmp/tmp5HIOkc.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_hartskeerlii_GCF_002811475.lastz
# Creating Leptospira_hartskeerlii_GCF_002811475 table
# Inserting data to Leptospira_hartskeerlii_GCF_002811475 table
#
# Running against Leptospira_idonii_GCF_004770995.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJ1gRbP.fasta
#
# Writing the results file...
# 	/tmp/tmpQWGWkS.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_idonii_GCF_004770995.lastz
# Creating Leptospira_idonii_GCF_004770995 table
# Inserting data to Leptospira_idonii_GCF_004770995 table
#
# Running against Leptospira_ilyithenensis_GCF_004771005.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpY7jAI7.fasta
#
# Writing the results file...
# 	/tmp/tmp3L_maL.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_ilyithenensis_GCF_004771005.lastz
# Creating Leptospira_ilyithenensis_GCF_004771005 table
# Inserting data to Leptospira_ilyithenensis_GCF_004771005 table
#
# Running against Leptospira_inadai_GCF_000243675.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpFGjr9Z.fasta
#
# Writing the results file...
# 	/tmp/tmpi9zvnh.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_inadai_GCF_000243675.lastz
# Creating Leptospira_inadai_GCF_000243675 table
# Inserting data to Leptospira_inadai_GCF_000243675 table
#
# Running against Leptospira_jelokensis_GCF_004769775.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpSLE4Jk.fasta
#
# Writing the results file...
# 	/tmp/tmpWDD4ng.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_jelokensis_GCF_004769775.lastz
# Creating Leptospira_jelokensis_GCF_004769775 table
# Inserting data to Leptospira_jelokensis_GCF_004769775 table
#
# Running against Leptospira_johnsonii_GCF_003112675.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpaHZITX.fasta
#
# Writing the results file...
# 	/tmp/tmphsMLdA.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_johnsonii_GCF_003112675.lastz
# Creating Leptospira_johnsonii_GCF_003112675 table
# Inserting data to Leptospira_johnsonii_GCF_003112675 table
#
# Running against Leptospira_kanakyensis_GCF_004769235.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpzAGwcu.fasta
#
# Writing the results file...
# 	/tmp/tmpOuJ52F.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_kanakyensis_GCF_004769235.lastz
# Creating Leptospira_kanakyensis_GCF_004769235 table
# Inserting data to Leptospira_kanakyensis_GCF_004769235 table
#
# Running against Leptospira_kemamanensis_GCF_004769665.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpztBRFb.fasta
#
# Writing the results file...
# 	/tmp/tmpKC6Rsr.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_kemamanensis_GCF_004769665.lastz
# Creating Leptospira_kemamanensis_GCF_004769665 table
# Inserting data to Leptospira_kemamanensis_GCF_004769665 table
#
# Running against Leptospira_kirschneri_GCF_000243695.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpMz4tU2.fasta
#
# Writing the results file...
# 	/tmp/tmpNhF3es.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_kirschneri_GCF_000243695.lastz
# Creating Leptospira_kirschneri_GCF_000243695 table
# Inserting data to Leptospira_kirschneri_GCF_000243695 table
#
# Running against Leptospira_kmetyi_GCF_000243735.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp7bwKvM.fasta
#
# Writing the results file...
# 	/tmp/tmpUG3WXV.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_kmetyi_GCF_000243735.lastz
# Creating Leptospira_kmetyi_GCF_000243735 table
# Inserting data to Leptospira_kmetyi_GCF_000243735 table
#
# Running against Leptospira_kobayashii_GCF_003114835.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpj2eJHK.fasta
#
# Writing the results file...
# 	/tmp/tmp9ImUCq.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_kobayashii_GCF_003114835.lastz
# Creating Leptospira_kobayashii_GCF_003114835 table
# Inserting data to Leptospira_kobayashii_GCF_003114835 table
#
# Running against Leptospira_koniamboensis_GCF_004769555.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpJp1IgV.fasta
#
# Writing the results file...
# 	/tmp/tmpy6H995.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_koniamboensis_GCF_004769555.lastz
# Creating Leptospira_koniamboensis_GCF_004769555 table
# Inserting data to Leptospira_koniamboensis_GCF_004769555 table
#
# Running against Leptospira_langatensis_GCF_004770615.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp86J19_.fasta
#
# Writing the results file...
# 	/tmp/tmpTnaMmF.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_langatensis_GCF_004770615.lastz
# Creating Leptospira_langatensis_GCF_004770615 table
# Inserting data to Leptospira_langatensis_GCF_004770615 table
#
# Running against Leptospira_levettii_GCF_002812085.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpp7DGEn.fasta
#
# Writing the results file...
# 	/tmp/tmpH2EWiq.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_levettii_GCF_002812085.lastz
# Creating Leptospira_levettii_GCF_002812085 table
# Inserting data to Leptospira_levettii_GCF_002812085 table
#
# Running against Leptospira_licerasiae_GCF_000244755.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpiAr2X1.fasta
#
# Writing the results file...
# 	/tmp/tmpMTLVLH.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_licerasiae_GCF_000244755.lastz
# Creating Leptospira_licerasiae_GCF_000244755 table
# Inserting data to Leptospira_licerasiae_GCF_000244755 table
#
# Running against Leptospira_macculloughii_GCF_002811975.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmppNOxe3.fasta
#
# Writing the results file...
# 	/tmp/tmpxrEl_b.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_macculloughii_GCF_002811975.lastz
# Creating Leptospira_macculloughii_GCF_002811975 table
# Inserting data to Leptospira_macculloughii_GCF_002811975 table
#
# Running against Leptospira_mayottensis_GCF_000306675.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxHLVVn.fasta
#
# Writing the results file...
# 	/tmp/tmpHQZK1a.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_mayottensis_GCF_000306675.lastz
# Creating Leptospira_mayottensis_GCF_000306675 table
# Inserting data to Leptospira_mayottensis_GCF_000306675 table
#
# Running against Leptospira_meyeri_GCF_000304275.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpml30jv.fasta
#
# Writing the results file...
# 	/tmp/tmpdXZbTD.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_meyeri_GCF_000304275.lastz
# Creating Leptospira_meyeri_GCF_000304275 table
# Inserting data to Leptospira_meyeri_GCF_000304275 table
#
# Running against Leptospira_montravelensis_GCF_004769455.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpfHaCAD.fasta
#
# Writing the results file...
# 	/tmp/tmpgmqC4y.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_montravelensis_GCF_004769455.lastz
# Creating Leptospira_montravelensis_GCF_004769455 table
# Inserting data to Leptospira_montravelensis_GCF_004769455 table
#
# Running against Leptospira_mtsangambouensis_GCF_004770475.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpuaPqzo.fasta
#
# Writing the results file...
# 	/tmp/tmpS5IDHI.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_mtsangambouensis_GCF_004770475.lastz
# Creating Leptospira_mtsangambouensis_GCF_004770475 table
# Inserting data to Leptospira_mtsangambouensis_GCF_004770475 table
#
# Running against Leptospira_neocaledonica_GCF_002812205.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmps8tN9i.fasta
#
# Writing the results file...
# 	/tmp/tmpIoWC5t.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_neocaledonica_GCF_002812205.lastz
# Creating Leptospira_neocaledonica_GCF_002812205 table
# Inserting data to Leptospira_neocaledonica_GCF_002812205 table
#
# Running against Leptospira_noguchii_GCF_000306255.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpSpJFZV.fasta
#
# Writing the results file...
# 	/tmp/tmp6CwLsx.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_noguchii_GCF_000306255.lastz
# Creating Leptospira_noguchii_GCF_000306255 table
# Inserting data to Leptospira_noguchii_GCF_000306255 table
#
# Running against Leptospira_noumeaensis_GCF_004770765.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpxttpuK.fasta
#
# Writing the results file...
# 	/tmp/tmpEOdsX1.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_noumeaensis_GCF_004770765.lastz
# Creating Leptospira_noumeaensis_GCF_004770765 table
# Inserting data to Leptospira_noumeaensis_GCF_004770765 table
#
# Running against Leptospira_ognonensis_GCF_004770745.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmphIjLpn.fasta
#
# Writing the results file...
# 	/tmp/tmpBkLLJL.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_ognonensis_GCF_004770745.lastz
# Creating Leptospira_ognonensis_GCF_004770745 table
# Inserting data to Leptospira_ognonensis_GCF_004770745 table
#
# Running against Leptospira_perdikensis_GCF_004769575.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp5UIuiz.fasta
#
# Writing the results file...
# 	/tmp/tmp06SpV6.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_perdikensis_GCF_004769575.lastz
# Creating Leptospira_perdikensis_GCF_004769575 table
# Inserting data to Leptospira_perdikensis_GCF_004769575 table
#
# Running against Leptospira_perolatii_GCF_002811875.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDGhAig.fasta
#
# Writing the results file...
# 	/tmp/tmpama1kG.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_perolatii_GCF_002811875.lastz
# Creating Leptospira_perolatii_GCF_002811875 table
# Inserting data to Leptospira_perolatii_GCF_002811875 table
#
# Running against Leptospira_putramalaysiae_GCF_004770035.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp80Nr4p.fasta
#
# Writing the results file...
# 	/tmp/tmpsfB36F.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_putramalaysiae_GCF_004770035.lastz
# Creating Leptospira_putramalaysiae_GCF_004770035 table
# Inserting data to Leptospira_putramalaysiae_GCF_004770035 table
#
# Running against Leptospira_ryugenii_GCF_003114855.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpa1aL1R.fasta
#
# Writing the results file...
# 	/tmp/tmpNbka0s.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_ryugenii_GCF_003114855.lastz
# Creating Leptospira_ryugenii_GCF_003114855 table
# Inserting data to Leptospira_ryugenii_GCF_003114855 table
#
# Running against Leptospira_saintgironsiae_GCF_002811765.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpm_bsXC.fasta
#
# Writing the results file...
# 	/tmp/tmpKQws94.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_saintgironsiae_GCF_002811765.lastz
# Creating Leptospira_saintgironsiae_GCF_002811765 table
# Inserting data to Leptospira_saintgironsiae_GCF_002811765 table
#
# Running against Leptospira_santarosai_GCF_000313175.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpb4rDVq.fasta
#
# Writing the results file...
# 	/tmp/tmp3W_MFK.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_santarosai_GCF_000313175.lastz
# Creating Leptospira_santarosai_GCF_000313175 table
# Inserting data to Leptospira_santarosai_GCF_000313175 table
#
# Running against Leptospira_sarikeiensis_GCF_004769615.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpOUJA2J.fasta
#
# Writing the results file...
# 	/tmp/tmp2hF7HY.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_sarikeiensis_GCF_004769615.lastz
# Creating Leptospira_sarikeiensis_GCF_004769615 table
# Inserting data to Leptospira_sarikeiensis_GCF_004769615 table
#
# Running against Leptospira_selangorensis_GCF_004769405.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpfdOszP.fasta
#
# Writing the results file...
# 	/tmp/tmp5hPhHr.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_selangorensis_GCF_004769405.lastz
# Creating Leptospira_selangorensis_GCF_004769405 table
# Inserting data to Leptospira_selangorensis_GCF_004769405 table
#
# Running against Leptospira_semungkisensis_GCF_004770055.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmpLoAb.fasta
#
# Writing the results file...
# 	/tmp/tmp4Ei63r.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_semungkisensis_GCF_004770055.lastz
# Creating Leptospira_semungkisensis_GCF_004770055 table
# Inserting data to Leptospira_semungkisensis_GCF_004770055 table
#
# Running against Leptospira_sp_GCF_000347035.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpttMtG5.fasta
#
# Writing the results file...
# 	/tmp/tmpa07UdZ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_sp_GCF_000347035.lastz
# Creating Leptospira_sp_GCF_000347035 table
# Inserting data to Leptospira_sp_GCF_000347035 table
#
# Running against Leptospira_stimsonii_GCF_003545885.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmjalGO.fasta
#
# Writing the results file...
# 	/tmp/tmpX3OSBd.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_stimsonii_GCF_003545885.lastz
# Creating Leptospira_stimsonii_GCF_003545885 table
# Inserting data to Leptospira_stimsonii_GCF_003545885 table
#
# Running against Leptospira_terpstrae_GCF_000332495.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp76Fwcd.fasta
#
# Writing the results file...
# 	/tmp/tmpzs8DCB.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_terpstrae_GCF_000332495.lastz
# Creating Leptospira_terpstrae_GCF_000332495 table
# Inserting data to Leptospira_terpstrae_GCF_000332495 table
#
# Running against Leptospira_tipperaryensis_GCF_001729245.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp8GwPiI.fasta
#
# Writing the results file...
# 	/tmp/tmpdb_Pgt.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_tipperaryensis_GCF_001729245.lastz
# Creating Leptospira_tipperaryensis_GCF_001729245 table
# Inserting data to Leptospira_tipperaryensis_GCF_001729245 table
#
# Running against Leptospira_vanthielii_GCF_000332455.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpcKqWJC.fasta
#
# Writing the results file...
# 	/tmp/tmpI35_m7.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_vanthielii_GCF_000332455.lastz
# Creating Leptospira_vanthielii_GCF_000332455 table
# Inserting data to Leptospira_vanthielii_GCF_000332455 table
#
# Running against Leptospira_venezuelensis_GCF_002150035.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpdLO0pc.fasta
#
# Writing the results file...
# 	/tmp/tmpVMMs7k.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_venezuelensis_GCF_002150035.lastz
# Creating Leptospira_venezuelensis_GCF_002150035 table
# Inserting data to Leptospira_venezuelensis_GCF_002150035 table
#
# Running against Leptospira_weilii_GCF_000244815.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpRH_dg9.fasta
#
# Writing the results file...
# 	/tmp/tmpLhgG0M.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_weilii_GCF_000244815.lastz
# Creating Leptospira_weilii_GCF_000244815 table
# Inserting data to Leptospira_weilii_GCF_000244815 table
#
# Running against Leptospira_wolbachii_GCF_000332515.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmps2hVrE.fasta
#
# Writing the results file...
# 	/tmp/tmpFzMP0E.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_wolbachii_GCF_000332515.lastz
# Creating Leptospira_wolbachii_GCF_000332515 table
# Inserting data to Leptospira_wolbachii_GCF_000332515 table
#
# Running against Leptospira_wolffii_GCF_000306115.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpyLg_VC.fasta
#
# Writing the results file...
# 	/tmp/tmpvSeoVa.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_wolffii_GCF_000306115.lastz
# Creating Leptospira_wolffii_GCF_000306115 table
# Inserting data to Leptospira_wolffii_GCF_000306115 table
#
# Running against Leptospira_yanagawae_GCF_000332475.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpnP8OWa.fasta
#
# Writing the results file...
# 	/tmp/tmpe3PsDB.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_yanagawae_GCF_000332475.lastz
# Creating Leptospira_yanagawae_GCF_000332475 table
# Inserting data to Leptospira_yanagawae_GCF_000332475 table
#
# Running against Leptospira_yasudae_GCF_003545925.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpn3WD1q.fasta
#
# Writing the results file...
# 	/tmp/tmp_yMmMM.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_yasudae_GCF_003545925.lastz
# Creating Leptospira_yasudae_GCF_003545925 table
# Inserting data to Leptospira_yasudae_GCF_003545925 table
#
# Running against Leptospira_interrogans_GCF_000092565.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpP9IoQC.fasta
#
# Writing the results file...
# 	/tmp/tmpomayrZ.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/leptospira/validate_intervals/lastz/Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_Leptospira_interrogans_GCF_000092565.lastz
# Creating Leptospira_interrogans_GCF_000092565 table
# Inserting data to Leptospira_interrogans_GCF_000092565 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/leptospira/extract_probes_from_group/leptospira_genome.conf --lastz results/phyluce/leptospira/validate_intervals/lastz --probes 120 --probe-prefix uce_leptospira_ --name-pattern "Leptospira_interrogans_GCF_000092565_+10_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/leptospira/extract_probes_from_group/probe_fasta;
# 2020-02-07 13:16:05,345 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 13:16:05,349 - Phyluce - INFO - ------- Working on Leptospira_adleri_GCF_002811985 genome -------
# 2020-02-07 13:16:05,350 - Phyluce - INFO - Reading Leptospira_adleri_GCF_002811985 genome
# 2020-02-07 13:16:06,627 - Phyluce - INFO - Leptospira_adleri_GCF_002811985: 354 uces, 16 dupes, 338 non-dupes, 0 orient drop, 0 length drop, 338 written
# 2020-02-07 13:16:06,627 - Phyluce - INFO - ----- Working on Leptospira_alexanderi_GCF_000243815 genome -----
# 2020-02-07 13:16:06,628 - Phyluce - INFO - Reading Leptospira_alexanderi_GCF_000243815 genome
# 2020-02-07 13:16:07,819 - Phyluce - INFO - Leptospira_alexanderi_GCF_000243815: 352 uces, 14 dupes, 338 non-dupes, 0 orient drop, 0 length drop, 338 written
# 2020-02-07 13:16:07,819 - Phyluce - INFO - ------ Working on Leptospira_alstonii_GCF_000347175 genome ------
# 2020-02-07 13:16:07,820 - Phyluce - INFO - Reading Leptospira_alstonii_GCF_000347175 genome
# 2020-02-07 13:16:09,064 - Phyluce - INFO - Leptospira_alstonii_GCF_000347175: 352 uces, 21 dupes, 331 non-dupes, 0 orient drop, 0 length drop, 331 written
# 2020-02-07 13:16:09,064 - Phyluce - INFO - --- Working on Leptospira_andrefontaineae_GCF_004770105 genome --
# 2020-02-07 13:16:09,065 - Phyluce - INFO - Reading Leptospira_andrefontaineae_GCF_004770105 genome
# 2020-02-07 13:16:10,016 - Phyluce - INFO - Leptospira_andrefontaineae_GCF_004770105: 300 uces, 5 dupes, 295 non-dupes, 4 orient drop, 7 length drop, 284 written
# 2020-02-07 13:16:10,016 - Phyluce - INFO - --- Working on Leptospira_bandrabouensis_GCF_004770905 genome ---
# 2020-02-07 13:16:10,029 - Phyluce - INFO - Reading Leptospira_bandrabouensis_GCF_004770905 genome
# 2020-02-07 13:16:10,675 - Phyluce - INFO - Leptospira_bandrabouensis_GCF_004770905: 217 uces, 10 dupes, 207 non-dupes, 0 orient drop, 6 length drop, 201 written
# 2020-02-07 13:16:10,675 - Phyluce - INFO - ----- Working on Leptospira_barantonii_GCF_002811925 genome -----
# 2020-02-07 13:16:10,676 - Phyluce - INFO - Reading Leptospira_barantonii_GCF_002811925 genome
# 2020-02-07 13:16:11,878 - Phyluce - INFO - Leptospira_barantonii_GCF_002811925: 354 uces, 13 dupes, 341 non-dupes, 1 orient drop, 1 length drop, 339 written
# 2020-02-07 13:16:11,878 - Phyluce - INFO - ------- Working on Leptospira_biflexa_GCF_000017685 genome ------
# 2020-02-07 13:16:11,890 - Phyluce - INFO - Reading Leptospira_biflexa_GCF_000017685 genome
# 2020-02-07 13:16:12,526 - Phyluce - INFO - Leptospira_biflexa_GCF_000017685: 211 uces, 0 dupes, 211 non-dupes, 10 orient drop, 9 length drop, 192 written
# 2020-02-07 13:16:12,527 - Phyluce - INFO - --- Working on Leptospira_borgpetersenii_GCF_000013945 genome ---
# 2020-02-07 13:16:12,556 - Phyluce - INFO - Reading Leptospira_borgpetersenii_GCF_000013945 genome
# 2020-02-07 13:16:13,858 - Phyluce - INFO - Leptospira_borgpetersenii_GCF_000013945: 353 uces, 0 dupes, 353 non-dupes, 8 orient drop, 42 length drop, 303 written
# 2020-02-07 13:16:13,858 - Phyluce - INFO - ------ Working on Leptospira_bourretii_GCF_004769285 genome -----
# 2020-02-07 13:16:13,859 - Phyluce - INFO - Reading Leptospira_bourretii_GCF_004769285 genome
# 2020-02-07 13:16:14,502 - Phyluce - INFO - Leptospira_bourretii_GCF_004769285: 218 uces, 8 dupes, 210 non-dupes, 1 orient drop, 4 length drop, 205 written
# 2020-02-07 13:16:14,502 - Phyluce - INFO - ---- Working on Leptospira_bouyouniensis_GCF_004770625 genome ---
# 2020-02-07 13:16:14,503 - Phyluce - INFO - Reading Leptospira_bouyouniensis_GCF_004770625 genome
# 2020-02-07 13:16:15,138 - Phyluce - INFO - Leptospira_bouyouniensis_GCF_004770625: 217 uces, 3 dupes, 214 non-dupes, 8 orient drop, 7 length drop, 199 written
# 2020-02-07 13:16:15,138 - Phyluce - INFO - ------ Working on Leptospira_brenneri_GCF_002812125 genome ------
# 2020-02-07 13:16:15,139 - Phyluce - INFO - Reading Leptospira_brenneri_GCF_002812125 genome
# 2020-02-07 13:16:15,789 - Phyluce - INFO - Leptospira_brenneri_GCF_002812125: 223 uces, 12 dupes, 211 non-dupes, 0 orient drop, 2 length drop, 209 written
# 2020-02-07 13:16:15,789 - Phyluce - INFO - ------- Working on Leptospira_broomii_GCF_000243715 genome ------
# 2020-02-07 13:16:15,790 - Phyluce - INFO - Reading Leptospira_broomii_GCF_000243715 genome
# 2020-02-07 13:16:16,752 - Phyluce - INFO - Leptospira_broomii_GCF_000243715: 307 uces, 4 dupes, 303 non-dupes, 3 orient drop, 8 length drop, 292 written
# 2020-02-07 13:16:16,753 - Phyluce - INFO - ---- Working on Leptospira_congkakensis_GCF_004770265 genome ----
# 2020-02-07 13:16:16,753 - Phyluce - INFO - Reading Leptospira_congkakensis_GCF_004770265 genome
# 2020-02-07 13:16:17,384 - Phyluce - INFO - Leptospira_congkakensis_GCF_004770265: 212 uces, 6 dupes, 206 non-dupes, 6 orient drop, 2 length drop, 198 written
# 2020-02-07 13:16:17,384 - Phyluce - INFO - ----- Working on Leptospira_dzianensis_GCF_004770135 genome -----
# 2020-02-07 13:16:17,389 - Phyluce - INFO - Reading Leptospira_dzianensis_GCF_004770135 genome
# 2020-02-07 13:16:18,624 - Phyluce - INFO - Leptospira_dzianensis_GCF_004770135: 354 uces, 13 dupes, 341 non-dupes, 1 orient drop, 3 length drop, 337 written
# 2020-02-07 13:16:18,625 - Phyluce - INFO - --- Working on Leptospira_dzoumogneensis_GCF_004770895 genome ---
# 2020-02-07 13:16:18,625 - Phyluce - INFO - Reading Leptospira_dzoumogneensis_GCF_004770895 genome
# 2020-02-07 13:16:19,566 - Phyluce - INFO - Leptospira_dzoumogneensis_GCF_004770895: 303 uces, 5 dupes, 298 non-dupes, 4 orient drop, 6 length drop, 288 written
# 2020-02-07 13:16:19,566 - Phyluce - INFO - --- Working on Leptospira_ellinghausenii_GCF_003114815 genome ---
# 2020-02-07 13:16:19,567 - Phyluce - INFO - Reading Leptospira_ellinghausenii_GCF_003114815 genome
# 2020-02-07 13:16:20,224 - Phyluce - INFO - Leptospira_ellinghausenii_GCF_003114815: 217 uces, 11 dupes, 206 non-dupes, 0 orient drop, 1 length drop, 205 written
# 2020-02-07 13:16:20,224 - Phyluce - INFO - ------ Working on Leptospira_elllisii_GCF_002811955 genome ------
# 2020-02-07 13:16:20,232 - Phyluce - INFO - Reading Leptospira_elllisii_GCF_002811955 genome
# 2020-02-07 13:16:21,446 - Phyluce - INFO - Leptospira_elllisii_GCF_002811955: 350 uces, 15 dupes, 335 non-dupes, 0 orient drop, 0 length drop, 335 written
# 2020-02-07 13:16:21,446 - Phyluce - INFO - ------- Working on Leptospira_fainei_GCF_000306235 genome -------
# 2020-02-07 13:16:21,447 - Phyluce - INFO - Reading Leptospira_fainei_GCF_000306235 genome
# 2020-02-07 13:16:22,423 - Phyluce - INFO - Leptospira_fainei_GCF_000306235: 306 uces, 10 dupes, 296 non-dupes, 0 orient drop, 6 length drop, 290 written
# 2020-02-07 13:16:22,424 - Phyluce - INFO - ------ Working on Leptospira_fletcheri_GCF_004769195 genome -----
# 2020-02-07 13:16:22,425 - Phyluce - INFO - Reading Leptospira_fletcheri_GCF_004769195 genome
# 2020-02-07 13:16:23,398 - Phyluce - INFO - Leptospira_fletcheri_GCF_004769195: 306 uces, 11 dupes, 295 non-dupes, 0 orient drop, 3 length drop, 292 written
# 2020-02-07 13:16:23,398 - Phyluce - INFO - ------ Working on Leptospira_fluminis_GCF_004771275 genome ------
# 2020-02-07 13:16:23,399 - Phyluce - INFO - Reading Leptospira_fluminis_GCF_004771275 genome
# 2020-02-07 13:16:24,369 - Phyluce - INFO - Leptospira_fluminis_GCF_004771275: 305 uces, 12 dupes, 293 non-dupes, 0 orient drop, 3 length drop, 290 written
# 2020-02-07 13:16:24,369 - Phyluce - INFO - ----- Working on Leptospira_gomenensis_GCF_004770155 genome -----
# 2020-02-07 13:16:24,376 - Phyluce - INFO - Reading Leptospira_gomenensis_GCF_004770155 genome
# 2020-02-07 13:16:25,578 - Phyluce - INFO - Leptospira_gomenensis_GCF_004770155: 353 uces, 15 dupes, 338 non-dupes, 1 orient drop, 0 length drop, 337 written
# 2020-02-07 13:16:25,578 - Phyluce - INFO - ------- Working on Leptospira_haakeii_GCF_002812045 genome ------
# 2020-02-07 13:16:25,580 - Phyluce - INFO - Reading Leptospira_haakeii_GCF_002812045 genome
# 2020-02-07 13:16:26,545 - Phyluce - INFO - Leptospira_haakeii_GCF_002812045: 301 uces, 9 dupes, 292 non-dupes, 0 orient drop, 6 length drop, 286 written
# 2020-02-07 13:16:26,546 - Phyluce - INFO - ------ Working on Leptospira_harrisiae_GCF_002811945 genome -----
# 2020-02-07 13:16:26,546 - Phyluce - INFO - Reading Leptospira_harrisiae_GCF_002811945 genome
# 2020-02-07 13:16:27,187 - Phyluce - INFO - Leptospira_harrisiae_GCF_002811945: 216 uces, 6 dupes, 210 non-dupes, 6 orient drop, 3 length drop, 201 written
# 2020-02-07 13:16:27,187 - Phyluce - INFO - ---- Working on Leptospira_hartskeerlii_GCF_002811475 genome ----
# 2020-02-07 13:16:27,188 - Phyluce - INFO - Reading Leptospira_hartskeerlii_GCF_002811475 genome
# 2020-02-07 13:16:28,109 - Phyluce - INFO - Leptospira_hartskeerlii_GCF_002811475: 298 uces, 5 dupes, 293 non-dupes, 4 orient drop, 3 length drop, 286 written
# 2020-02-07 13:16:28,109 - Phyluce - INFO - ------- Working on Leptospira_idonii_GCF_004770995 genome -------
# 2020-02-07 13:16:28,110 - Phyluce - INFO - Reading Leptospira_idonii_GCF_004770995 genome
# 2020-02-07 13:16:28,774 - Phyluce - INFO - Leptospira_idonii_GCF_004770995: 230 uces, 2 dupes, 228 non-dupes, 0 orient drop, 8 length drop, 220 written
# 2020-02-07 13:16:28,774 - Phyluce - INFO - ---- Working on Leptospira_ilyithenensis_GCF_004771005 genome ---
# 2020-02-07 13:16:28,775 - Phyluce - INFO - Reading Leptospira_ilyithenensis_GCF_004771005 genome
# 2020-02-07 13:16:29,421 - Phyluce - INFO - Leptospira_ilyithenensis_GCF_004771005: 215 uces, 11 dupes, 204 non-dupes, 1 orient drop, 3 length drop, 200 written
# 2020-02-07 13:16:29,421 - Phyluce - INFO - ------- Working on Leptospira_inadai_GCF_000243675 genome -------
# 2020-02-07 13:16:29,422 - Phyluce - INFO - Reading Leptospira_inadai_GCF_000243675 genome
# 2020-02-07 13:16:30,406 - Phyluce - INFO - Leptospira_inadai_GCF_000243675: 308 uces, 9 dupes, 299 non-dupes, 4 orient drop, 5 length drop, 290 written
# 2020-02-07 13:16:30,407 - Phyluce - INFO - ----- Working on Leptospira_jelokensis_GCF_004769775 genome -----
# 2020-02-07 13:16:30,407 - Phyluce - INFO - Reading Leptospira_jelokensis_GCF_004769775 genome
# 2020-02-07 13:16:31,042 - Phyluce - INFO - Leptospira_jelokensis_GCF_004769775: 217 uces, 10 dupes, 207 non-dupes, 1 orient drop, 5 length drop, 201 written
# 2020-02-07 13:16:31,043 - Phyluce - INFO - ------ Working on Leptospira_johnsonii_GCF_003112675 genome -----
# 2020-02-07 13:16:31,043 - Phyluce - INFO - Reading Leptospira_johnsonii_GCF_003112675 genome
# 2020-02-07 13:16:31,988 - Phyluce - INFO - Leptospira_johnsonii_GCF_003112675: 303 uces, 2 dupes, 301 non-dupes, 4 orient drop, 6 length drop, 291 written
# 2020-02-07 13:16:31,988 - Phyluce - INFO - ----- Working on Leptospira_kanakyensis_GCF_004769235 genome ----
# 2020-02-07 13:16:31,988 - Phyluce - INFO - Reading Leptospira_kanakyensis_GCF_004769235 genome
# 2020-02-07 13:16:32,624 - Phyluce - INFO - Leptospira_kanakyensis_GCF_004769235: 220 uces, 4 dupes, 216 non-dupes, 6 orient drop, 2 length drop, 208 written
# 2020-02-07 13:16:32,624 - Phyluce - INFO - ---- Working on Leptospira_kemamanensis_GCF_004769665 genome ----
# 2020-02-07 13:16:32,631 - Phyluce - INFO - Reading Leptospira_kemamanensis_GCF_004769665 genome
# 2020-02-07 13:16:33,275 - Phyluce - INFO - Leptospira_kemamanensis_GCF_004769665: 219 uces, 12 dupes, 207 non-dupes, 0 orient drop, 1 length drop, 206 written
# 2020-02-07 13:16:33,275 - Phyluce - INFO - ----- Working on Leptospira_kirschneri_GCF_000243695 genome -----
# 2020-02-07 13:16:33,287 - Phyluce - INFO - Reading Leptospira_kirschneri_GCF_000243695 genome
# 2020-02-07 13:16:34,488 - Phyluce - INFO - Leptospira_kirschneri_GCF_000243695: 354 uces, 4 dupes, 350 non-dupes, 4 orient drop, 5 length drop, 341 written
# 2020-02-07 13:16:34,488 - Phyluce - INFO - ------- Working on Leptospira_kmetyi_GCF_000243735 genome -------
# 2020-02-07 13:16:34,489 - Phyluce - INFO - Reading Leptospira_kmetyi_GCF_000243735 genome
# 2020-02-07 13:16:35,714 - Phyluce - INFO - Leptospira_kmetyi_GCF_000243735: 354 uces, 3 dupes, 351 non-dupes, 12 orient drop, 5 length drop, 334 written
# 2020-02-07 13:16:35,714 - Phyluce - INFO - ----- Working on Leptospira_kobayashii_GCF_003114835 genome -----
# 2020-02-07 13:16:35,715 - Phyluce - INFO - Reading Leptospira_kobayashii_GCF_003114835 genome
# 2020-02-07 13:16:36,349 - Phyluce - INFO - Leptospira_kobayashii_GCF_003114835: 218 uces, 9 dupes, 209 non-dupes, 0 orient drop, 2 length drop, 207 written
# 2020-02-07 13:16:36,349 - Phyluce - INFO - ---- Working on Leptospira_koniamboensis_GCF_004769555 genome ---
# 2020-02-07 13:16:36,350 - Phyluce - INFO - Reading Leptospira_koniamboensis_GCF_004769555 genome
# 2020-02-07 13:16:37,278 - Phyluce - INFO - Leptospira_koniamboensis_GCF_004769555: 300 uces, 3 dupes, 297 non-dupes, 4 orient drop, 6 length drop, 287 written
# 2020-02-07 13:16:37,278 - Phyluce - INFO - ----- Working on Leptospira_langatensis_GCF_004770615 genome ----
# 2020-02-07 13:16:37,293 - Phyluce - INFO - Reading Leptospira_langatensis_GCF_004770615 genome
# 2020-02-07 13:16:38,243 - Phyluce - INFO - Leptospira_langatensis_GCF_004770615: 301 uces, 10 dupes, 291 non-dupes, 0 orient drop, 5 length drop, 286 written
# 2020-02-07 13:16:38,243 - Phyluce - INFO - ------ Working on Leptospira_levettii_GCF_002812085 genome ------
# 2020-02-07 13:16:38,244 - Phyluce - INFO - Reading Leptospira_levettii_GCF_002812085 genome
# 2020-02-07 13:16:38,882 - Phyluce - INFO - Leptospira_levettii_GCF_002812085: 219 uces, 10 dupes, 209 non-dupes, 0 orient drop, 2 length drop, 207 written
# 2020-02-07 13:16:38,882 - Phyluce - INFO - ----- Working on Leptospira_licerasiae_GCF_000244755 genome -----
# 2020-02-07 13:16:38,883 - Phyluce - INFO - Reading Leptospira_licerasiae_GCF_000244755 genome
# 2020-02-07 13:16:39,832 - Phyluce - INFO - Leptospira_licerasiae_GCF_000244755: 302 uces, 9 dupes, 293 non-dupes, 4 orient drop, 5 length drop, 284 written
# 2020-02-07 13:16:39,832 - Phyluce - INFO - ---- Working on Leptospira_macculloughii_GCF_002811975 genome ---
# 2020-02-07 13:16:39,833 - Phyluce - INFO - Reading Leptospira_macculloughii_GCF_002811975 genome
# 2020-02-07 13:16:40,870 - Phyluce - INFO - Leptospira_macculloughii_GCF_002811975: 227 uces, 155 dupes, 72 non-dupes, 0 orient drop, 0 length drop, 72 written
# 2020-02-07 13:16:40,870 - Phyluce - INFO - ----- Working on Leptospira_mayottensis_GCF_000306675 genome ----
# 2020-02-07 13:16:40,880 - Phyluce - INFO - Reading Leptospira_mayottensis_GCF_000306675 genome
# 2020-02-07 13:16:42,115 - Phyluce - INFO - Leptospira_mayottensis_GCF_000306675: 353 uces, 0 dupes, 353 non-dupes, 19 orient drop, 4 length drop, 330 written
# 2020-02-07 13:16:42,115 - Phyluce - INFO - ------- Working on Leptospira_meyeri_GCF_000304275 genome -------
# 2020-02-07 13:16:42,116 - Phyluce - INFO - Reading Leptospira_meyeri_GCF_000304275 genome
# 2020-02-07 13:16:42,786 - Phyluce - INFO - Leptospira_meyeri_GCF_000304275: 223 uces, 8 dupes, 215 non-dupes, 0 orient drop, 7 length drop, 208 written
# 2020-02-07 13:16:42,787 - Phyluce - INFO - --- Working on Leptospira_montravelensis_GCF_004769455 genome ---
# 2020-02-07 13:16:42,787 - Phyluce - INFO - Reading Leptospira_montravelensis_GCF_004769455 genome
# 2020-02-07 13:16:43,419 - Phyluce - INFO - Leptospira_montravelensis_GCF_004769455: 219 uces, 4 dupes, 215 non-dupes, 6 orient drop, 4 length drop, 205 written
# 2020-02-07 13:16:43,419 - Phyluce - INFO - -- Working on Leptospira_mtsangambouensis_GCF_004770475 genome --
# 2020-02-07 13:16:43,420 - Phyluce - INFO - Reading Leptospira_mtsangambouensis_GCF_004770475 genome
# 2020-02-07 13:16:44,058 - Phyluce - INFO - Leptospira_mtsangambouensis_GCF_004770475: 219 uces, 3 dupes, 216 non-dupes, 6 orient drop, 3 length drop, 207 written
# 2020-02-07 13:16:44,058 - Phyluce - INFO - ---- Working on Leptospira_neocaledonica_GCF_002812205 genome ---
# 2020-02-07 13:16:44,059 - Phyluce - INFO - Reading Leptospira_neocaledonica_GCF_002812205 genome
# 2020-02-07 13:16:44,979 - Phyluce - INFO - Leptospira_neocaledonica_GCF_002812205: 299 uces, 3 dupes, 296 non-dupes, 3 orient drop, 6 length drop, 287 written
# 2020-02-07 13:16:44,979 - Phyluce - INFO - ------ Working on Leptospira_noguchii_GCF_000306255 genome ------
# 2020-02-07 13:16:44,987 - Phyluce - INFO - Reading Leptospira_noguchii_GCF_000306255 genome
# 2020-02-07 13:16:46,217 - Phyluce - INFO - Leptospira_noguchii_GCF_000306255: 353 uces, 15 dupes, 338 non-dupes, 1 orient drop, 1 length drop, 336 written
# 2020-02-07 13:16:46,217 - Phyluce - INFO - ----- Working on Leptospira_noumeaensis_GCF_004770765 genome ----
# 2020-02-07 13:16:46,218 - Phyluce - INFO - Reading Leptospira_noumeaensis_GCF_004770765 genome
# 2020-02-07 13:16:46,849 - Phyluce - INFO - Leptospira_noumeaensis_GCF_004770765: 216 uces, 12 dupes, 204 non-dupes, 0 orient drop, 2 length drop, 202 written
# 2020-02-07 13:16:46,849 - Phyluce - INFO - ----- Working on Leptospira_ognonensis_GCF_004770745 genome -----
# 2020-02-07 13:16:46,852 - Phyluce - INFO - Reading Leptospira_ognonensis_GCF_004770745 genome
# 2020-02-07 13:16:47,482 - Phyluce - INFO - Leptospira_ognonensis_GCF_004770745: 216 uces, 10 dupes, 206 non-dupes, 0 orient drop, 0 length drop, 206 written
# 2020-02-07 13:16:47,483 - Phyluce - INFO - ----- Working on Leptospira_perdikensis_GCF_004769575 genome ----
# 2020-02-07 13:16:47,483 - Phyluce - INFO - Reading Leptospira_perdikensis_GCF_004769575 genome
# 2020-02-07 13:16:48,115 - Phyluce - INFO - Leptospira_perdikensis_GCF_004769575: 216 uces, 11 dupes, 205 non-dupes, 0 orient drop, 1 length drop, 204 written
# 2020-02-07 13:16:48,115 - Phyluce - INFO - ------ Working on Leptospira_perolatii_GCF_002811875 genome -----
# 2020-02-07 13:16:48,116 - Phyluce - INFO - Reading Leptospira_perolatii_GCF_002811875 genome
# 2020-02-07 13:16:49,065 - Phyluce - INFO - Leptospira_perolatii_GCF_002811875: 307 uces, 9 dupes, 298 non-dupes, 0 orient drop, 4 length drop, 294 written
# 2020-02-07 13:16:49,065 - Phyluce - INFO - --- Working on Leptospira_putramalaysiae_GCF_004770035 genome ---
# 2020-02-07 13:16:49,066 - Phyluce - INFO - Reading Leptospira_putramalaysiae_GCF_004770035 genome
# 2020-02-07 13:16:50,271 - Phyluce - INFO - Leptospira_putramalaysiae_GCF_004770035: 353 uces, 16 dupes, 337 non-dupes, 1 orient drop, 1 length drop, 335 written
# 2020-02-07 13:16:50,271 - Phyluce - INFO - ------ Working on Leptospira_ryugenii_GCF_003114855 genome ------
# 2020-02-07 13:16:50,271 - Phyluce - INFO - Reading Leptospira_ryugenii_GCF_003114855 genome
# 2020-02-07 13:16:50,886 - Phyluce - INFO - Leptospira_ryugenii_GCF_003114855: 214 uces, 3 dupes, 211 non-dupes, 0 orient drop, 9 length drop, 202 written
# 2020-02-07 13:16:50,886 - Phyluce - INFO - --- Working on Leptospira_saintgironsiae_GCF_002811765 genome ---
# 2020-02-07 13:16:50,887 - Phyluce - INFO - Reading Leptospira_saintgironsiae_GCF_002811765 genome
# 2020-02-07 13:16:51,820 - Phyluce - INFO - Leptospira_saintgironsiae_GCF_002811765: 298 uces, 5 dupes, 293 non-dupes, 4 orient drop, 6 length drop, 283 written
# 2020-02-07 13:16:51,821 - Phyluce - INFO - ----- Working on Leptospira_santarosai_GCF_000313175 genome -----
# 2020-02-07 13:16:51,821 - Phyluce - INFO - Reading Leptospira_santarosai_GCF_000313175 genome
# 2020-02-07 13:16:53,035 - Phyluce - INFO - Leptospira_santarosai_GCF_000313175: 353 uces, 1 dupes, 352 non-dupes, 15 orient drop, 3 length drop, 334 written
# 2020-02-07 13:16:53,035 - Phyluce - INFO - ---- Working on Leptospira_sarikeiensis_GCF_004769615 genome ----
# 2020-02-07 13:16:53,036 - Phyluce - INFO - Reading Leptospira_sarikeiensis_GCF_004769615 genome
# 2020-02-07 13:16:53,979 - Phyluce - INFO - Leptospira_sarikeiensis_GCF_004769615: 302 uces, 11 dupes, 291 non-dupes, 0 orient drop, 3 length drop, 288 written
# 2020-02-07 13:16:53,979 - Phyluce - INFO - ---- Working on Leptospira_selangorensis_GCF_004769405 genome ---
# 2020-02-07 13:16:53,979 - Phyluce - INFO - Reading Leptospira_selangorensis_GCF_004769405 genome
# 2020-02-07 13:16:54,952 - Phyluce - INFO - Leptospira_selangorensis_GCF_004769405: 301 uces, 5 dupes, 296 non-dupes, 4 orient drop, 6 length drop, 286 written
# 2020-02-07 13:16:54,952 - Phyluce - INFO - --- Working on Leptospira_semungkisensis_GCF_004770055 genome ---
# 2020-02-07 13:16:54,959 - Phyluce - INFO - Reading Leptospira_semungkisensis_GCF_004770055 genome
# 2020-02-07 13:16:55,910 - Phyluce - INFO - Leptospira_semungkisensis_GCF_004770055: 301 uces, 4 dupes, 297 non-dupes, 4 orient drop, 7 length drop, 286 written
# 2020-02-07 13:16:55,911 - Phyluce - INFO - --------- Working on Leptospira_sp_GCF_000347035 genome ---------
# 2020-02-07 13:16:55,911 - Phyluce - INFO - Reading Leptospira_sp_GCF_000347035 genome
# 2020-02-07 13:16:56,877 - Phyluce - INFO - Leptospira_sp_GCF_000347035: 302 uces, 6 dupes, 296 non-dupes, 4 orient drop, 5 length drop, 287 written
# 2020-02-07 13:16:56,878 - Phyluce - INFO - ------ Working on Leptospira_stimsonii_GCF_003545885 genome -----
# 2020-02-07 13:16:56,878 - Phyluce - INFO - Reading Leptospira_stimsonii_GCF_003545885 genome
# 2020-02-07 13:16:58,100 - Phyluce - INFO - Leptospira_stimsonii_GCF_003545885: 353 uces, 10 dupes, 343 non-dupes, 4 orient drop, 5 length drop, 334 written
# 2020-02-07 13:16:58,100 - Phyluce - INFO - ------ Working on Leptospira_terpstrae_GCF_000332495 genome -----
# 2020-02-07 13:16:58,101 - Phyluce - INFO - Reading Leptospira_terpstrae_GCF_000332495 genome
# 2020-02-07 13:16:58,773 - Phyluce - INFO - Leptospira_terpstrae_GCF_000332495: 223 uces, 10 dupes, 213 non-dupes, 6 orient drop, 1 length drop, 206 written
# 2020-02-07 13:16:58,773 - Phyluce - INFO - --- Working on Leptospira_tipperaryensis_GCF_001729245 genome ---
# 2020-02-07 13:16:58,773 - Phyluce - INFO - Reading Leptospira_tipperaryensis_GCF_001729245 genome
# 2020-02-07 13:17:00,008 - Phyluce - INFO - Leptospira_tipperaryensis_GCF_001729245: 354 uces, 1 dupes, 353 non-dupes, 15 orient drop, 9 length drop, 329 written
# 2020-02-07 13:17:00,008 - Phyluce - INFO - ----- Working on Leptospira_vanthielii_GCF_000332455 genome -----
# 2020-02-07 13:17:00,011 - Phyluce - INFO - Reading Leptospira_vanthielii_GCF_000332455 genome
# 2020-02-07 13:17:00,687 - Phyluce - INFO - Leptospira_vanthielii_GCF_000332455: 220 uces, 18 dupes, 202 non-dupes, 0 orient drop, 1 length drop, 201 written
# 2020-02-07 13:17:00,687 - Phyluce - INFO - ---- Working on Leptospira_venezuelensis_GCF_002150035 genome ---
# 2020-02-07 13:17:00,696 - Phyluce - INFO - Reading Leptospira_venezuelensis_GCF_002150035 genome
# 2020-02-07 13:17:01,636 - Phyluce - INFO - Leptospira_venezuelensis_GCF_002150035: 303 uces, 5 dupes, 298 non-dupes, 4 orient drop, 6 length drop, 288 written
# 2020-02-07 13:17:01,636 - Phyluce - INFO - ------- Working on Leptospira_weilii_GCF_000244815 genome -------
# 2020-02-07 13:17:01,637 - Phyluce - INFO - Reading Leptospira_weilii_GCF_000244815 genome
# 2020-02-07 13:17:02,860 - Phyluce - INFO - Leptospira_weilii_GCF_000244815: 352 uces, 18 dupes, 334 non-dupes, 0 orient drop, 0 length drop, 334 written
# 2020-02-07 13:17:02,860 - Phyluce - INFO - ------ Working on Leptospira_wolbachii_GCF_000332515 genome -----
# 2020-02-07 13:17:02,869 - Phyluce - INFO - Reading Leptospira_wolbachii_GCF_000332515 genome
# 2020-02-07 13:17:03,541 - Phyluce - INFO - Leptospira_wolbachii_GCF_000332515: 219 uces, 15 dupes, 204 non-dupes, 0 orient drop, 3 length drop, 201 written
# 2020-02-07 13:17:03,541 - Phyluce - INFO - ------- Working on Leptospira_wolffii_GCF_000306115 genome ------
# 2020-02-07 13:17:03,550 - Phyluce - INFO - Reading Leptospira_wolffii_GCF_000306115 genome
# 2020-02-07 13:17:04,509 - Phyluce - INFO - Leptospira_wolffii_GCF_000306115: 305 uces, 6 dupes, 299 non-dupes, 4 orient drop, 3 length drop, 292 written
# 2020-02-07 13:17:04,509 - Phyluce - INFO - ------ Working on Leptospira_yanagawae_GCF_000332475 genome -----
# 2020-02-07 13:17:04,510 - Phyluce - INFO - Reading Leptospira_yanagawae_GCF_000332475 genome
# 2020-02-07 13:17:05,162 - Phyluce - INFO - Leptospira_yanagawae_GCF_000332475: 217 uces, 13 dupes, 204 non-dupes, 1 orient drop, 0 length drop, 203 written
# 2020-02-07 13:17:05,163 - Phyluce - INFO - ------- Working on Leptospira_yasudae_GCF_003545925 genome ------
# 2020-02-07 13:17:05,163 - Phyluce - INFO - Reading Leptospira_yasudae_GCF_003545925 genome
# 2020-02-07 13:17:06,369 - Phyluce - INFO - Leptospira_yasudae_GCF_003545925: 354 uces, 8 dupes, 346 non-dupes, 3 orient drop, 6 length drop, 337 written
# 2020-02-07 13:17:06,369 - Phyluce - INFO - ----- Working on Leptospira_interrogans_GCF_000092565 genome ----
# 2020-02-07 13:17:06,370 - Phyluce - INFO - Reading Leptospira_interrogans_GCF_000092565 genome
# 2020-02-07 13:17:07,595 - Phyluce - INFO - Leptospira_interrogans_GCF_000092565: 354 uces, 0 dupes, 354 non-dupes, 16 orient drop, 5 length drop, 333 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/leptospira/extract_probes_from_group/probe_fasta --output results/phyluce/leptospira/extract_probes_from_group/multifastas.sqlite --base-taxon Leptospira_interrogans_GCF_000092565;
# leptospira_adleri_gcf_002811985.
# leptospira_alexanderi_gcf_000243815.
# leptospira_alstonii_gcf_000347175.
# leptospira_andrefontaineae_gcf_004770105.
# leptospira_bandrabouensis_gcf_004770905.
# leptospira_barantonii_gcf_002811925.
# leptospira_biflexa_gcf_000017685.
# leptospira_borgpetersenii_gcf_000013945.
# leptospira_bourretii_gcf_004769285.
# leptospira_bouyouniensis_gcf_004770625.
# leptospira_brenneri_gcf_002812125.
# leptospira_broomii_gcf_000243715.
# leptospira_congkakensis_gcf_004770265.
# leptospira_dzianensis_gcf_004770135.
# leptospira_dzoumogneensis_gcf_004770895.
# leptospira_ellinghausenii_gcf_003114815.
# leptospira_elllisii_gcf_002811955.
# leptospira_fainei_gcf_000306235.
# leptospira_fletcheri_gcf_004769195.
# leptospira_fluminis_gcf_004771275.
# leptospira_gomenensis_gcf_004770155.
# leptospira_haakeii_gcf_002812045.
# leptospira_harrisiae_gcf_002811945.
# leptospira_hartskeerlii_gcf_002811475.
# leptospira_idonii_gcf_004770995.
# leptospira_ilyithenensis_gcf_004771005.
# leptospira_inadai_gcf_000243675.
# leptospira_jelokensis_gcf_004769775.
# leptospira_johnsonii_gcf_003112675.
# leptospira_kanakyensis_gcf_004769235.
# leptospira_kemamanensis_gcf_004769665.
# leptospira_kirschneri_gcf_000243695.
# leptospira_kmetyi_gcf_000243735.
# leptospira_kobayashii_gcf_003114835.
# leptospira_koniamboensis_gcf_004769555.
# leptospira_langatensis_gcf_004770615.
# leptospira_levettii_gcf_002812085.
# leptospira_licerasiae_gcf_000244755.
# leptospira_macculloughii_gcf_002811975.
# leptospira_mayottensis_gcf_000306675.
# leptospira_meyeri_gcf_000304275.
# leptospira_montravelensis_gcf_004769455.
# leptospira_mtsangambouensis_gcf_004770475.
# leptospira_neocaledonica_gcf_002812205.
# leptospira_noguchii_gcf_000306255.
# leptospira_noumeaensis_gcf_004770765.
# leptospira_ognonensis_gcf_004770745.
# leptospira_perdikensis_gcf_004769575.
# leptospira_perolatii_gcf_002811875.
# leptospira_putramalaysiae_gcf_004770035.
# leptospira_ryugenii_gcf_003114855.
# leptospira_saintgironsiae_gcf_002811765.
# leptospira_santarosai_gcf_000313175.
# leptospira_sarikeiensis_gcf_004769615.
# leptospira_selangorensis_gcf_004769405.
# leptospira_semungkisensis_gcf_004770055.
# leptospira_sp_gcf_000347035.
# leptospira_stimsonii_gcf_003545885.
# leptospira_terpstrae_gcf_000332495.
# leptospira_tipperaryensis_gcf_001729245.
# leptospira_vanthielii_gcf_000332455.
# leptospira_venezuelensis_gcf_002150035.
# leptospira_weilii_gcf_000244815.
# leptospira_wolbachii_gcf_000332515.
# leptospira_wolffii_gcf_000306115.
# leptospira_yanagawae_gcf_000332475.
# leptospira_yasudae_gcf_003545925.
# leptospira_interrogans_gcf_000092565.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/leptospira/extract_probes_from_group/multifastas.sqlite --base-taxon Leptospira_interrogans_GCF_000092565;
# Loci shared by 0 taxa:	348.0
# Loci shared by 1 taxa:	348.0
# Loci shared by 2 taxa:	346.0
# Loci shared by 3 taxa:	346.0
# Loci shared by 4 taxa:	346.0
# Loci shared by 5 taxa:	346.0
# Loci shared by 6 taxa:	346.0
# Loci shared by 7 taxa:	346.0
# Loci shared by 8 taxa:	345.0
# Loci shared by 9 taxa:	345.0
# Loci shared by 10 taxa:	345.0
# Loci shared by 11 taxa:	345.0
# Loci shared by 12 taxa:	344.0
# Loci shared by 13 taxa:	342.0
# Loci shared by 14 taxa:	341.0
# Loci shared by 15 taxa:	341.0
# Loci shared by 16 taxa:	341.0
# Loci shared by 17 taxa:	341.0
# Loci shared by 18 taxa:	339.0
# Loci shared by 19 taxa:	337.0
# Loci shared by 20 taxa:	316.0
# Loci shared by 21 taxa:	313.0
# Loci shared by 22 taxa:	311.0
# Loci shared by 23 taxa:	309.0
# Loci shared by 24 taxa:	306.0
# Loci shared by 25 taxa:	305.0
# Loci shared by 26 taxa:	304.0
# Loci shared by 27 taxa:	303.0
# Loci shared by 28 taxa:	302.0
# Loci shared by 29 taxa:	301.0
# Loci shared by 30 taxa:	299.0
# Loci shared by 31 taxa:	298.0
# Loci shared by 32 taxa:	297.0
# Loci shared by 33 taxa:	297.0
# Loci shared by 34 taxa:	296.0
# Loci shared by 35 taxa:	294.0
# Loci shared by 36 taxa:	292.0
# Loci shared by 37 taxa:	290.0
# Loci shared by 38 taxa:	289.0
# Loci shared by 39 taxa:	286.0
# Loci shared by 40 taxa:	283.0
# Loci shared by 41 taxa:	273.0
# Loci shared by 42 taxa:	240.0
# Loci shared by 43 taxa:	230.0
# Loci shared by 44 taxa:	225.0
# Loci shared by 45 taxa:	223.0
# Loci shared by 46 taxa:	219.0
# Loci shared by 47 taxa:	215.0
# Loci shared by 48 taxa:	209.0
# Loci shared by 49 taxa:	207.0
# Loci shared by 50 taxa:	206.0
# Loci shared by 51 taxa:	200.0
# Loci shared by 52 taxa:	195.0
# Loci shared by 53 taxa:	191.0
# Loci shared by 54 taxa:	190.0
# Loci shared by 55 taxa:	190.0
# Loci shared by 56 taxa:	187.0
# Loci shared by 57 taxa:	185.0
# Loci shared by 58 taxa:	184.0
# Loci shared by 59 taxa:	181.0
# Loci shared by 60 taxa:	176.0
# Loci shared by 61 taxa:	173.0
# Loci shared by 62 taxa:	170.0
# Loci shared by 63 taxa:	166.0
# Loci shared by 64 taxa:	160.0
# Loci shared by 65 taxa:	151.0
# Loci shared by 66 taxa:	141.0
# Loci shared by 67 taxa:	115.0
# Loci shared by 68 taxa:	25.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(67)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/leptospira/extract_probes_from_group/multifastas.sqlite  --base-taxon Leptospira_interrogans_GCF_000092565 --output results/phyluce/leptospira/extract_probes_from_group/Leptospira_interrogans_GCF_000092565+10-back-to-67.conf --specific-counts 67;
# Counter({'leptospira_tipperaryensis_gcf_001729245': 115, 'leptospira_kirschneri_gcf_000243695': 115, 'leptospira_jelokensis_gcf_004769775': 115, 'leptospira_selangorensis_gcf_004769405': 115, 'leptospira_neocaledonica_gcf_002812205': 115, 'leptospira_johnsonii_gcf_003112675': 115, 'leptospira_venezuelensis_gcf_002150035': 115, 'leptospira_broomii_gcf_000243715': 115, 'leptospira_inadai_gcf_000243675': 115, 'leptospira_gomenensis_gcf_004770155': 115, 'leptospira_bouyouniensis_gcf_004770625': 115, 'leptospira_sp_gcf_000347035': 115, 'leptospira_noguchii_gcf_000306255': 115, 'leptospira_ryugenii_gcf_003114855': 115, 'leptospira_fletcheri_gcf_004769195': 115, 'leptospira_brenneri_gcf_002812125': 115, 'leptospira_kobayashii_gcf_003114835': 115, 'leptospira_yanagawae_gcf_000332475': 115, 'leptospira_andrefontaineae_gcf_004770105': 115, 'leptospira_bandrabouensis_gcf_004770905': 115, 'leptospira_licerasiae_gcf_000244755': 115, 'leptospira_meyeri_gcf_000304275': 115, 'leptospira_alexanderi_gcf_000243815': 115, 'leptospira_hartskeerlii_gcf_002811475': 115, 'leptospira_terpstrae_gcf_000332495': 115, 'leptospira_koniamboensis_gcf_004769555': 115, 'leptospira_fluminis_gcf_004771275': 115, 'leptospira_weilii_gcf_000244815': 115, 'leptospira_saintgironsiae_gcf_002811765': 115, 'leptospira_fainei_gcf_000306235': 115, 'leptospira_santarosai_gcf_000313175': 115, 'leptospira_yasudae_gcf_003545925': 115, 'leptospira_elllisii_gcf_002811955': 115, 'leptospira_congkakensis_gcf_004770265': 115, 'leptospira_levettii_gcf_002812085': 115, 'leptospira_wolbachii_gcf_000332515': 115, 'leptospira_dzianensis_gcf_004770135': 115, 'leptospira_mayottensis_gcf_000306675': 115, 'leptospira_mtsangambouensis_gcf_004770475': 115, 'leptospira_bourretii_gcf_004769285': 115, 'leptospira_stimsonii_gcf_003545885': 115, 'leptospira_langatensis_gcf_004770615': 115, 'leptospira_kemamanensis_gcf_004769665': 115, 'leptospira_putramalaysiae_gcf_004770035': 115, 'leptospira_kmetyi_gcf_000243735': 115, 'leptospira_interrogans_gcf_000092565': 115, 'leptospira_haakeii_gcf_002812045': 115, 'leptospira_idonii_gcf_004770995': 115, 'leptospira_adleri_gcf_002811985': 115, 'leptospira_montravelensis_gcf_004769455': 115, 'leptospira_sarikeiensis_gcf_004769615': 115, 'leptospira_noumeaensis_gcf_004770765': 115, 'leptospira_biflexa_gcf_000017685': 115, 'leptospira_semungkisensis_gcf_004770055': 115, 'leptospira_ilyithenensis_gcf_004771005': 115, 'leptospira_alstonii_gcf_000347175': 115, 'leptospira_kanakyensis_gcf_004769235': 115, 'leptospira_wolffii_gcf_000306115': 115, 'leptospira_harrisiae_gcf_002811945': 115, 'leptospira_perdikensis_gcf_004769575': 115, 'leptospira_vanthielii_gcf_000332455': 115, 'leptospira_barantonii_gcf_002811925': 115, 'leptospira_dzoumogneensis_gcf_004770895': 115, 'leptospira_ellinghausenii_gcf_003114815': 114, 'leptospira_ognonensis_gcf_004770745': 114, 'leptospira_perolatii_gcf_002811875': 114, 'leptospira_borgpetersenii_gcf_000013945': 108, 'leptospira_macculloughii_gcf_002811975': 35})
# Total loci = 115

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/leptospira/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/leptospira/extract_probes_from_group/Leptospira_interrogans_GCF_000092565+10-back-to-67.conf --probe-prefix uce_leptospira_ --designer rnplattii --design leptospira_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.fasta;
# GGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 115
# Probe Count = 15390

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.fasta --query results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  13:19:30
# Ended:  Fri Feb 07, 2020  13:20:54
# Time for execution:  1.39971166452 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.fasta --lastz results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_leptospira_;
# Parsing lastz file...
# Screening results...
# Screened 15389 fasta sequences.  Filtered 0 duplicates. Kept 15390.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.fasta
#          -o
#          results/phyluce/leptospira/final_probe_design/leptospira_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 13:54:26 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 15390
# longest and shortest : 80 and 80
# Total letters: 1231200
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 3M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 17M = 34M
# Miscellaneous   : 4M
# Total           : 90M
#
# Table limit with the given memory limit:
# Max number of representatives: 3938769
# Max number of word counting entries: 88661707
#
# # comparing sequences from          0  to       2565
# ..---------- new table with     1422 representatives
# # comparing sequences from       2565  to       4702
# ----------    894 remaining sequences to the next cycle
# ---------- new table with      798 representatives
# # comparing sequences from       3808  to       5738
# ----------    858 remaining sequences to the next cycle
# ---------- new table with      585 representatives
# # comparing sequences from       4880  to       6631
# ----------    827 remaining sequences to the next cycle
# ---------- new table with      498 representatives
# # comparing sequences from       5804  to       7401
# ----------    765 remaining sequences to the next cycle
# ---------- new table with      490 representatives
# # comparing sequences from       6636  to       8095
# ----------    692 remaining sequences to the next cycle
# ---------- new table with      469 representatives
# # comparing sequences from       7403  to       8734
# ----------    530 remaining sequences to the next cycle
# ---------- new table with      434 representatives
# # comparing sequences from       8204  to       9401
# ----------    450 remaining sequences to the next cycle
# ---------- new table with      434 representatives
# # comparing sequences from       8951  to      10024
# ----------    490 remaining sequences to the next cycle
# ---------- new table with      312 representatives
# # comparing sequences from       9534  to      10510
# ..........    10000  finished       5674  clusters
# ----------    381 remaining sequences to the next cycle
# ---------- new table with      274 representatives
# # comparing sequences from      10129  to      11005
# ----------    321 remaining sequences to the next cycle
# ---------- new table with      254 representatives
# # comparing sequences from      10684  to      11468
# ----------    327 remaining sequences to the next cycle
# ---------- new table with      275 representatives
# # comparing sequences from      11141  to      11849
# ----------    435 remaining sequences to the next cycle
# ---------- new table with      200 representatives
# # comparing sequences from      11414  to      12076
# ----------    204 remaining sequences to the next cycle
# ---------- new table with      285 representatives
# # comparing sequences from      11872  to      12458
# ----------    265 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      12193  to      12725
# ----------    126 remaining sequences to the next cycle
# ---------- new table with      191 representatives
# # comparing sequences from      12599  to      13064
# ----------    146 remaining sequences to the next cycle
# ---------- new table with      181 representatives
# # comparing sequences from      12918  to      13330
# ----------     24 remaining sequences to the next cycle
# ---------- new table with      158 representatives
# # comparing sequences from      13306  to      13653
# ----------    144 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      13509  to      13822
# ----------    131 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      13691  to      13974
# 99.9%---------- new table with      141 representatives
# # comparing sequences from      13974  to      14210
# ----------     15 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      14195  to      14394
# ----------     19 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from      14375  to      14544
# 99.9%---------- new table with       82 representatives
# # comparing sequences from      14544  to      15390
# ....................---------- new table with      413 representatives
#
#     15390  finished       8396  clusters
#
# Approximated maximum memory consumption: 91M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 2.69

# %% [markdown]
# # Listeria

# %% [markdown]
# ## Prep directory and group info

# %% [markdown]
# Create a clean directory to work from and build a list of all the taxa to include.  Desired taxa should includ Genus, species, and assembly accession like so :
#
# ```
# Genus_species_GCA_123456789
# ```
#
# In addition, for each "group" (albiet genus, phylum, etc...) we need to designate a `reference_taxon`.  This is the species/genome that all the others will be compared to.  Ideally it will be from a high quality genome.
#
# I used NCBI Genomes to identify all available __"representative"__ assemblies for each group.  I extracted the accesion numbers and genreated a csv file that looks like:
#
# ```
# $> cat data/genomes/trematode_accessions.csv
# genus,species,accession
# Clonorchis,sinensis,GCA_003604175.1
# Dicrocoelium,dendriticum,GCA_000950715.1
# Echinostoma,caproni,GCA_900618425.1
# Fasciola,gigantica,GCA_006461475.1
# Fasciola,hepatica,GCA_900302435.1
# Fasciolopsis,buski,GCA_008360955.1
# ```

# %%
group = 'listeria'

# %%
if os.path.exists("results/phyluce/" + group):
    shutil.rmtree("results/phyluce/" + group)

os.makedirs("results/phyluce/" + group)

# %%
group_taxa = [ "Listeria_aquatica_GCF_000525795",
               "Listeria_booriae_GCF_000766865",
               "Listeria_cornellensis_GCF_000525855",
               "Listeria_costaricensis_GCF_900183385",
               "Listeria_fleischmannii_GCF_000252625",
               "Listeria_floridensis_GCF_000525875",
               "Listeria_goaensis_GCF_900186125",
               "Listeria_grandensis_GCF_000525835",
               "Listeria_grayi_GCF_000148995",
               "Listeria_innocua_GCF_000195795",
               "Listeria_ivanovii_GCF_900637745",
               "Listeria_kieliensis_GCF_003369925",
               "Listeria_marthii_GCF_000183865",          
               "Listeria_newyorkensis_GCF_900461625",
               "Listeria_riparia_GCF_000525995",
               "Listeria_rocourtiae_GCF_000525975",
               "Listeria_seeligeri_GCF_000027145",
               "Listeria_sp_GCF_003856515",
               "Listeria_thailandensis_GCF_900576925",
               "Listeria_weihenstephanensis_GCF_000525955",
               "Listeria_welshimeri_GCF_900187315" ]
                    
reference_taxon = "Listeria_monocytogenes_GCF_000196035"

all_taxa = group_taxa + [ reference_taxon ]

# %% [markdown]
# ## Download genomes

# %% [markdown]
# Read from the accessions `data/genomes/*_accessions.csv` then find the ftp link, download, and format the genome file name in a standard format `Genus_species_GCA_123456789`
#
# For sanity's sake, I have saved all the ftp info in a csv file stored in `data/genomes/*group*`

# %%
#get all of the genomes and gffs for a single representative
if not os.path.exists("data/genomes/" + group):
    os.makedirs("data/genomes/" + group)
    
accession_df = pd.read_csv("data/" + group +  "_accessions.csv")
accession_w_ftp=[]

for index, row in accession_df.iterrows():
    
    #get the ftp site from the accession
    ftp=!(esearch -db assembly -query {row["accession"]} | esummary | xtract -pattern DocumentSummary -element FtpPath_GenBank)
    ftp=ftp[0].replace("ftp://", "")
    
    #generate a fas and download
    fas_ftp_link = ftp + "/" + ftp.split("/")[-1] + "_genomic.fna.gz"
    fas_rsync_cmd="rsync --copy-links --times --verbose rsync://{} data/genomes/{}".format(fas_ftp_link, group)
   
    # !{fas_rsync_cmd}

    #create "clean/standardized" name for gff and fas
    #Genus_species_GCA_12345678
    clean_fas_name = "_".join([ str(row["genus"]), str(row["species"]), row["accession"].split(".")[0]]) + ".fas.gz"

    orig_fas_name = ftp.split("/")[-1] + "_genomic.fna.gz"

    os.rename("data/genomes/" + group + "/" + orig_fas_name, "data/genomes/" + group + "/" + clean_fas_name)
    
    #finally make a table documenting changes
    #accession, fas_ftp, gff_ftp, original file name, updated file name
    xfer_info = [row["accession"], ftp, orig_fas_name, clean_fas_name]
    accession_w_ftp.append(xfer_info)
    
#convert the tableto a df
ftp_df=pd.DataFrame(accession_w_ftp, columns = ["accession", 
                                                "ftp", 
                                                "orig_fas_name", 
                                                "new_fas_name"])

#save to csv
ftp_df.to_csv("data/genomes/" + group + "/ftp_info.csv", index=False)

#finally uncompress all of the gzipped files (will be easier to manage donw the line)
# !gunzip data/genomes/{group}/*gz
# Out:
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525795.1_Listeriaceae_bacterium_FSL_S10-1188_genomic.fna.gz
#
# sent 42 bytes  received 773875 bytes  515944.67 bytes/sec
# total size is 773553  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000766865.1_ASM76686v1_genomic.fna.gz
#
# sent 42 bytes  received 1022888 bytes  681953.33 bytes/sec
# total size is 1022527  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525855.1_Listeriaceae_bacterium_FSL_F6-969_genomic.fna.gz
#
# sent 42 bytes  received 1000469 bytes  400204.40 bytes/sec
# total size is 1000093  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900183385.1_CLIP_2016_00682_genomic.fna.gz
#
# sent 42 bytes  received 950880 bytes  633948.00 bytes/sec
# total size is 950530  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000252625.2_ASM25262v2_genomic.fna.gz
#
# sent 42 bytes  received 843010 bytes  562034.67 bytes/sec
# total size is 842697  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525875.1_Listeriaceae_bacterium_FSL_S10-1187_genomic.fna.gz
#
# sent 42 bytes  received 833819 bytes  555907.33 bytes/sec
# total size is 833481  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900186125.1_ILCC801.fasta_genomic.fna.gz
#
# sent 42 bytes  received 860462 bytes  573669.33 bytes/sec
# total size is 860138  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525835.1_Listeriaceaebacterium_FSL_F6-971_genomic.fna.gz
#
# sent 42 bytes  received 950991 bytes  634022.00 bytes/sec
# total size is 950624  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000148995.1_ASM14899v1_genomic.fna.gz
#
# sent 42 bytes  received 769862 bytes  513269.33 bytes/sec
# total size is 769565  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000195795.1_ASM19579v1_genomic.fna.gz
#
# sent 42 bytes  received 911779 bytes  607880.67 bytes/sec
# total size is 911450  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_900637745.1_52551_F01_genomic.fna.gz
#
# sent 42 bytes  received 885882 bytes  590616.00 bytes/sec
# total size is 885554  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003369925.1_ASM336992v1_genomic.fna.gz
#
# sent 42 bytes  received 773749 bytes  515860.67 bytes/sec
# total size is 773451  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000183865.1_ASM18386v1_genomic.fna.gz
#
# sent 42 bytes  received 824466 bytes  549672.00 bytes/sec
# total size is 824153  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000196035.1_ASM19603v1_genomic.fna.gz
#
# sent 42 bytes  received 869721 bytes  579842.00 bytes/sec
# total size is 869400  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900461625.1_58116_G02_genomic.fna.gz
#
# sent 42 bytes  received 1042892 bytes  695289.33 bytes/sec
# total size is 1042532  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525995.1_PRIP_MIRA_assembly_genomic.fna.gz
#
# sent 42 bytes  received 981442 bytes  654322.67 bytes/sec
# total size is 981089  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525975.1_LrocourtiaeTYPE_genomic.fna.gz
#
# sent 42 bytes  received 960612 bytes  640436.00 bytes/sec
# total size is 960262  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000027145.1_ASM2714v1_genomic.fna.gz
#
# sent 42 bytes  received 823530 bytes  549048.00 bytes/sec
# total size is 823218  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_003856515.1_ASM385651v1_genomic.fna.gz
#
# sent 42 bytes  received 1068210 bytes  712168.00 bytes/sec
# total size is 1067840  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_900576925.1_CLIP201500305T_genomic.fna.gz
#
# sent 42 bytes  received 801809 bytes  534567.33 bytes/sec
# total size is 801500  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
#
#
# GCA_000525955.1_Lweihenstaphanensis_genomic.fna.gz
#
# sent 42 bytes  received 1008856 bytes  672598.67 bytes/sec
# total size is 1008494  speedup is 1.00
#
# Warning Notice!
#
# You are accessing a U.S. Government information system which includes this
# computer, network, and all attached devices. This system is for
# Government-authorized use only. Unauthorized use of this system may result in
# disciplinary action and civil and criminal penalties. System users have no
# expectation of privacy regarding any communications or data processed by this
# system. At any time, the government may monitor, record, or seize any
# communication or data transiting or stored on this information system.
#
# -------------------------------------------------------------------------------
#
# Welcome to the NCBI rsync server.
# GCA_900187315.1_52087_C01_genomic.fna.gz
#
# sent 42 bytes  received 827718 bytes  551840.00 bytes/sec
# total size is 827406  speedup is 1.00

# %% [markdown]
# ## Clean up and format genome

# %% [markdown]
# Further process the genomes so that the headers only contain the accession and then the entire genome is converted into 2bit.  These are reqs. for the `phyluce` pipeline.

# %%
if os.path.exists("results/phyluce/" + group + "/cleaned_genomes"):
    shutil.rmtree("results/phyluce/" + group + "/cleaned_genomes")

os.makedirs("results/phyluce/" + group + "/cleaned_genomes")

for sample in all_taxa:
        
        i_genome_file = "data/genomes/" + group + "/" + sample + ".fas"
        o_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
        o_2bit_file   = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
        
        with open(i_genome_file, "rU") as infile:
            with open(o_genome_file, "w") as outfile:
                for seq in SeqIO.parse(infile, 'fasta'):
                    seq.name = ""
                    seq.description = ""
                    outfile.write(seq.format('fasta'))
                    
        f2bit_cmd = "faToTwoBit {} {}".format(i_genome_file, o_2bit_file)
        subprocess.call(f2bit_cmd.split(" "))

# %% [markdown]
# ## Simluate and map reads at 10x coverage

# %% [markdown]
# Use `art` to simulate 25x coverage of error free reads for each species/genome.  In the next step these reads will all be mapped against the reference taxon to find conserved regions were we can map reads from multiple different species.
#
# A quick comment about coverage: In most cases 4-6x is acceptable. I have chosen 25x coverage because it should provide 4bp resolution on conserved orthologous regions and since my genomes are relatilvely small...I can trade compute time for resolution.
#
# __NOTE__: Here and in several other places throught the notebook(s) jobs are not run on the local machine, but instead sent to our cluster via PBS.  In these cases you cannot proceed to the next step in the pipeline/notebook untill all jobs from the current step have completed.  In some cases this mean waiting up to a few hours.  These steps are identifed in giant/commented block text.

# %%
if os.path.exists("results/phyluce/" + group + "/simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/simulated_reads")

os.makedirs("results/phyluce/" + group + "/simulated_reads/logs")

for sample in group_taxa:
    i_genome_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.fas"
    o_prefix      = "results/phyluce/" + group + "/simulated_reads/" + sample + "_"
        
    art_cmd = str("art_illumina "
                      "--paired "
                      "--len 100 "
                      "--fcov 10 "
                      "--mflen 200 "
                      "--sdev 150 "
                      "-ir 0.0 "
                      "-ir2 0.0 "
                      "-dr 0.0 "
                      "-dr2 0.0 "
                      "-qs 100 "
                      "-qs2 100 "
                      "-na "
                      "--in {} "
                      "--out {};").format(i_genome_file, o_prefix)

    #now set up qsub
    jid= "sim_" + sample
    log= "results/phyluce/" + group + "/simulated_reads/logs/sim_" + sample + ".log"
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -pe smp 12".format(jid, log)

    #conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #and submit to the queue
    combined_cmd ="echo \"" + conda_cmd + art_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}

    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483096 ("sim_Listeria_aquatica_GCF_000525795") has been submitted
# Your job 5483097 ("sim_Listeria_booriae_GCF_000766865") has been submitted
# Your job 5483098 ("sim_Listeria_cornellensis_GCF_000525855") has been submitted
# Your job 5483099 ("sim_Listeria_costaricensis_GCF_900183385") has been submitted
# Your job 5483100 ("sim_Listeria_fleischmannii_GCF_000252625") has been submitted
# Your job 5483101 ("sim_Listeria_floridensis_GCF_000525875") has been submitted
# Your job 5483102 ("sim_Listeria_goaensis_GCF_900186125") has been submitted
# Your job 5483103 ("sim_Listeria_grandensis_GCF_000525835") has been submitted
# Your job 5483104 ("sim_Listeria_grayi_GCF_000148995") has been submitted
# Your job 5483105 ("sim_Listeria_innocua_GCF_000195795") has been submitted
# Your job 5483106 ("sim_Listeria_ivanovii_GCF_900637745") has been submitted
# Your job 5483107 ("sim_Listeria_kieliensis_GCF_003369925") has been submitted
# Your job 5483108 ("sim_Listeria_marthii_GCF_000183865") has been submitted
# Your job 5483109 ("sim_Listeria_newyorkensis_GCF_900461625") has been submitted
# Your job 5483110 ("sim_Listeria_riparia_GCF_000525995") has been submitted
# Your job 5483111 ("sim_Listeria_rocourtiae_GCF_000525975") has been submitted
# Your job 5483112 ("sim_Listeria_seeligeri_GCF_000027145") has been submitted
# Your job 5483113 ("sim_Listeria_sp_GCF_003856515") has been submitted
# Your job 5483114 ("sim_Listeria_thailandensis_GCF_900576925") has been submitted
# Your job 5483115 ("sim_Listeria_weihenstephanensis_GCF_000525955") has been submitted
# Your job 5483116 ("sim_Listeria_welshimeri_GCF_900187315") has been submitted

# %% [markdown]
# Before we can map the reads to the reference taxon genome we need to index it with `bbmap`

# %%
if os.path.exists("results/phyluce/" + group + "/map_simulated_reads"):
    shutil.rmtree("results/phyluce/" + group + "/map_simulated_reads")

os.makedirs("results/phyluce/" + group + "/map_simulated_reads/logs")

#generate a bbmap index of the reference genome
i_ref_genome = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.fas"
o_dir        = "results/phyluce/" + group + "/map_simulated_reads/"

bbmap_cmd = "bbmap.sh ref={} path={}".format(i_ref_genome, o_dir)

print(bbmap_cmd)
subprocess.call(bbmap_cmd.split(" "))
# Out:
# bbmap.sh ref=results/phyluce/listeria/cleaned_genomes/Listeria_monocytogenes_GCF_000196035_formatted.fas path=results/phyluce/listeria/map_simulated_reads/
# 0

# %% [markdown]
# Now we can use bbmap to align reads from all species to the reference genome.  In this case we are allowing up to 15% divergence between the reference genome and simulated read.  Generally this number is smaller and may be adjusted for other groups, however, given the diversity of some groups a larger number may identify more orthologous regions.

# %%
#map reads to reference genome   

"results/phyluce/" + group + "/map_simulated_reads/logs"

for sample in group_taxa:
    #
    #input and output files
    i_sim_r1_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_1.fq"
    i_sim_r2_fas  = "results/phyluce/" + group + "/simulated_reads/" + sample + "_2.fq"
    i_ref_genome  = i_ref_genome
    o_sim_r12_fas = "results/phyluce/" + group + "/simulated_reads/" + sample + ".fq"
    o_bbmap_sam   = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"

    #merge r1 and r2 simulated reads
    cat_cmd = "cat {} {} >{}; ".format(i_sim_r1_fas, i_sim_r2_fas, o_sim_r12_fas)

    #map with bbmap (via qsub)
    bbmap_cmd = str("bbmap.sh t=12 "
                        "in={} "
                        "ref={} "
                        "path=results/phyluce/" + group + "/map_simulated_reads/ "
                        "out={} "
                        "minid=0.90 "
                        "mappedonly=t "
                        "ignorebadquality=t; ").format(o_sim_r12_fas, 
                                                       i_ref_genome, 
                                                       o_bbmap_sam)

    #set up qsub
    jid= "map_" + sample
    log= "results/phyluce/" + group + "/map_simulated_reads/logs/map_" + sample + ".log"
    hold = "sim_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)
    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    #submit to the queue
    combined_cmd ='echo \"' + conda_cmd + " " + cat_cmd + "  " + bbmap_cmd + '\" | ' + qsub_cmd
    #combined_cmd ='echo \"' + conda_cmd + " " + bbmap_cmd + '\" | ' + qsub_cmd

    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483117 ("map_Listeria_aquatica_GCF_000525795") has been submitted
# Your job 5483118 ("map_Listeria_booriae_GCF_000766865") has been submitted
# Your job 5483119 ("map_Listeria_cornellensis_GCF_000525855") has been submitted
# Your job 5483120 ("map_Listeria_costaricensis_GCF_900183385") has been submitted
# Your job 5483121 ("map_Listeria_fleischmannii_GCF_000252625") has been submitted
# Your job 5483122 ("map_Listeria_floridensis_GCF_000525875") has been submitted
# Your job 5483123 ("map_Listeria_goaensis_GCF_900186125") has been submitted
# Your job 5483124 ("map_Listeria_grandensis_GCF_000525835") has been submitted
# Your job 5483125 ("map_Listeria_grayi_GCF_000148995") has been submitted
# Your job 5483126 ("map_Listeria_innocua_GCF_000195795") has been submitted
# Your job 5483127 ("map_Listeria_ivanovii_GCF_900637745") has been submitted
# Your job 5483128 ("map_Listeria_kieliensis_GCF_003369925") has been submitted
# Your job 5483129 ("map_Listeria_marthii_GCF_000183865") has been submitted
# Your job 5483130 ("map_Listeria_newyorkensis_GCF_900461625") has been submitted
# Your job 5483131 ("map_Listeria_riparia_GCF_000525995") has been submitted
# Your job 5483132 ("map_Listeria_rocourtiae_GCF_000525975") has been submitted
# Your job 5483133 ("map_Listeria_seeligeri_GCF_000027145") has been submitted
# Your job 5483134 ("map_Listeria_sp_GCF_003856515") has been submitted
# Your job 5483135 ("map_Listeria_thailandensis_GCF_900576925") has been submitted
# Your job 5483136 ("map_Listeria_weihenstephanensis_GCF_000525955") has been submitted
# Your job 5483137 ("map_Listeria_welshimeri_GCF_900187315") has been submitted

# %% [markdown]
# ## Use mapped reads to find orthologous loci

# %% [markdown]
# `bbmap` aligns all reads and stores the info in a `.sam` file.  Here we use a few filtering steps to remove unmapped reads, and then sort and merge mapped reads for each species/sample.

# %%
if os.path.exists("results/phyluce/" + group + "/initial_intervals"):
    shutil.rmtree("results/phyluce/" + group + "/initial_intervals")

os.makedirs("results/phyluce/" + group + "/initial_intervals/logs")

#map reads to reference genome   
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"
    
    #sam to (filtered) bam
    i_sam = "results/phyluce/" + group + "/map_simulated_reads/" + sample + ".sam"
    o_filt_bam = o_dir + sample + ".bam"
    
    sam_cmd = "samtools view -b -F 4 {} >{};".format(i_sam, o_filt_bam)
  
    #bam to bed
    i_filt_bam = o_filt_bam
    o_bed      = o_dir + sample + ".bed"
    
    bed_to_bam_cmd = "bedtools bamtobed -i {} >{};".format(i_filt_bam, o_bed)
    
    #sort bed
    i_bed        = o_bed
    o_sorted_bed = o_dir + sample +  "_sorted.bed"
    
    sort_bed_cmd = "bedtools sort -i {} >{};".format(i_bed, o_sorted_bed)
    
    #merge bed
    i_sorted_bed   = o_sorted_bed
    o_interval_bed = o_dir + sample +  "_merged.bed"
    
    merge_cmd = "bedtools merge -i {} >{};".format(i_sorted_bed, o_interval_bed)
    
    #set up qsub
    jid= "merge_" + sample
    log= o_dir + "logs/merge_" + sample + ".log"
    hold = "map_" + sample
    qsub_cmd = "qsub -V -cwd -S /bin/bash -q all.q -j y -N {} -o {} -hold_jid {} -pe smp 12".format(jid, 
                                                                                                    log, 
                                                                                                    hold)

    #and conda
    conda_cmd = "conda activate pathogen_probes-phyluce; "

    bed_cmd = sam_cmd + bed_to_bam_cmd + sort_bed_cmd + merge_cmd
    
    combined_cmd ="echo \"" + conda_cmd + bed_cmd + "\" | " + qsub_cmd
    
    #print(combined_cmd)
    # !{combined_cmd}
    
#################################################################################################
#  __          __     _____ _______   ______ ____  _____     ____  _    _ ______ _    _ ______  #
#  \ \        / /\   |_   _|__   __| |  ____/ __ \|  __ \   / __ \| |  | |  ____| |  | |  ____| #
#   \ \  /\  / /  \    | |    | |    | |__ | |  | | |__) | | |  | | |  | | |__  | |  | | |__    #
#    \ \/  \/ / /\ \   | |    | |    |  __|| |  | |  _  /  | |  | | |  | |  __| | |  | |  __|   #
#     \  /\  / ____ \ _| |_   | |    | |   | |__| | | \ \  | |__| | |__| | |____| |__| | |____  #
#      \/  \/_/    \_\_____|  |_|    |_|    \____/|_|  \_\  \___\_\\____/|______|\____/|______| #
#                                                                                               #
#################################################################################################
#wait_on_running_jobs()
# Out:
# Your job 5483138 ("merge_Listeria_aquatica_GCF_000525795") has been submitted
# Your job 5483139 ("merge_Listeria_booriae_GCF_000766865") has been submitted
# Your job 5483140 ("merge_Listeria_cornellensis_GCF_000525855") has been submitted
# Your job 5483141 ("merge_Listeria_costaricensis_GCF_900183385") has been submitted
# Your job 5483142 ("merge_Listeria_fleischmannii_GCF_000252625") has been submitted
# Your job 5483143 ("merge_Listeria_floridensis_GCF_000525875") has been submitted
# Your job 5483144 ("merge_Listeria_goaensis_GCF_900186125") has been submitted
# Your job 5483145 ("merge_Listeria_grandensis_GCF_000525835") has been submitted
# Your job 5483146 ("merge_Listeria_grayi_GCF_000148995") has been submitted
# Your job 5483147 ("merge_Listeria_innocua_GCF_000195795") has been submitted
# Your job 5483148 ("merge_Listeria_ivanovii_GCF_900637745") has been submitted
# Your job 5483149 ("merge_Listeria_kieliensis_GCF_003369925") has been submitted
# Your job 5483150 ("merge_Listeria_marthii_GCF_000183865") has been submitted
# Your job 5483151 ("merge_Listeria_newyorkensis_GCF_900461625") has been submitted
# Your job 5483152 ("merge_Listeria_riparia_GCF_000525995") has been submitted
# Your job 5483153 ("merge_Listeria_rocourtiae_GCF_000525975") has been submitted
# Your job 5483154 ("merge_Listeria_seeligeri_GCF_000027145") has been submitted
# Your job 5483155 ("merge_Listeria_sp_GCF_003856515") has been submitted
# Your job 5483156 ("merge_Listeria_thailandensis_GCF_900576925") has been submitted
# Your job 5483157 ("merge_Listeria_weihenstephanensis_GCF_000525955") has been submitted
# Your job 5483158 ("merge_Listeria_welshimeri_GCF_900187315") has been submitted

# %% [markdown]
# remove loci that were masked in the original genome

# %%
#strip repeats
for sample in group_taxa:
    
    o_dir = "results/phyluce/" + group + "/initial_intervals/"

    #input and output files
    i_merged_bed   = o_dir + sample + "_merged.bed"
    i_genome_2bit  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
    o_stripped_bed = o_dir + sample + "_stripped.bed"

    #repeat strip w/ phyluce
    phyluce_cmd = str("phyluce_probe_strip_masked_loci_from_set "
                          "--filter-mask 0.25 "
                          "--min-length 160 "
                          "--bed {} "
                          "--twobit {} " 
                          "--output {};").format(i_merged_bed,
                                                 i_genome_2bit,
                                                 o_stripped_bed)
    # !{phyluce_cmd}
# Out:
# Screened 196 sequences from Listeria_aquatica_GCF_000525795_merged.bed.  Filtered 131 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 65.
# Screened 308 sequences from Listeria_booriae_GCF_000766865_merged.bed.  Filtered 205 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 103.
# Screened 220 sequences from Listeria_cornellensis_GCF_000525855_merged.bed.  Filtered 138 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 82.
# Screened 248 sequences from Listeria_costaricensis_GCF_900183385_merged.bed.  Filtered 164 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 84.
# Screened 268 sequences from Listeria_fleischmannii_GCF_000252625_merged.bed.  Filtered 176 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 92.
# Screened 242 sequences from Listeria_floridensis_GCF_000525875_merged.bed.  Filtered 167 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 75.
# Screened 263 sequences from Listeria_goaensis_GCF_900186125_merged.bed.  Filtered 167 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 96.
# Screened 231 sequences from Listeria_grandensis_GCF_000525835_merged.bed.  Filtered 156 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 75.
# Screened 228 sequences from Listeria_grayi_GCF_000148995_merged.bed.  Filtered 137 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 91.
# Screened 3801 sequences from Listeria_innocua_GCF_000195795_merged.bed.  Filtered 1357 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 2444.
# Screened 2848 sequences from Listeria_ivanovii_GCF_900637745_merged.bed.  Filtered 1397 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 1451.
# Screened 205 sequences from Listeria_kieliensis_GCF_003369925_merged.bed.  Filtered 146 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 59.
# Screened 4140 sequences from Listeria_marthii_GCF_000183865_merged.bed.  Filtered 1384 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 2756.
# Screened 243 sequences from Listeria_newyorkensis_GCF_900461625_merged.bed.  Filtered 155 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 88.
# Screened 247 sequences from Listeria_riparia_GCF_000525995_merged.bed.  Filtered 177 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 70.
# Screened 207 sequences from Listeria_rocourtiae_GCF_000525975_merged.bed.  Filtered 139 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 68.
# Screened 2935 sequences from Listeria_seeligeri_GCF_000027145_merged.bed.  Filtered 1428 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 1507.
# Screened 246 sequences from Listeria_sp_GCF_003856515_merged.bed.  Filtered 165 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 81.
# Screened 201 sequences from Listeria_thailandensis_GCF_900576925_merged.bed.  Filtered 148 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 53.
# Screened 253 sequences from Listeria_weihenstephanensis_GCF_000525955_merged.bed.  Filtered 167 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 86.
# Screened 3902 sequences from Listeria_welshimeri_GCF_900187315_merged.bed.  Filtered 1512 with > 25.0% masked bases or > 0 N-bases or < 160 length. Kept 2390.

# %% [markdown]
# ## Find conserved loci across taxa

# %% [markdown]
# We used phyluce to find regions that are consistently mapped ("conserved") across various taxa.
#
# First, make ```conf``` file that indicates where the stripped bedfiles (from above) are stored.
#
# ```
# [beds]
# agrPla1:agrPla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# anoGla1:anoGla1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# denPon1:denPon1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# lepDec1:lepDec1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ontTau1:ontTau1-to-triCas1-MAPPING.bam.sort.merge.strip.bed
# ```

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
o_bed_conf = o_dir + group + "_bed-files.conf"

with open(o_bed_conf, "w") as outfile:

    #print the header line
    outfile.write("[beds]\n")

    #print bedinfo for each species for the genus
    for sample in group_taxa:
        stripped_bed = o_dir + sample + "_stripped.bed"

        outfile.write(sample + ":" + stripped_bed + "\n")

# %% [markdown]
# Then merge all of the data into a single ```sqlite``` db.

# %%
#make output file
o_dir      = "results/phyluce/" + group + "/initial_intervals/"
i_bed_conf = o_dir + group + "_bed-files.conf"

#now run phyluce to get table of orthologous sequeneces across the genus
o_sqlite_db = o_dir + group + "-to-" + reference_taxon + ".sqlite"

phyluce_merge_cmd=str("phyluce_probe_get_multi_merge_table "
                          "--conf {} "
                          "--base-taxon {} "
                          "--output {};").format(o_bed_conf,
                                                 reference_taxon,
                                                 o_sqlite_db)
print(phyluce_cmd)
# !{phyluce_merge_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/listeria/initial_intervals/Listeria_welshimeri_GCF_900187315_merged.bed --twobit results/phyluce/listeria/cleaned_genomes/Listeria_monocytogenes_GCF_000196035_formatted.2bit --output results/phyluce/listeria/initial_intervals/Listeria_welshimeri_GCF_900187315_stripped.bed;
# listeria_aquatica_gcf_000525795.
# listeria_booriae_gcf_000766865.
# listeria_cornellensis_gcf_000525855.
# listeria_costaricensis_gcf_900183385.
# listeria_fleischmannii_gcf_000252625.
# listeria_floridensis_gcf_000525875.
# listeria_goaensis_gcf_900186125.
# listeria_grandensis_gcf_000525835.
# listeria_grayi_gcf_000148995.
# listeria_innocua_gcf_000195795...
# listeria_ivanovii_gcf_900637745..
# listeria_kieliensis_gcf_003369925.
# listeria_marthii_gcf_000183865...
# listeria_newyorkensis_gcf_900461625.
# listeria_riparia_gcf_000525995.
# listeria_rocourtiae_gcf_000525975.
# listeria_seeligeri_gcf_000027145..
# listeria_sp_gcf_003856515.
# listeria_thailandensis_gcf_900576925.
# listeria_weihenstephanensis_gcf_000525955.
# listeria_welshimeri_gcf_900187315...
# Creating database
# Inserting results

# %% [markdown]
# Quantify probes and the number of targeted taxa for each.

# %%
#get genus and species
i_sqlite_db = o_sqlite_db

phyluce_query_cmd = "phyluce_probe_query_multi_merge_table --db {} --base-taxon {}".format(i_sqlite_db,
                                                                                           reference_taxon)

print(phyluce_cmd)
# !{phyluce_query_cmd}
# Out:
# phyluce_probe_strip_masked_loci_from_set --filter-mask 0.25 --min-length 160 --bed results/phyluce/listeria/initial_intervals/Listeria_welshimeri_GCF_900187315_merged.bed --twobit results/phyluce/listeria/cleaned_genomes/Listeria_monocytogenes_GCF_000196035_formatted.2bit --output results/phyluce/listeria/initial_intervals/Listeria_welshimeri_GCF_900187315_stripped.bed;
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 0 taxa:	3,661.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 1 taxa:	3,661.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 2 taxa:	2,643.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 3 taxa:	2,008.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 4 taxa:	1,323.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 5 taxa:	913.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 6 taxa:	214.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 7 taxa:	156.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 8 taxa:	132.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 9 taxa:	121.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 10 taxa:	109.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 11 taxa:	92.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 12 taxa:	85.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 13 taxa:	71.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 14 taxa:	62.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 15 taxa:	52.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 16 taxa:	43.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 17 taxa:	39.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 18 taxa:	30.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 19 taxa:	27.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 20 taxa:	24.0
# Loci shared by Listeria_monocytogenes_GCF_000196035 + 21 taxa:	14.0

# %%
o_dir      = "results/phyluce/" + group + "/initial_intervals/"

#set up input and output files
num_taxa = 6
i_sqlite_db = o_sqlite_db
out_bed = o_dir + reference_taxon + "_+" + str(num_taxa) + ".bed"

phyluce_cmd = str("phyluce_probe_query_multi_merge_table "
                      "--db {} "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db,
                                                      reference_taxon,
                                                      out_bed,
                                                      num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_merge_table --db results/phyluce/listeria/initial_intervals/listeria-to-Listeria_monocytogenes_GCF_000196035.sqlite --base-taxon Listeria_monocytogenes_GCF_000196035 --output results/phyluce/listeria/initial_intervals/Listeria_monocytogenes_GCF_000196035_+6.bed --specific-counts 6;
# Counter({'listeria_welshimeri_gcf_900187315': 213, 'listeria_seeligeri_gcf_000027145': 212, 'listeria_innocua_gcf_000195795': 211, 'listeria_ivanovii_gcf_900637745': 210, 'listeria_marthii_gcf_000183865': 199, 'listeria_goaensis_gcf_900186125': 100, 'listeria_grayi_gcf_000148995': 95, 'listeria_newyorkensis_gcf_900461625': 92, 'listeria_fleischmannii_gcf_000252625': 90, 'listeria_weihenstephanensis_gcf_000525955': 89, 'listeria_booriae_gcf_000766865': 89, 'listeria_sp_gcf_003856515': 87, 'listeria_cornellensis_gcf_000525855': 85, 'listeria_costaricensis_gcf_900183385': 83, 'listeria_grandensis_gcf_000525835': 80, 'listeria_rocourtiae_gcf_000525975': 78, 'listeria_riparia_gcf_000525995': 76, 'listeria_floridensis_gcf_000525875': 75, 'listeria_aquatica_gcf_000525795': 64, 'listeria_kieliensis_gcf_003369925': 61, 'listeria_thailandensis_gcf_900576925': 52})

# %% [markdown]
# ## Design temp set of baits

# %%
o_dir = "results/phyluce/" + group + "/validate_intervals/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.makedirs(o_dir)


i_2bit_genome  = "results/phyluce/" + group + "/cleaned_genomes/" + reference_taxon + "_formatted.2bit"
i_interval_bed = "results/phyluce/" + group + "/initial_intervals/" + reference_taxon + "_+" + str(num_taxa) + ".bed"
i_bp_buffer    = 160
o_interval_fas = o_dir + reference_taxon + "_+" + str(num_taxa) + ".fasta"

phyluce_cmd = str("phyluce_probe_get_genome_sequences_from_bed "
                      "--bed {} "
                      "--twobit {} "
                      "--buffer-to {} "
                      "--output {};").format(i_interval_bed,
                                             i_2bit_genome,
                                             i_bp_buffer,
                                             o_interval_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_genome_sequences_from_bed --bed results/phyluce/listeria/initial_intervals/Listeria_monocytogenes_GCF_000196035_+6.bed --twobit results/phyluce/listeria/cleaned_genomes/Listeria_monocytogenes_GCF_000196035_formatted.2bit --buffer-to 160 --output results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6.fasta;
# Screened 214 sequences.  Filtered 0 < 160 bp or with > 25.0% masked bases or > 0 N-bases. Kept 214.

# %% [markdown]
# design the baits

# %%
i_interval_fas   = o_interval_fas
i_probe_prefix   = "uce_" + group + "_"
i_design_txt     = group + "_v1"
i_designer_txt   = "rnplattii"
i_tiling_density = "3"
o_probes_fas     = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas"



phyluce_cmd = str("phyluce_probe_get_tiled_probes "
                      "--input {} "
                      "--probe-prefix {} "
                      "--design {} "
                      "--designer {} "
                      "--tiling-density {} "
                      "--two-probes "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--output {}").format(i_interval_fas, 
                                            i_probe_prefix, 
                                            i_design_txt, 
                                            i_designer_txt, 
                                            i_tiling_density,
                                            o_probes_fas)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probes --input results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6.fasta --probe-prefix uce_listeria_ --design listeria_v1 --designer rnplattii --tiling-density 3 --two-probes --overlap middle --masking 0.25 --remove-gc --output results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas
# Probes removed for masking (.) / low GC % (G) / ambiguous bases (N):
# GGGG
#
#
# Conserved locus count = 213
# Probe Count = 424

# %% [markdown]
# ## Find duplicate baited regions

# %%
#find duplicated probes within the probes set by a self v self lastz search
#set up input and output files
i_probes_fas   = o_probes_fas
i_identity_int = str(50)
i_coverage_int = str(50)

o_probe_lastz  = o_dir + reference_taxon + "_+" + str(num_taxa) + "_temp_probes_vself.lastz"

phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity {} "
                      "--coverage {} "
                      "--output {};").format(i_probes_fas, 
                                             i_probes_fas, 
                                             i_identity_int, 
                                             i_coverage_int, 
                                             o_probe_lastz)

print(phyluce_cmd)
# !{phyluce_cmd}


#remove duplicated probes
phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz \
                      --fasta {}  \
                      --lastz {} \
                      --probe-prefix={};").format(i_probes_fas, 
                                                  o_probe_lastz,
                                                  i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas --query results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas --identity 50 --coverage 50 --output results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes_vself.lastz;
# Started:  Fri Feb 07, 2020  10:43:07
# Ended:  Fri Feb 07, 2020  10:43:07
# Time for execution:  0.00404454867045 minutes
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz                       --fasta results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas                        --lastz results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes_vself.lastz                       --probe-prefix=uce_listeria_;
# Parsing lastz file...
# Screening results...
# Screened 423 fasta sequences.  Filtered 19 duplicates. Kept 386.

# %% [markdown]
# ## Find orthologous seqs in other taxa (via lastz)

# %% [markdown]
# Create a modified genome dir structure to work with phyluce

# %%
#need to set up soft links to make this work properly
for sample in all_taxa:
    
    src_file = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "_formatted.2bit"
    
    dst_dir  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/"
    dst_file = dst_dir + sample + ".2bit"
    
    if os.path.exists(dst_dir):
        shutil.rmtree(dst_dir)
        
    os.mkdir(dst_dir)
    copy(src_file, dst_file)

# %% [markdown]
# Use phyluce to run lastz runs against each genome in group

# %%
i_probes_fas    = i_probes_fas
i_genome_list   = " ".join(all_taxa)
i_genome_dir    = "results/phyluce/" + group + "/cleaned_genomes"
i_percident_int = str(30)
i_ncores_int    = str(4)
o_sqlite_db     = o_dir + group + "-to-" + reference_taxon + ".sqlite"
o_lastz_dir     = o_dir + "lastz/"

phyluce_cmd = str("phyluce_probe_run_multiple_lastzs_sqlite "
                      "--probefile {} "
                      "--scaffoldlist {} "
                      "--genome-base-path {} "
                      "--identity {} "
                      "--cores {} "
                      "--db {} "
                      "--output {};").format(i_probes_fas, 
                                             i_genome_list, 
                                             i_genome_dir,
                                             i_percident_int,
                                             i_ncores_int,
                                             o_sqlite_db,
                                             o_lastz_dir)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_run_multiple_lastzs_sqlite --probefile results/phyluce/listeria/validate_intervals/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas --scaffoldlist Listeria_aquatica_GCF_000525795 Listeria_booriae_GCF_000766865 Listeria_cornellensis_GCF_000525855 Listeria_costaricensis_GCF_900183385 Listeria_fleischmannii_GCF_000252625 Listeria_floridensis_GCF_000525875 Listeria_goaensis_GCF_900186125 Listeria_grandensis_GCF_000525835 Listeria_grayi_GCF_000148995 Listeria_innocua_GCF_000195795 Listeria_ivanovii_GCF_900637745 Listeria_kieliensis_GCF_003369925 Listeria_marthii_GCF_000183865 Listeria_newyorkensis_GCF_900461625 Listeria_riparia_GCF_000525995 Listeria_rocourtiae_GCF_000525975 Listeria_seeligeri_GCF_000027145 Listeria_sp_GCF_003856515 Listeria_thailandensis_GCF_900576925 Listeria_weihenstephanensis_GCF_000525955 Listeria_welshimeri_GCF_900187315 Listeria_monocytogenes_GCF_000196035 --genome-base-path results/phyluce/listeria/cleaned_genomes --identity 30 --cores 4 --db results/phyluce/listeria/validate_intervals/listeria-to-Listeria_monocytogenes_GCF_000196035.sqlite --output results/phyluce/listeria/validate_intervals/lastz/;
#
# Running against Listeria_aquatica_GCF_000525795.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpr0gi0n.fasta
#
# Writing the results file...
# 	/tmp/tmp4pQPy2.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_aquatica_GCF_000525795.lastz
# Creating Listeria_aquatica_GCF_000525795 table
# Inserting data to Listeria_aquatica_GCF_000525795 table
#
# Running against Listeria_booriae_GCF_000766865.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpmHcBZj.fasta
#
# Writing the results file...
# 	/tmp/tmpKlhqX0.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_booriae_GCF_000766865.lastz
# Creating Listeria_booriae_GCF_000766865 table
# Inserting data to Listeria_booriae_GCF_000766865 table
#
# Running against Listeria_cornellensis_GCF_000525855.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpbV3xDu.fasta
#
# Writing the results file...
# 	/tmp/tmpLzAjc4.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_cornellensis_GCF_000525855.lastz
# Creating Listeria_cornellensis_GCF_000525855 table
# Inserting data to Listeria_cornellensis_GCF_000525855 table
#
# Running against Listeria_costaricensis_GCF_900183385.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp4sFenA.fasta
#
# Writing the results file...
# 	/tmp/tmpW_j3Mf.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_costaricensis_GCF_900183385.lastz
# Creating Listeria_costaricensis_GCF_900183385 table
# Inserting data to Listeria_costaricensis_GCF_900183385 table
#
# Running against Listeria_fleischmannii_GCF_000252625.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpwUEkkI.fasta
#
# Writing the results file...
# 	/tmp/tmpmKcyWF.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_fleischmannii_GCF_000252625.lastz
# Creating Listeria_fleischmannii_GCF_000252625 table
# Inserting data to Listeria_fleischmannii_GCF_000252625 table
#
# Running against Listeria_floridensis_GCF_000525875.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpv6ieIy.fasta
#
# Writing the results file...
# 	/tmp/tmpwyQ19a.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_floridensis_GCF_000525875.lastz
# Creating Listeria_floridensis_GCF_000525875 table
# Inserting data to Listeria_floridensis_GCF_000525875 table
#
# Running against Listeria_goaensis_GCF_900186125.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpsmcN57.fasta
#
# Writing the results file...
# 	/tmp/tmpa4tJtY.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_goaensis_GCF_900186125.lastz
# Creating Listeria_goaensis_GCF_900186125 table
# Inserting data to Listeria_goaensis_GCF_900186125 table
#
# Running against Listeria_grandensis_GCF_000525835.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp9fSHQt.fasta
#
# Writing the results file...
# 	/tmp/tmpPWKrBu.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_grandensis_GCF_000525835.lastz
# Creating Listeria_grandensis_GCF_000525835 table
# Inserting data to Listeria_grandensis_GCF_000525835 table
#
# Running against Listeria_grayi_GCF_000148995.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpIWkPol.fasta
#
# Writing the results file...
# 	/tmp/tmpdUH6qX.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_grayi_GCF_000148995.lastz
# Creating Listeria_grayi_GCF_000148995 table
# Inserting data to Listeria_grayi_GCF_000148995 table
#
# Running against Listeria_innocua_GCF_000195795.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpddjfH9.fasta
#
# Writing the results file...
# 	/tmp/tmpV1LXHy.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_innocua_GCF_000195795.lastz
# Creating Listeria_innocua_GCF_000195795 table
# Inserting data to Listeria_innocua_GCF_000195795 table
#
# Running against Listeria_ivanovii_GCF_900637745.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpyCdCrx.fasta
#
# Writing the results file...
# 	/tmp/tmpA3z4Uj.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_ivanovii_GCF_900637745.lastz
# Creating Listeria_ivanovii_GCF_900637745 table
# Inserting data to Listeria_ivanovii_GCF_900637745 table
#
# Running against Listeria_kieliensis_GCF_003369925.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpYAnE_S.fasta
#
# Writing the results file...
# 	/tmp/tmpqMSdRX.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_kieliensis_GCF_003369925.lastz
# Creating Listeria_kieliensis_GCF_003369925 table
# Inserting data to Listeria_kieliensis_GCF_003369925 table
#
# Running against Listeria_marthii_GCF_000183865.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpB0NGc8.fasta
#
# Writing the results file...
# 	/tmp/tmpvP1t1O.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_marthii_GCF_000183865.lastz
# Creating Listeria_marthii_GCF_000183865 table
# Inserting data to Listeria_marthii_GCF_000183865 table
#
# Running against Listeria_newyorkensis_GCF_900461625.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpaTHJLW.fasta
#
# Writing the results file...
# 	/tmp/tmpoe7aR1.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_newyorkensis_GCF_900461625.lastz
# Creating Listeria_newyorkensis_GCF_900461625 table
# Inserting data to Listeria_newyorkensis_GCF_900461625 table
#
# Running against Listeria_riparia_GCF_000525995.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmptsfym0.fasta
#
# Writing the results file...
# 	/tmp/tmpBH4ick.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_riparia_GCF_000525995.lastz
# Creating Listeria_riparia_GCF_000525995 table
# Inserting data to Listeria_riparia_GCF_000525995 table
#
# Running against Listeria_rocourtiae_GCF_000525975.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpz8wgiJ.fasta
#
# Writing the results file...
# 	/tmp/tmpNlZhgR.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_rocourtiae_GCF_000525975.lastz
# Creating Listeria_rocourtiae_GCF_000525975 table
# Inserting data to Listeria_rocourtiae_GCF_000525975 table
#
# Running against Listeria_seeligeri_GCF_000027145.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpZZ8Uxu.fasta
#
# Writing the results file...
# 	/tmp/tmpk62b0s.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_seeligeri_GCF_000027145.lastz
# Creating Listeria_seeligeri_GCF_000027145 table
# Inserting data to Listeria_seeligeri_GCF_000027145 table
#
# Running against Listeria_sp_GCF_003856515.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpsu1hg2.fasta
#
# Writing the results file...
# 	/tmp/tmpDhlGsC.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_sp_GCF_003856515.lastz
# Creating Listeria_sp_GCF_003856515 table
# Inserting data to Listeria_sp_GCF_003856515 table
#
# Running against Listeria_thailandensis_GCF_900576925.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpDolh59.fasta
#
# Writing the results file...
# 	/tmp/tmpQsUg9U.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_thailandensis_GCF_900576925.lastz
# Creating Listeria_thailandensis_GCF_900576925 table
# Inserting data to Listeria_thailandensis_GCF_900576925 table
#
# Running against Listeria_weihenstephanensis_GCF_000525955.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp53Bi5K.fasta
#
# Writing the results file...
# 	/tmp/tmpn50LTE.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_weihenstephanensis_GCF_000525955.lastz
# Creating Listeria_weihenstephanensis_GCF_000525955 table
# Inserting data to Listeria_weihenstephanensis_GCF_000525955 table
#
# Running against Listeria_welshimeri_GCF_900187315.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmpz9mcLb.fasta
#
# Writing the results file...
# 	/tmp/tmpxMolnK.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_welshimeri_GCF_900187315.lastz
# Creating Listeria_welshimeri_GCF_900187315 table
# Inserting data to Listeria_welshimeri_GCF_900187315 table
#
# Running against Listeria_monocytogenes_GCF_000196035.2bit
# Running with the --huge option.  Chunking files into 10000000 bp...
# Running the targets against 1 queries...
# 	/tmp/tmp_muMJ1.fasta
#
# Writing the results file...
# 	/tmp/tmprLY3da.lastz
# Cleaning up the chunked files...
# Cleaning /master/nplatt/pathogen_probes/results/phyluce/listeria/validate_intervals/lastz/Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_Listeria_monocytogenes_GCF_000196035.lastz
# Creating Listeria_monocytogenes_GCF_000196035 table
# Inserting data to Listeria_monocytogenes_GCF_000196035 table

# %% [markdown]
# ## Extract seqeunces from group genomes

# %% [markdown]
# make a conf file with the following format
#
# ```
# [scaffolds]
# menMol1:/path/to/uce-coleoptera/genomes/menMol1/menMol1.2bit
# agrPla1:/path/to/uce-coleoptera/genomes/agrPla1/agrPla1.2bit
# anoGla1:/path/to/uce-coleoptera/genomes/anoGla1/anoGla1.2bit
# denPon1:/path/to/uce-coleoptera/genomes/denPon1/denPon1.2bit
# lepDec1:/path/to/uce-coleoptera/genomes/lepDec1/lepDec1.2bit
# ontTau1:/path/to/uce-coleoptera/genomes/ontTau1/ontTau1.2bit
# triCas1:/path/to/uce-coleoptera/genomes/triCas1/triCas1.2bit
# ```

# %%
o_dir = "results/phyluce/" + group + "/extract_probes_from_group/"
if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

o_scaff_conf = o_dir + group + "_genome.conf"

in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"
with open(o_scaff_conf, "w") as outfile:

    #print the header line
    outfile.write("[scaffolds]\n")

    #print bedinfo for each species for the genus
    for sample in all_taxa:
        in_2bit_dest  = "results/phyluce/" + group + "/cleaned_genomes/" + sample + "/" + sample + ".2bit"

        outfile.write(sample + ":" + in_2bit_dest + "\n")     


i_scaff_conf   = o_scaff_conf
i_lastz        = "results/phyluce/" + group + "/validate_intervals/lastz"
i_bp_int       = str(120)
i_name_pattern = "\"" + reference_taxon + "_+" + str(num_taxa) + "_temp_probes.fas_v_{}.lastz.clean\""
i_probe_prefix = "uce_" + group + "_"
o_probe_dir    = o_dir + "probe_fasta"

phyluce_cmd = str("phyluce_probe_slice_sequence_from_genomes "
                      "--conf {} "
                      "--lastz {} "
                      "--probes {} "
                      "--probe-prefix {} "
                      "--name-pattern {} "
                      "--output {};").format(i_scaff_conf, 
                                             i_lastz, 
                                             i_bp_int,
                                             i_probe_prefix,
                                             i_name_pattern, 
                                             o_probe_dir)
print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_slice_sequence_from_genomes --conf results/phyluce/listeria/extract_probes_from_group/listeria_genome.conf --lastz results/phyluce/listeria/validate_intervals/lastz --probes 120 --probe-prefix uce_listeria_ --name-pattern "Listeria_monocytogenes_GCF_000196035_+6_temp_probes.fas_v_{}.lastz.clean" --output results/phyluce/listeria/extract_probes_from_group/probe_fasta;
# 2020-02-07 10:43:50,288 - Phyluce - INFO - =================== Starting Phyluce: Slice Sequence ===================
# 2020-02-07 10:43:50,291 - Phyluce - INFO - ------- Working on Listeria_aquatica_GCF_000525795 genome -------
# 2020-02-07 10:43:50,292 - Phyluce - INFO - Reading Listeria_aquatica_GCF_000525795 genome
# 2020-02-07 10:43:51,135 - Phyluce - INFO - Listeria_aquatica_GCF_000525795: 210 uces, 25 dupes, 185 non-dupes, 0 orient drop, 0 length drop, 185 written
# 2020-02-07 10:43:51,135 - Phyluce - INFO - -------- Working on Listeria_booriae_GCF_000766865 genome -------
# 2020-02-07 10:43:51,135 - Phyluce - INFO - Reading Listeria_booriae_GCF_000766865 genome
# 2020-02-07 10:43:51,898 - Phyluce - INFO - Listeria_booriae_GCF_000766865: 211 uces, 19 dupes, 192 non-dupes, 0 orient drop, 2 length drop, 190 written
# 2020-02-07 10:43:51,898 - Phyluce - INFO - ----- Working on Listeria_cornellensis_GCF_000525855 genome -----
# 2020-02-07 10:43:51,898 - Phyluce - INFO - Reading Listeria_cornellensis_GCF_000525855 genome
# 2020-02-07 10:43:52,670 - Phyluce - INFO - Listeria_cornellensis_GCF_000525855: 210 uces, 22 dupes, 188 non-dupes, 0 orient drop, 4 length drop, 184 written
# 2020-02-07 10:43:52,670 - Phyluce - INFO - ----- Working on Listeria_costaricensis_GCF_900183385 genome ----
# 2020-02-07 10:43:52,671 - Phyluce - INFO - Reading Listeria_costaricensis_GCF_900183385 genome
# 2020-02-07 10:43:53,394 - Phyluce - INFO - Listeria_costaricensis_GCF_900183385: 203 uces, 18 dupes, 185 non-dupes, 0 orient drop, 1 length drop, 184 written
# 2020-02-07 10:43:53,394 - Phyluce - INFO - ----- Working on Listeria_fleischmannii_GCF_000252625 genome ----
# 2020-02-07 10:43:53,395 - Phyluce - INFO - Reading Listeria_fleischmannii_GCF_000252625 genome
# 2020-02-07 10:43:54,126 - Phyluce - INFO - Listeria_fleischmannii_GCF_000252625: 208 uces, 19 dupes, 189 non-dupes, 0 orient drop, 0 length drop, 188 written
# 2020-02-07 10:43:54,126 - Phyluce - INFO - ------ Working on Listeria_floridensis_GCF_000525875 genome -----
# 2020-02-07 10:43:54,129 - Phyluce - INFO - Reading Listeria_floridensis_GCF_000525875 genome
# 2020-02-07 10:43:54,909 - Phyluce - INFO - Listeria_floridensis_GCF_000525875: 211 uces, 24 dupes, 187 non-dupes, 0 orient drop, 0 length drop, 187 written
# 2020-02-07 10:43:54,909 - Phyluce - INFO - ------- Working on Listeria_goaensis_GCF_900186125 genome -------
# 2020-02-07 10:43:54,910 - Phyluce - INFO - Reading Listeria_goaensis_GCF_900186125 genome
# 2020-02-07 10:43:55,657 - Phyluce - INFO - Listeria_goaensis_GCF_900186125: 205 uces, 19 dupes, 186 non-dupes, 0 orient drop, 0 length drop, 186 written
# 2020-02-07 10:43:55,658 - Phyluce - INFO - ------ Working on Listeria_grandensis_GCF_000525835 genome ------
# 2020-02-07 10:43:55,658 - Phyluce - INFO - Reading Listeria_grandensis_GCF_000525835 genome
# 2020-02-07 10:43:56,451 - Phyluce - INFO - Listeria_grandensis_GCF_000525835: 210 uces, 28 dupes, 182 non-dupes, 0 orient drop, 1 length drop, 181 written
# 2020-02-07 10:43:56,452 - Phyluce - INFO - --------- Working on Listeria_grayi_GCF_000148995 genome --------
# 2020-02-07 10:43:56,462 - Phyluce - INFO - Reading Listeria_grayi_GCF_000148995 genome
# 2020-02-07 10:43:57,293 - Phyluce - INFO - Listeria_grayi_GCF_000148995: 211 uces, 11 dupes, 200 non-dupes, 7 orient drop, 7 length drop, 186 written
# 2020-02-07 10:43:57,293 - Phyluce - INFO - -------- Working on Listeria_innocua_GCF_000195795 genome -------
# 2020-02-07 10:43:57,304 - Phyluce - INFO - Reading Listeria_innocua_GCF_000195795 genome
# 2020-02-07 10:43:58,419 - Phyluce - INFO - Listeria_innocua_GCF_000195795: 213 uces, 2 dupes, 211 non-dupes, 39 orient drop, 9 length drop, 163 written
# 2020-02-07 10:43:58,420 - Phyluce - INFO - ------- Working on Listeria_ivanovii_GCF_900637745 genome -------
# 2020-02-07 10:43:58,421 - Phyluce - INFO - Reading Listeria_ivanovii_GCF_900637745 genome
# 2020-02-07 10:43:59,517 - Phyluce - INFO - Listeria_ivanovii_GCF_900637745: 213 uces, 0 dupes, 213 non-dupes, 39 orient drop, 10 length drop, 164 written
# 2020-02-07 10:43:59,517 - Phyluce - INFO - ------ Working on Listeria_kieliensis_GCF_003369925 genome ------
# 2020-02-07 10:43:59,518 - Phyluce - INFO - Reading Listeria_kieliensis_GCF_003369925 genome
# 2020-02-07 10:44:00,285 - Phyluce - INFO - Listeria_kieliensis_GCF_003369925: 209 uces, 17 dupes, 192 non-dupes, 5 orient drop, 2 length drop, 185 written
# 2020-02-07 10:44:00,285 - Phyluce - INFO - -------- Working on Listeria_marthii_GCF_000183865 genome -------
# 2020-02-07 10:44:00,286 - Phyluce - INFO - Reading Listeria_marthii_GCF_000183865 genome
# 2020-02-07 10:44:00,984 - Phyluce - INFO - Listeria_marthii_GCF_000183865: 202 uces, 0 dupes, 202 non-dupes, 14 orient drop, 12 length drop, 176 written
# 2020-02-07 10:44:00,984 - Phyluce - INFO - ----- Working on Listeria_newyorkensis_GCF_900461625 genome -----
# 2020-02-07 10:44:00,991 - Phyluce - INFO - Reading Listeria_newyorkensis_GCF_900461625 genome
# 2020-02-07 10:44:02,074 - Phyluce - INFO - Listeria_newyorkensis_GCF_900461625: 210 uces, 40 dupes, 170 non-dupes, 0 orient drop, 1 length drop, 169 written
# 2020-02-07 10:44:02,074 - Phyluce - INFO - -------- Working on Listeria_riparia_GCF_000525995 genome -------
# 2020-02-07 10:44:02,075 - Phyluce - INFO - Reading Listeria_riparia_GCF_000525995 genome
# 2020-02-07 10:44:02,848 - Phyluce - INFO - Listeria_riparia_GCF_000525995: 210 uces, 23 dupes, 187 non-dupes, 0 orient drop, 2 length drop, 185 written
# 2020-02-07 10:44:02,849 - Phyluce - INFO - ------ Working on Listeria_rocourtiae_GCF_000525975 genome ------
# 2020-02-07 10:44:02,866 - Phyluce - INFO - Reading Listeria_rocourtiae_GCF_000525975 genome
# 2020-02-07 10:44:03,644 - Phyluce - INFO - Listeria_rocourtiae_GCF_000525975: 211 uces, 20 dupes, 191 non-dupes, 0 orient drop, 0 length drop, 191 written
# 2020-02-07 10:44:03,644 - Phyluce - INFO - ------- Working on Listeria_seeligeri_GCF_000027145 genome ------
# 2020-02-07 10:44:03,645 - Phyluce - INFO - Reading Listeria_seeligeri_GCF_000027145 genome
# 2020-02-07 10:44:04,733 - Phyluce - INFO - Listeria_seeligeri_GCF_000027145: 213 uces, 0 dupes, 213 non-dupes, 42 orient drop, 9 length drop, 162 written
# 2020-02-07 10:44:04,733 - Phyluce - INFO - ---------- Working on Listeria_sp_GCF_003856515 genome ----------
# 2020-02-07 10:44:04,734 - Phyluce - INFO - Reading Listeria_sp_GCF_003856515 genome
# 2020-02-07 10:44:05,486 - Phyluce - INFO - Listeria_sp_GCF_003856515: 210 uces, 17 dupes, 193 non-dupes, 0 orient drop, 3 length drop, 190 written
# 2020-02-07 10:44:05,486 - Phyluce - INFO - ----- Working on Listeria_thailandensis_GCF_900576925 genome ----
# 2020-02-07 10:44:05,487 - Phyluce - INFO - Reading Listeria_thailandensis_GCF_900576925 genome
# 2020-02-07 10:44:06,257 - Phyluce - INFO - Listeria_thailandensis_GCF_900576925: 208 uces, 21 dupes, 187 non-dupes, 2 orient drop, 0 length drop, 185 written
# 2020-02-07 10:44:06,257 - Phyluce - INFO - -- Working on Listeria_weihenstephanensis_GCF_000525955 genome --
# 2020-02-07 10:44:06,258 - Phyluce - INFO - Reading Listeria_weihenstephanensis_GCF_000525955 genome
# 2020-02-07 10:44:07,067 - Phyluce - INFO - Listeria_weihenstephanensis_GCF_000525955: 211 uces, 30 dupes, 181 non-dupes, 0 orient drop, 1 length drop, 180 written
# 2020-02-07 10:44:07,067 - Phyluce - INFO - ------ Working on Listeria_welshimeri_GCF_900187315 genome ------
# 2020-02-07 10:44:07,068 - Phyluce - INFO - Reading Listeria_welshimeri_GCF_900187315 genome
# 2020-02-07 10:44:08,170 - Phyluce - INFO - Listeria_welshimeri_GCF_900187315: 213 uces, 0 dupes, 213 non-dupes, 41 orient drop, 11 length drop, 161 written
# 2020-02-07 10:44:08,170 - Phyluce - INFO - ----- Working on Listeria_monocytogenes_GCF_000196035 genome ----
# 2020-02-07 10:44:08,172 - Phyluce - INFO - Reading Listeria_monocytogenes_GCF_000196035 genome
# 2020-02-07 10:44:09,271 - Phyluce - INFO - Listeria_monocytogenes_GCF_000196035: 213 uces, 0 dupes, 213 non-dupes, 40 orient drop, 11 length drop, 162 written

# %%
o_dir       = "results/phyluce/" + group + "/extract_probes_from_group/"
o_probe_dir = o_probe_dir
o_sqlite_db = o_dir + "multifastas.sqlite"

phyluce_cmd = str("phyluce_probe_get_multi_fasta_table "
                      "--fastas {} "
                      "--output {} "
                      "--base-taxon {};").format(o_probe_dir, 
                                                 o_sqlite_db, 
                                                 reference_taxon)
print(phyluce_cmd)
# !{phyluce_cmd}

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {} "
                      "--base-taxon {};").format(o_sqlite_db, 
                                                 reference_taxon)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_multi_fasta_table --fastas results/phyluce/listeria/extract_probes_from_group/probe_fasta --output results/phyluce/listeria/extract_probes_from_group/multifastas.sqlite --base-taxon Listeria_monocytogenes_GCF_000196035;
# listeria_aquatica_gcf_000525795.
# listeria_booriae_gcf_000766865.
# listeria_cornellensis_gcf_000525855.
# listeria_costaricensis_gcf_900183385.
# listeria_fleischmannii_gcf_000252625.
# listeria_floridensis_gcf_000525875.
# listeria_goaensis_gcf_900186125.
# listeria_grandensis_gcf_000525835.
# listeria_grayi_gcf_000148995.
# listeria_innocua_gcf_000195795.
# listeria_ivanovii_gcf_900637745.
# listeria_kieliensis_gcf_003369925.
# listeria_marthii_gcf_000183865.
# listeria_newyorkensis_gcf_900461625.
# listeria_riparia_gcf_000525995.
# listeria_rocourtiae_gcf_000525975.
# listeria_seeligeri_gcf_000027145.
# listeria_sp_gcf_003856515.
# listeria_thailandensis_gcf_900576925.
# listeria_weihenstephanensis_gcf_000525955.
# listeria_welshimeri_gcf_900187315.
# listeria_monocytogenes_gcf_000196035.
# Creating database
# Inserting results
# phyluce_probe_query_multi_fasta_table --db results/phyluce/listeria/extract_probes_from_group/multifastas.sqlite --base-taxon Listeria_monocytogenes_GCF_000196035;
# Loci shared by 0 taxa:	208.0
# Loci shared by 1 taxa:	208.0
# Loci shared by 2 taxa:	204.0
# Loci shared by 3 taxa:	202.0
# Loci shared by 4 taxa:	202.0
# Loci shared by 5 taxa:	200.0
# Loci shared by 6 taxa:	200.0
# Loci shared by 7 taxa:	198.0
# Loci shared by 8 taxa:	196.0
# Loci shared by 9 taxa:	194.0
# Loci shared by 10 taxa:	192.0
# Loci shared by 11 taxa:	189.0
# Loci shared by 12 taxa:	184.0
# Loci shared by 13 taxa:	181.0
# Loci shared by 14 taxa:	177.0
# Loci shared by 15 taxa:	175.0
# Loci shared by 16 taxa:	163.0
# Loci shared by 17 taxa:	157.0
# Loci shared by 18 taxa:	152.0
# Loci shared by 19 taxa:	150.0
# Loci shared by 20 taxa:	145.0
# Loci shared by 21 taxa:	144.0
# Loci shared by 22 taxa:	131.0

# %%
i_sqlite_db     = o_sqlite_db
target_num_taxa = str(20)
o_conf          = "".join([o_dir, reference_taxon, "+", str(num_taxa), "-back-to-", target_num_taxa, ".conf"])

phyluce_cmd = str("phyluce_probe_query_multi_fasta_table "
                      "--db {}  "
                      "--base-taxon {} "
                      "--output {} "
                      "--specific-counts {};").format(i_sqlite_db, 
                                                      reference_taxon, 
                                                      o_conf, 
                                                      target_num_taxa)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_query_multi_fasta_table --db results/phyluce/listeria/extract_probes_from_group/multifastas.sqlite  --base-taxon Listeria_monocytogenes_GCF_000196035 --output results/phyluce/listeria/extract_probes_from_group/Listeria_monocytogenes_GCF_000196035+6-back-to-20.conf --specific-counts 20;
# Counter({'listeria_goaensis_gcf_900186125': 145, 'listeria_floridensis_gcf_000525875': 145, 'listeria_fleischmannii_gcf_000252625': 145, 'listeria_welshimeri_gcf_900187315': 145, 'listeria_aquatica_gcf_000525795': 145, 'listeria_cornellensis_gcf_000525855': 145, 'listeria_weihenstephanensis_gcf_000525955': 145, 'listeria_kieliensis_gcf_003369925': 145, 'listeria_thailandensis_gcf_900576925': 145, 'listeria_rocourtiae_gcf_000525975': 145, 'listeria_grayi_gcf_000148995': 145, 'listeria_riparia_gcf_000525995': 145, 'listeria_sp_gcf_003856515': 145, 'listeria_monocytogenes_gcf_000196035': 145, 'listeria_newyorkensis_gcf_900461625': 145, 'listeria_seeligeri_gcf_000027145': 144, 'listeria_ivanovii_gcf_900637745': 144, 'listeria_booriae_gcf_000766865': 144, 'listeria_grandensis_gcf_000525835': 144, 'listeria_innocua_gcf_000195795': 143, 'listeria_costaricensis_gcf_900183385': 141, 'listeria_marthii_gcf_000183865': 140})
# Total loci = 145

# %% [markdown]
# ## Final group specific bait design

# %%
o_dir       = "results/phyluce/" + group + "/final_probe_design/"

if os.path.exists(o_dir):
    shutil.rmtree(o_dir)

os.mkdir(o_dir)

i_probe_dir = o_probe_dir
i_conf = o_conf
i_probe_prefix = "uce_" + group + "_"
i_designer_txt = "rnplattii"
i_design_txt   = group + "_v1"
i_tiling_density = "3"

o_probes_fas     = o_dir + i_design_txt + "-master_probe_list.fasta"


phyluce_cmd = str("phyluce_probe_get_tiled_probe_from_multiple_inputs "
                      "--fastas {} "
                      "--multi-fasta-output {} "
                      "--probe-prefix {} "
                      "--designer {} "
                      "--design {} "
                      "--probe-length 80 "
                      "--tiling-density 3 "
                      "--overlap middle "
                      "--masking 0.25 "
                      "--remove-gc "
                      "--two-probes "
                      "--output {};").format(i_probe_dir, 
                                             i_conf, i_probe_prefix, 
                                             i_designer_txt, 
                                             i_design_txt, 
                                             o_probes_fas)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_get_tiled_probe_from_multiple_inputs --fastas results/phyluce/listeria/extract_probes_from_group/probe_fasta --multi-fasta-output results/phyluce/listeria/extract_probes_from_group/Listeria_monocytogenes_GCF_000196035+6-back-to-20.conf --probe-prefix uce_listeria_ --designer rnplattii --design listeria_v1 --probe-length 80 --tiling-density 3 --overlap middle --masking 0.25 --remove-gc --two-probes --output results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.fasta;
# GGGGGGGGGGGNNGGGGGNGGGNNNNNGGGGGGNGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGGG
#
#
# Conserved locus count = 145
# Probe Count = 6264

# %%
i_probes_fas   = o_probes_fas
o_lastz_tbl    = o_dir + i_design_txt + "-master_probe_list-TO-SELF-PROBES.lastz"


phyluce_cmd = str("phyluce_probe_easy_lastz "
                      "--target {} "
                      "--query {} "
                      "--identity 50 "
                      "--coverage 50 "
                      "--output {};").format(o_probes_fas, 
                                             o_probes_fas, 
                                             o_lastz_tbl)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_easy_lastz --target results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.fasta --query results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.fasta --identity 50 --coverage 50 --output results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list-TO-SELF-PROBES.lastz;
# Started:  Fri Feb 07, 2020  10:44:32
# Ended:  Fri Feb 07, 2020  10:44:47
# Time for execution:  0.244520934423 minutes

# %%
i_lastz_tbl = o_lastz_tbl
i_probe_prefix = "uce_" + group + "_"

phyluce_cmd = str("phyluce_probe_remove_duplicate_hits_from_probes_using_lastz "
                      "--fasta {} "
                      "--lastz {} "
                      "--probe-prefix={};").format(i_probes_fas, 
                                                   i_lastz_tbl, 
                                                   i_probe_prefix)

print(phyluce_cmd)
# !{phyluce_cmd}
# Out:
# phyluce_probe_remove_duplicate_hits_from_probes_using_lastz --fasta results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.fasta --lastz results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list-TO-SELF-PROBES.lastz --probe-prefix=uce_listeria_;
# Parsing lastz file...
# Screening results...
# Screened 6263 fasta sequences.  Filtered 2 duplicates. Kept 6180.

# %% [markdown]
# ## CDhit to reduce numbers

# %%
i_probe_fasta = o_probes_fas 
o_clust_prfx = o_probes_fas.replace("fasta", "95P_cdhit")

cdhit_cmd = "cd-hit-est -c 0.95 -G 1 -T 4 -i {} -o {}".format(i_probe_fasta, o_clust_prfx)

# !{cdhit_cmd}
# Out:
# ================================================================
# Program: CD-HIT, V4.8.1 (+OpenMP), Oct 26 2019, 14:51:47
# Command: cd-hit-est -c 0.95 -G 1 -T 4 -i
#          results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.fasta
#          -o
#          results/phyluce/listeria/final_probe_design/listeria_v1-master_probe_list.95P_cdhit
#
# Started: Fri Feb  7 10:50:30 2020
# ================================================================
#                             Output
# ----------------------------------------------------------------
# total seq: 6264
# longest and shortest : 80 and 80
# Total letters: 501120
# Sequences have been sorted
#
# Approximated minimal memory consumption:
# Sequence        : 1M
# Buffer          : 4 X 12M = 48M
# Table           : 2 X 16M = 33M
# Miscellaneous   : 4M
# Total           : 87M
#
# Table limit with the given memory limit:
# Max number of representatives: 3954331
# Max number of word counting entries: 89011995
#
# # comparing sequences from          0  to       1044
# .---------- new table with      645 representatives
# # comparing sequences from       1044  to       1914
# ----------    386 remaining sequences to the next cycle
# ---------- new table with      299 representatives
# # comparing sequences from       1528  to       2317
# ----------    326 remaining sequences to the next cycle
# ---------- new table with      264 representatives
# # comparing sequences from       1991  to       2703
# ----------    335 remaining sequences to the next cycle
# ---------- new table with      149 representatives
# # comparing sequences from       2368  to       3017
# ----------    344 remaining sequences to the next cycle
# ---------- new table with      131 representatives
# # comparing sequences from       2673  to       3271
# ----------    194 remaining sequences to the next cycle
# ---------- new table with      225 representatives
# # comparing sequences from       3077  to       3608
# ----------    252 remaining sequences to the next cycle
# ---------- new table with      141 representatives
# # comparing sequences from       3356  to       3840
# ----------    132 remaining sequences to the next cycle
# ---------- new table with      201 representatives
# # comparing sequences from       3708  to       4134
# ----------    207 remaining sequences to the next cycle
# ---------- new table with      152 representatives
# # comparing sequences from       3927  to       4316
# ----------    172 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from       4144  to       4497
# ----------     19 remaining sequences to the next cycle
# ---------- new table with      148 representatives
# # comparing sequences from       4478  to       4775
# ----------    110 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from       4665  to       4931
# ----------    106 remaining sequences to the next cycle
# ---------- new table with      100 representatives
# # comparing sequences from       4825  to       5064
# ----------     66 remaining sequences to the next cycle
# ---------- new table with      106 representatives
# # comparing sequences from       4998  to       5209
# ...................---------- new table with       86 representatives
# # comparing sequences from       5209  to       5384
# 100.0%---------- new table with       91 representatives
# # comparing sequences from       5384  to       6264
# .....................---------- new table with      507 representatives
#
#      6264  finished       3445  clusters
#
# Approximated maximum memory consumption: 88M
# writing new database
# writing clustering information
# program completed !
#
# Total CPU time 1.38
